# %%
from torchvision.datasets import MNIST, FashionMNIST, CIFAR10
import torchvision
import numpy as np
import random

import torch
import torch.nn.functional as F
import cl_gym as cl

import sys
import os

seed = 10

np.random.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.cuda.manual_seed_all(seed)
torch.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = True
torch.set_num_threads(8)

# torch.backends.cudnn.enabled = False

def make_params() -> dict:
    import os
    from pathlib import Path
    import uuid

    params = {
            # dataset
            # 'dataset': "CIFAR100",
            'dataset': "Drug",
            'fairness_agg': 'mean',
            'random_class_idx': False,

            # benchmark
            'seed': seed,
            'num_tasks': 3,
            'epochs_per_task': 25,
            'per_task_examples': np.inf,
            # 'per_task_examples': 10000,
            'per_task_memory_examples': 64,
            'batch_size_train': 64,
            'batch_size_memory': 64,
            'batch_size_validation': 256,
            'tau': 10.,
            # 'tau': 0.0,

            # algorithm
            'optimizer': 'sgd',
            'learning_rate': 0.001,
            'momentum': 0.9,
            'learning_rate_decay': 1.0,
            'criterion': torch.nn.CrossEntropyLoss(),
            'device': torch.device('cuda:7' if torch.cuda.is_available() else 'cpu'),
             
            # sample selection
            'alpha':0.000,
            'lambda': .0,
            'lambda_old': 0.0,
              }

#     trial_id = str(uuid.uuid4())
    trial_id = f"demo/dataset={params['dataset']}/seed={params['seed']}_epoch={params['epochs_per_task']}_lr={params['learning_rate']}_alpha={params['alpha']}_tau={params['tau']}"
    params['trial_id'] = trial_id
    params['output_dir'] = os.path.join("./outputs/{}".format(trial_id))
    print(f"output_dir={params['output_dir']}")
    Path(params['output_dir']).mkdir(parents=True, exist_ok=True)

    return params

params = make_params()
# Out:
# output_dir=./outputs/demo/dataset=Drug/seed=10_epoch=25_lr=0.001_alpha=0.0_tau=10

# %%
from datasets import MNIST
from datasets import FashionMNIST
from datasets import BiasedMNIST
from datasets import CIFAR10, CIFAR100, Drug

if params['dataset'] == 'MNIST':
    benchmark = MNIST(num_tasks=params['num_tasks'],
                    per_task_memory_examples=params['per_task_memory_examples'],
                    per_task_examples = params['per_task_examples'],
                    random_class_idx = params['random_class_idx'])
    input_dim = (28, 28)
elif params['dataset'] == 'FashionMNIST':
    benchmark = FashionMNIST(num_tasks=params['num_tasks'],
                            per_task_memory_examples=params['per_task_memory_examples'],
                            per_task_examples = params['per_task_examples'],
                            random_class_idx = params['random_class_idx'])
    input_dim = (28, 28)
elif params['dataset'] == 'CIFAR10':
    benchmark = CIFAR10(num_tasks=params['num_tasks'],
                        per_task_memory_examples=params['per_task_memory_examples'],
                        per_task_examples = params['per_task_examples'],
                        random_class_idx = params['random_class_idx'])
    input_dim = (3, 32, 32)
elif params['dataset'] == 'CIFAR100':        
    benchmark = CIFAR100(num_tasks=params['num_tasks'],
                        per_task_memory_examples=params['per_task_memory_examples'],
                        per_task_examples = params['per_task_examples'],
                        random_class_idx = params['random_class_idx'])
    input_dim = (3, 32, 32)
elif params['dataset'] in ["BiasedMNIST"]:
    benchmark = BiasedMNIST(num_tasks=params['num_tasks'],
                                per_task_memory_examples=params['per_task_memory_examples'],
                                per_task_examples = params['per_task_examples'],
                                random_class_idx=False)
    input_dim = (3, 28, 28)
elif params['dataset'] == 'Drug':        
    benchmark = Drug(num_tasks=params['num_tasks'],
                        per_task_memory_examples=params['per_task_memory_examples'],
                        per_task_examples = params['per_task_examples'],
                        joint = params['random_class_idx'],
                        random_class_idx = params['random_class_idx'])
    input_dim = (12)
else:
    raise NotImplementedError
class_idx = benchmark.class_idx
num_classes = len(class_idx)

# %%
from algorithms.ocs import OCS
from metrics import FairMetricCollector
from backbones import MLP2Layers2

backbone = MLP2Layers2(
    input_dim=input_dim, 
    hidden_dim_1=256, 
    hidden_dim_2=256, 
    output_dim=num_classes,
    class_idx=class_idx,
    config=params
    ).to(params['device'])

# from backbones import ResNet18
# backbone = ResNet18(
#     input_dim=input_dim, 
#     output_dim=num_classes,
#     class_idx=class_idx,
#     config=params
#     ).to(params['device'])

algorithm = OCS(backbone, benchmark, params, requires_memory=True)
metric_manager_callback = FairMetricCollector(num_tasks=params['num_tasks'],
                                                        eval_interval='epoch',
                                                        epochs_per_task=params['epochs_per_task'])

# %%
metric_manager_callback.meters['accuracy'].data.shape
# Out:
# (4, 4, 25)

# %%
from trainers.baselines import BaseMemoryContinualTrainer3 as ContinualTrainer

trainer = ContinualTrainer(algorithm, params, callbacks=[metric_manager_callback])

# %%
# CIFAR10: self.dataset.data.shape=(50000, 32, 32, 3)

# %%
np.seterr(all='raise')

trainer.run()
print("final avg-acc", metric_manager_callback.meters['accuracy'].compute_final())
print("final avg-forget", metric_manager_callback.meters['forgetting'].compute_final())
# Out:
# ---------------------------- Task 1 -----------------------
# [1] Eval metrics for task 1 >> {'accuracy': 0.41796875, 'loss': 0.009389458791069363, 'std': 0.41796875, 'EER': -1, 'EO': [0.0, 0.17755102040816328], 'DP': -1, 'accuracy_s0': 0.35, 'accuracy_s1': 0.4387755102040816, 'classwise_accuracy': {1: array([ 0, 56]), 0: array([107, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 43, 5: 3, 3: 10}, 'class_pred_count_s1': {0: 112, 5: 12, 3: 4}, 'class_pred_count': {0: 155, 5: 15, 3: 14}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [1] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.008593519744665726, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 56]), 0: array([128, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [2] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.007678612418796705, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 56]), 0: array([128, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [2] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.006850768042647321, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([128, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [3] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.00624847412109375, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([128, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [3] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.005797360254370648, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([128, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [4] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.00542052219743314, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 56]), 0: array([128, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [4] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.005144309414469678, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([128, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [5] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.004919155784275221, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([128, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [5] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.00464164595241132, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([128, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [6] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.004417407771815424, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 56]), 0: array([128, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [6] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.004257249767365663, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([128, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [7] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.004103525501230489, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([128, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [7] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.003964394007040107, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 56]), 0: array([128, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [8] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.003901923804179482, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([128, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [8] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0038945908131806746, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 56]), 0: array([128, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [9] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.003756771592990212, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([128, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [9] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.003682476670845695, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 56]), 0: array([128, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [10] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.003644752437653749, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 56]), 0: array([128, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [10] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.003618135076502095, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([128, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [11] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.003600100136321524, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([128, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [11] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.003578500255294468, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 56]), 0: array([128, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [12] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0035381586007449937, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([128, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [12] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.003533501016057056, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 56]), 0: array([128, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [13] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0035147663691769476, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([128, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [13] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.003463452924852786, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 56]), 0: array([128, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [14] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.003450009162011354, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 56]), 0: array([128, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [14] Eval metrics for task 1 >> {'accuracy': 0.49609375, 'loss': 0.0034666265482487884, 'std': 0.49609375, 'EER': -1, 'EO': [0.033333333333333326, 0.0], 'DP': -1, 'accuracy_s0': 0.48333333333333334, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([127, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 55, 1: 1}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 183, 1: 1}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [15] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0034383409049199977, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([128, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [15] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0034148880968923154, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 56]), 0: array([128, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [16] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.003396361742330634, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([128, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [16] Eval metrics for task 1 >> {'accuracy': 0.49609375, 'loss': 0.0033859607318173284, 'std': 0.49609375, 'EER': -1, 'EO': [0.033333333333333326, 0.0], 'DP': -1, 'accuracy_s0': 0.48333333333333334, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([127, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 55, 1: 1}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 183, 1: 1}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [17] Eval metrics for task 1 >> {'accuracy': 0.5011160714285714, 'loss': 0.00339318520349005, 'std': 0.4832589285714286, 'EER': -1, 'EO': [0.06666666666666665, 0.038461538461538464], 'DP': -1, 'accuracy_s0': 0.4858974358974359, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([126, 128]), 1: array([ 1, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 53, 1: 3}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 181, 1: 3}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [17] Eval metrics for task 1 >> {'accuracy': 0.49609375, 'loss': 0.0033600932877996693, 'std': 0.49609375, 'EER': -1, 'EO': [0.033333333333333326, 0.0], 'DP': -1, 'accuracy_s0': 0.48333333333333334, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([127, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 55, 1: 1}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 183, 1: 1}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [18] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.003341687114342399, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([128, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [18] Eval metrics for task 1 >> {'accuracy': 0.5011160714285714, 'loss': 0.003349990948386814, 'std': 0.4832589285714286, 'EER': -1, 'EO': [0.06666666666666665, 0.038461538461538464], 'DP': -1, 'accuracy_s0': 0.4858974358974359, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([126, 128]), 1: array([ 1, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 53, 1: 3}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 181, 1: 3}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [19] Eval metrics for task 1 >> {'accuracy': 0.5172991071428571, 'loss': 0.003400664938532788, 'std': 0.42801339285714285, 'EER': -1, 'EO': [0.10272108843537409, 0.12051282051282053], 'DP': -1, 'accuracy_s0': 0.5102564102564102, 'accuracy_s1': 0.501360544217687, 'classwise_accuracy': {0: array([121, 128]), 1: array([ 5, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 48, 1: 8}, 'class_pred_count_s1': {0: 124, 1: 4}, 'class_pred_count': {0: 172, 1: 12}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [19] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.003315391099971274, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 56]), 0: array([128, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [20] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0033091225701829662, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([128, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [20] Eval metrics for task 1 >> {'accuracy': 0.5011160714285714, 'loss': 0.003314521973547728, 'std': 0.4832589285714286, 'EER': -1, 'EO': [0.06666666666666665, 0.038461538461538464], 'DP': -1, 'accuracy_s0': 0.4858974358974359, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([126, 128]), 1: array([ 1, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 53, 1: 3}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 181, 1: 3}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [21] Eval metrics for task 1 >> {'accuracy': 0.5212053571428571, 'loss': 0.003352307431075884, 'std': 0.43191964285714285, 'EER': -1, 'EO': [0.11292517006802716, 0.12051282051282053], 'DP': -1, 'accuracy_s0': 0.5102564102564102, 'accuracy_s1': 0.5064625850340136, 'classwise_accuracy': {0: array([122, 128]), 1: array([ 5, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 48, 1: 8}, 'class_pred_count_s1': {0: 125, 1: 3}, 'class_pred_count': {0: 173, 1: 11}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [21] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.003288950609124225, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 56]), 0: array([128, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 56}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 184}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [22] Eval metrics for task 1 >> {'accuracy': 0.5251116071428571, 'loss': 0.0033271202574605527, 'std': 0.43582589285714285, 'EER': -1, 'EO': [0.12051282051282053, 0.07959183673469383], 'DP': -1, 'accuracy_s0': 0.5269230769230769, 'accuracy_s1': 0.5064625850340136, 'classwise_accuracy': {1: array([ 5, 56]), 0: array([123, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 49, 1: 7}, 'class_pred_count_s1': {0: 125, 1: 3}, 'class_pred_count': {0: 174, 1: 10}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [22] Eval metrics for task 1 >> {'accuracy': 0.5290178571428571, 'loss': 0.0032996046154395394, 'std': 0.43973214285714285, 'EER': -1, 'EO': [0.0897959183673469, 0.12051282051282053], 'DP': -1, 'accuracy_s0': 0.5269230769230769, 'accuracy_s1': 0.5115646258503401, 'classwise_accuracy': {0: array([124, 128]), 1: array([ 5, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 49, 1: 7}, 'class_pred_count_s1': {0: 126, 1: 2}, 'class_pred_count': {0: 175, 1: 9}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [23] Eval metrics for task 1 >> {'accuracy': 0.5050223214285714, 'loss': 0.0032698359826336737, 'std': 0.48716517857142855, 'EER': -1, 'EO': [0.038461538461538464, 0.033333333333333326], 'DP': -1, 'accuracy_s0': 0.5025641025641026, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 1, 56]), 0: array([127, 128])}, 'DP_ingredients': {'class_pred_count_s0': {1: 2, 0: 54}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {1: 2, 0: 182}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [23] Eval metrics for task 1 >> {'accuracy': 0.5100446428571429, 'loss': 0.003265391549338465, 'std': 0.47433035714285715, 'EER': -1, 'EO': [0.06666666666666665, 0.005128205128205131], 'DP': -1, 'accuracy_s0': 0.4858974358974359, 'accuracy_s1': 0.5166666666666667, 'classwise_accuracy': {0: array([126, 128]), 1: array([ 2, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 53, 1: 3}, 'class_pred_count_s1': {0: 127, 1: 1}, 'class_pred_count': {0: 180, 1: 4}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [24] Eval metrics for task 1 >> {'accuracy': 0.5050223214285714, 'loss': 0.003254883315252221, 'std': 0.48716517857142855, 'EER': -1, 'EO': [0.038461538461538464, 0.033333333333333326], 'DP': -1, 'accuracy_s0': 0.5025641025641026, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 1, 56]), 0: array([127, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 54, 1: 2}, 'class_pred_count_s1': {0: 128}, 'class_pred_count': {0: 182, 1: 2}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [24] Eval metrics for task 1 >> {'accuracy': 0.5290178571428571, 'loss': 0.003262465414793595, 'std': 0.43973214285714285, 'EER': -1, 'EO': [0.0897959183673469, 0.12051282051282053], 'DP': -1, 'accuracy_s0': 0.5269230769230769, 'accuracy_s1': 0.5115646258503401, 'classwise_accuracy': {0: array([124, 128]), 1: array([ 5, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 49, 1: 7}, 'class_pred_count_s1': {0: 126, 1: 2}, 'class_pred_count': {0: 175, 1: 9}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [25] Eval metrics for task 1 >> {'accuracy': 0.5212053571428571, 'loss': 0.003277143058569535, 'std': 0.43191964285714285, 'EER': -1, 'EO': [0.06938775510204076, 0.12051282051282053], 'DP': -1, 'accuracy_s0': 0.5269230769230769, 'accuracy_s1': 0.501360544217687, 'classwise_accuracy': {0: array([122, 128]), 1: array([ 5, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 49, 1: 7}, 'class_pred_count_s1': {0: 124, 1: 4}, 'class_pred_count': {0: 173, 1: 11}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# after select_coreset, num samples per label [118, 74]
# [25] Eval metrics for task 1 >> {'accuracy': 0.5251116071428571, 'loss': 0.00326484150212744, 'std': 0.43582589285714285, 'EER': -1, 'EO': [0.12051282051282053, 0.07959183673469383], 'DP': -1, 'accuracy_s0': 0.5269230769230769, 'accuracy_s1': 0.5064625850340136, 'classwise_accuracy': {1: array([ 5, 56]), 0: array([123, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 49, 1: 7}, 'class_pred_count_s1': {0: 125, 1: 3}, 'class_pred_count': {0: 174, 1: 10}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# training_task_end
# ---------------------------- Task 2 -----------------------
# [26] Eval metrics for task 1 >> {'accuracy': 0.5223214285714286, 'loss': 0.0033287457797838292, 'std': 0.41517857142857145, 'EER': -1, 'EO': [0.09251700680272101, 0.158974358974359], 'DP': -1, 'accuracy_s0': 0.5294871794871795, 'accuracy_s1': 0.4962585034013605, 'classwise_accuracy': {0: array([120, 128]), 1: array([ 6, 56])}, 'DP_ingredients': {'class_pred_count_s0': {1: 9, 0: 47}, 'class_pred_count_s1': {0: 123, 1: 5}, 'class_pred_count': {0: 170, 1: 14}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [26] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.029945248365402223, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {3: array([ 0, 78]), 2: array([ 0, 82])}, 'DP_ingredients': {'class_pred_count_s0': {1: 22, 0: 48}, 'class_pred_count_s1': {0: 85, 1: 5}, 'class_pred_count': {1: 27, 0: 133}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [26] Eval metrics for task 1 >> {'accuracy': 0.5703125, 'loss': 0.003485432785490285, 'std': 0.3203125, 'EER': -1, 'EO': [0.1794871794871795, 0.11836734693877549], 'DP': -1, 'accuracy_s0': 0.573076923076923, 'accuracy_s1': 0.5425170068027211, 'classwise_accuracy': {1: array([14, 56]), 0: array([114, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 41, 1: 15}, 'class_pred_count_s1': {0: 115, 1: 13}, 'class_pred_count': {0: 156, 1: 28}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [26] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.025117701292037962, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 82]), 3: array([ 0, 78])}, 'DP_ingredients': {'class_pred_count_s0': {0: 39, 1: 31}, 'class_pred_count_s1': {0: 80, 1: 10}, 'class_pred_count': {0: 119, 1: 41}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [27] Eval metrics for task 1 >> {'accuracy': 0.5675223214285714, 'loss': 0.003750478119953819, 'std': 0.29966517857142855, 'EER': -1, 'EO': [0.17482993197278918, 0.14615384615384613], 'DP': -1, 'accuracy_s0': 0.5397435897435897, 'accuracy_s1': 0.5540816326530612, 'classwise_accuracy': {0: array([111, 128]), 1: array([15, 56])}, 'DP_ingredients': {'class_pred_count_s0': {1: 17, 0: 39}, 'class_pred_count_s1': {0: 113, 1: 15}, 'class_pred_count': {1: 32, 0: 152}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [27] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.020264682173728944, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {3: array([ 0, 78]), 2: array([ 0, 82])}, 'DP_ingredients': {'class_pred_count_s0': {0: 36, 1: 34}, 'class_pred_count_s1': {1: 14, 0: 76}, 'class_pred_count': {1: 48, 0: 112}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [27] Eval metrics for task 1 >> {'accuracy': 0.5636160714285714, 'loss': 0.004142352096412493, 'std': 0.29575892857142855, 'EER': -1, 'EO': [0.14615384615384613, 0.1646258503401361], 'DP': -1, 'accuracy_s0': 0.5397435897435897, 'accuracy_s1': 0.5489795918367347, 'classwise_accuracy': {1: array([15, 56]), 0: array([110, 128])}, 'DP_ingredients': {'class_pred_count_s0': {1: 17, 0: 39}, 'class_pred_count_s1': {0: 112, 1: 16}, 'class_pred_count': {0: 151, 1: 33}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [27] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.016488485038280487, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 82]), 3: array([ 0, 78])}, 'DP_ingredients': {'class_pred_count_s0': {0: 36, 1: 34}, 'class_pred_count_s1': {0: 75, 1: 15}, 'class_pred_count': {0: 111, 1: 49}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [28] Eval metrics for task 1 >> {'accuracy': 0.5636160714285714, 'loss': 0.0046214088797569275, 'std': 0.29575892857142855, 'EER': -1, 'EO': [0.1646258503401361, 0.14615384615384613], 'DP': -1, 'accuracy_s0': 0.5397435897435897, 'accuracy_s1': 0.5489795918367347, 'classwise_accuracy': {0: array([110, 128]), 1: array([15, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 39, 1: 17}, 'class_pred_count_s1': {0: 112, 1: 16}, 'class_pred_count': {0: 151, 1: 33}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [28] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.01394389122724533, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {3: array([ 0, 78]), 2: array([ 0, 82])}, 'DP_ingredients': {'class_pred_count_s0': {1: 35, 0: 35}, 'class_pred_count_s1': {0: 76, 1: 14}, 'class_pred_count': {1: 49, 0: 111}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [28] Eval metrics for task 1 >> {'accuracy': 0.5636160714285714, 'loss': 0.005121282585289167, 'std': 0.29575892857142855, 'EER': -1, 'EO': [0.14615384615384613, 0.1646258503401361], 'DP': -1, 'accuracy_s0': 0.5397435897435897, 'accuracy_s1': 0.5489795918367347, 'classwise_accuracy': {1: array([15, 56]), 0: array([110, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 39, 1: 17}, 'class_pred_count_s1': {0: 112, 1: 16}, 'class_pred_count': {0: 151, 1: 33}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [28] Eval metrics for task 2 >> {'accuracy': 0.057692307692307696, 'loss': 0.012269244343042374, 'std': 0.057692307692307696, 'EER': -1, 'EO': [0.04812834224598929, 0.0], 'DP': -1, 'accuracy_s0': 0.06818181818181818, 'accuracy_s1': 0.04411764705882353, 'classwise_accuracy': {3: array([ 9, 78]), 2: array([ 0, 82])}, 'DP_ingredients': {'class_pred_count_s0': {0: 31, 1: 33, 3: 6}, 'class_pred_count_s1': {1: 13, 0: 74, 3: 3}, 'class_pred_count': {1: 46, 0: 105, 3: 9}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [29] Eval metrics for task 1 >> {'accuracy': 0.5457589285714286, 'loss': 0.005568482953569163, 'std': 0.3136160714285714, 'EER': -1, 'EO': [0.0692307692307692, 0.0775510204081632], 'DP': -1, 'accuracy_s0': 0.5346153846153846, 'accuracy_s1': 0.5387755102040817, 'classwise_accuracy': {1: array([13, 56]), 0: array([110, 128])}, 'DP_ingredients': {'class_pred_count_s0': {1: 12, 0: 41, 3: 3}, 'class_pred_count_s1': {0: 109, 1: 16, 3: 3}, 'class_pred_count': {1: 28, 0: 150, 3: 6}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [29] Eval metrics for task 2 >> {'accuracy': 0.15384615384615385, 'loss': 0.01115391030907631, 'std': 0.15384615384615385, 'EER': -1, 'EO': [0.232620320855615, 0.0], 'DP': -1, 'accuracy_s0': 0.20454545454545456, 'accuracy_s1': 0.08823529411764706, 'classwise_accuracy': {3: array([24, 78]), 2: array([ 0, 82])}, 'DP_ingredients': {'class_pred_count_s0': {0: 25, 3: 20, 1: 25}, 'class_pred_count_s1': {0: 68, 3: 11, 1: 11}, 'class_pred_count': {0: 93, 3: 31, 1: 36}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [29] Eval metrics for task 1 >> {'accuracy': 0.5083705357142857, 'loss': 0.005950741793798364, 'std': 0.3119419642857143, 'EER': -1, 'EO': [0.11360544217687085, 0.1358974358974359], 'DP': -1, 'accuracy_s0': 0.5012820512820513, 'accuracy_s1': 0.4901360544217687, 'classwise_accuracy': {0: array([105, 128]), 1: array([11, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 38, 1: 8, 3: 10}, 'class_pred_count_s1': {0: 106, 1: 13, 3: 9}, 'class_pred_count': {0: 144, 1: 21, 3: 19}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [29] Eval metrics for task 2 >> {'accuracy': 0.25, 'loss': 0.010355468094348907, 'std': 0.25, 'EER': -1, 'EO': [0.0, 0.46925133689839577], 'DP': -1, 'accuracy_s0': 0.3522727272727273, 'accuracy_s1': 0.11764705882352941, 'classwise_accuracy': {2: array([ 0, 82]), 3: array([39, 78])}, 'DP_ingredients': {'class_pred_count_s0': {0: 18, 1: 15, 3: 37}, 'class_pred_count_s1': {0: 66, 3: 16, 1: 8}, 'class_pred_count': {0: 84, 1: 23, 3: 53}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [30] Eval metrics for task 1 >> {'accuracy': 0.47879464285714285, 'loss': 0.006265764003214629, 'std': 0.31808035714285715, 'EER': -1, 'EO': [0.08299319727891163, 0.20256410256410257], 'DP': -1, 'accuracy_s0': 0.5012820512820513, 'accuracy_s1': 0.4414965986394558, 'classwise_accuracy': {0: array([102, 128]), 1: array([ 9, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 38, 3: 11, 1: 7}, 'class_pred_count_s1': {0: 104, 1: 7, 3: 17}, 'class_pred_count': {0: 142, 1: 14, 3: 28}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [30] Eval metrics for task 2 >> {'accuracy': 0.3076923076923077, 'loss': 0.009746292978525162, 'std': 0.3076923076923077, 'EER': -1, 'EO': [0.0, 0.41310160427807485], 'DP': -1, 'accuracy_s0': 0.3977272727272727, 'accuracy_s1': 0.19117647058823528, 'classwise_accuracy': {2: array([ 0, 82]), 3: array([48, 78])}, 'DP_ingredients': {'class_pred_count_s0': {3: 48, 0: 14, 1: 8}, 'class_pred_count_s1': {0: 63, 3: 23, 1: 4}, 'class_pred_count': {0: 77, 3: 71, 1: 12}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [30] Eval metrics for task 1 >> {'accuracy': 0.4609375, 'loss': 0.0065304526816243715, 'std': 0.3359375, 'EER': -1, 'EO': [0.12564102564102564, 0.12653061224489803], 'DP': -1, 'accuracy_s0': 0.4461538461538461, 'accuracy_s1': 0.4465986394557823, 'classwise_accuracy': {1: array([ 7, 56]), 0: array([102, 128])}, 'DP_ingredients': {'class_pred_count_s0': {3: 14, 1: 5, 0: 37}, 'class_pred_count_s1': {0: 103, 3: 19, 1: 6}, 'class_pred_count': {0: 140, 3: 33, 1: 11}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [30] Eval metrics for task 2 >> {'accuracy': 0.3522514071294559, 'loss': 0.009256859123706818, 'std': 0.3400562851782364, 'EER': -1, 'EO': [0.017857142857142856, 0.2887700534759359], 'DP': -1, 'accuracy_s0': 0.4090909090909091, 'accuracy_s1': 0.27363445378151263, 'classwise_accuracy': {2: array([ 1, 82]), 3: array([54, 78])}, 'DP_ingredients': {'class_pred_count_s0': {3: 52, 0: 15, 1: 3}, 'class_pred_count_s1': {0: 57, 3: 31, 1: 1, 2: 1}, 'class_pred_count': {3: 83, 0: 72, 1: 4, 2: 1}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [31] Eval metrics for task 1 >> {'accuracy': 0.42354910714285715, 'loss': 0.006764351673748182, 'std': 0.33426339285714285, 'EER': -1, 'EO': [0.048717948717948725, 0.11904761904761907], 'DP': -1, 'accuracy_s0': 0.391025641025641, 'accuracy_s1': 0.4261904761904762, 'classwise_accuracy': {1: array([ 5, 56]), 0: array([ 97, 128])}, 'DP_ingredients': {'class_pred_count_s0': {3: 16, 0: 37, 1: 3}, 'class_pred_count_s1': {3: 23, 0: 99, 1: 4, 2: 2}, 'class_pred_count': {3: 39, 0: 136, 1: 7, 2: 2}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [31] Eval metrics for task 2 >> {'accuracy': 0.3714821763602251, 'loss': 0.008843916654586791, 'std': 0.3592870544090056, 'EER': -1, 'EO': [0.017857142857142856, 0.25267379679144386], 'DP': -1, 'accuracy_s0': 0.42045454545454547, 'accuracy_s1': 0.303046218487395, 'classwise_accuracy': {2: array([ 1, 82]), 3: array([57, 78])}, 'DP_ingredients': {'class_pred_count_s0': {0: 12, 3: 54, 2: 1, 1: 3}, 'class_pred_count_s1': {0: 50, 3: 37, 1: 1, 2: 2}, 'class_pred_count': {0: 62, 3: 91, 1: 4, 2: 3}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [31] Eval metrics for task 1 >> {'accuracy': 0.38002232142857145, 'loss': 0.006971492067627285, 'std': 0.36216517857142855, 'EER': -1, 'EO': [0.14217687074829932, 0.038461538461538464], 'DP': -1, 'accuracy_s0': 0.33589743589743587, 'accuracy_s1': 0.3877551020408163, 'classwise_accuracy': {0: array([ 95, 128]), 1: array([ 1, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 34, 3: 20, 1: 1, 2: 1}, 'class_pred_count_s1': {0: 97, 2: 8, 3: 22, 1: 1}, 'class_pred_count': {0: 131, 2: 9, 3: 42, 1: 2}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [31] Eval metrics for task 2 >> {'accuracy': 0.3900875547217011, 'loss': 0.008495260030031204, 'std': 0.3535021888680425, 'EER': -1, 'EO': [0.05357142857142857, 0.2232620320855615], 'DP': -1, 'accuracy_s0': 0.42045454545454547, 'accuracy_s1': 0.335609243697479, 'classwise_accuracy': {2: array([ 3, 82]), 3: array([58, 78])}, 'DP_ingredients': {'class_pred_count_s0': {0: 10, 3: 57, 2: 1, 1: 2}, 'class_pred_count_s1': {0: 46, 3: 40, 2: 4}, 'class_pred_count': {0: 56, 3: 97, 2: 5, 1: 2}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [32] Eval metrics for task 1 >> {'accuracy': 0.36439732142857145, 'loss': 0.007152272307354471, 'std': 0.3465401785714286, 'EER': -1, 'EO': [0.14489795918367354, 0.038461538461538464], 'DP': -1, 'accuracy_s0': 0.3192307692307692, 'accuracy_s1': 0.37244897959183676, 'classwise_accuracy': {0: array([ 91, 128]), 1: array([ 1, 56])}, 'DP_ingredients': {'class_pred_count_s0': {3: 20, 2: 2, 0: 33, 1: 1}, 'class_pred_count_s1': {0: 94, 3: 20, 2: 13, 1: 1}, 'class_pred_count': {0: 127, 3: 40, 2: 15, 1: 2}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [32] Eval metrics for task 2 >> {'accuracy': 0.4019699812382739, 'loss': 0.00820133313536644, 'std': 0.32879924953095685, 'EER': -1, 'EO': [0.25267379679144386, 0.050824175824175824], 'DP': -1, 'accuracy_s0': 0.4396853146853147, 'accuracy_s1': 0.3387605042016807, 'classwise_accuracy': {3: array([57, 78]), 2: array([ 6, 82])}, 'DP_ingredients': {'class_pred_count_s0': {3: 57, 0: 8, 1: 2, 2: 3}, 'class_pred_count_s1': {3: 38, 0: 44, 2: 8}, 'class_pred_count': {3: 95, 0: 52, 2: 11, 1: 2}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [32] Eval metrics for task 1 >> {'accuracy': 0.34765625, 'loss': 0.007311224937438965, 'std': 0.34765625, 'EER': -1, 'EO': [0.0, 0.1244897959183674], 'DP': -1, 'accuracy_s0': 0.3, 'accuracy_s1': 0.3622448979591837, 'classwise_accuracy': {1: array([ 0, 56]), 0: array([ 89, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 33, 3: 18, 2: 5}, 'class_pred_count_s1': {0: 92, 3: 21, 1: 1, 2: 14}, 'class_pred_count': {0: 125, 3: 39, 1: 1, 2: 19}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [32] Eval metrics for task 2 >> {'accuracy': 0.41353971232020015, 'loss': 0.00795285552740097, 'std': 0.29158849280800503, 'EER': -1, 'EO': [0.009615384615384609, 0.3114973262032086], 'DP': -1, 'accuracy_s0': 0.4781468531468532, 'accuracy_s1': 0.3272058823529412, 'classwise_accuracy': {2: array([10, 82]), 3: array([55, 78])}, 'DP_ingredients': {'class_pred_count_s0': {3: 55, 0: 7, 1: 2, 2: 6}, 'class_pred_count_s1': {2: 13, 3: 34, 0: 43}, 'class_pred_count': {2: 19, 3: 89, 0: 50, 1: 2}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [33] Eval metrics for task 1 >> {'accuracy': 0.34375, 'loss': 0.007441704687864884, 'std': 0.34375, 'EER': -1, 'EO': [0.11428571428571432, 0.0], 'DP': -1, 'accuracy_s0': 0.3, 'accuracy_s1': 0.35714285714285715, 'classwise_accuracy': {0: array([ 88, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {3: 15, 0: 32, 2: 9}, 'class_pred_count_s1': {0: 90, 2: 18, 3: 19, 1: 1}, 'class_pred_count': {0: 122, 3: 34, 2: 27, 1: 1}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [33] Eval metrics for task 2 >> {'accuracy': 0.41322701688555347, 'loss': 0.007748399674892425, 'std': 0.2790806754221388, 'EER': -1, 'EO': [0.2887700534759359, 0.027472527472527458], 'DP': -1, 'accuracy_s0': 0.4667832167832168, 'accuracy_s1': 0.33613445378151263, 'classwise_accuracy': {3: array([54, 78]), 2: array([11, 82])}, 'DP_ingredients': {'class_pred_count_s0': {3: 54, 0: 7, 2: 8, 1: 1}, 'class_pred_count_s1': {0: 42, 3: 34, 2: 14}, 'class_pred_count': {3: 88, 0: 49, 2: 22, 1: 1}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [33] Eval metrics for task 1 >> {'accuracy': 0.33203125, 'loss': 0.00753898270752119, 'std': 0.33203125, 'EER': -1, 'EO': [0.1272108843537415, 0.0], 'DP': -1, 'accuracy_s0': 0.2833333333333333, 'accuracy_s1': 0.3469387755102041, 'classwise_accuracy': {0: array([ 85, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {2: 11, 0: 31, 3: 14}, 'class_pred_count_s1': {0: 88, 3: 17, 2: 22, 1: 1}, 'class_pred_count': {0: 119, 2: 33, 3: 31, 1: 1}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [33] Eval metrics for task 2 >> {'accuracy': 0.4437148217636022, 'loss': 0.007586774975061416, 'std': 0.24859287054409004, 'EER': -1, 'EO': [0.2887700534759359, 0.06043956043956042], 'DP': -1, 'accuracy_s0': 0.48601398601398604, 'accuracy_s1': 0.37184873949579833, 'classwise_accuracy': {3: array([54, 78]), 2: array([16, 82])}, 'DP_ingredients': {'class_pred_count_s0': {3: 54, 0: 5, 2: 10, 1: 1}, 'class_pred_count_s1': {0: 40, 2: 18, 3: 32}, 'class_pred_count': {3: 86, 0: 45, 2: 28, 1: 1}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [34] Eval metrics for task 1 >> {'accuracy': 0.3359375, 'loss': 0.007606137705885846, 'std': 0.3359375, 'EER': -1, 'EO': [0.13741496598639458, 0.0], 'DP': -1, 'accuracy_s0': 0.2833333333333333, 'accuracy_s1': 0.3520408163265306, 'classwise_accuracy': {0: array([ 86, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {2: 13, 0: 31, 3: 12}, 'class_pred_count_s1': {0: 89, 2: 23, 3: 16}, 'class_pred_count': {0: 120, 2: 36, 3: 28}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [34] Eval metrics for task 2 >> {'accuracy': 0.46810506566604126, 'loss': 0.0074629709124565125, 'std': 0.22420262664165103, 'EER': -1, 'EO': [0.07554945054945053, 0.2887700534759359], 'DP': -1, 'accuracy_s0': 0.5052447552447553, 'accuracy_s1': 0.39863445378151263, 'classwise_accuracy': {2: array([20, 82]), 3: array([54, 78])}, 'DP_ingredients': {'class_pred_count_s0': {2: 11, 3: 53, 0: 6}, 'class_pred_count_s1': {0: 37, 3: 31, 2: 22}, 'class_pred_count': {0: 43, 3: 84, 2: 33}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [34] Eval metrics for task 1 >> {'accuracy': 0.33203125, 'loss': 0.007650275593218596, 'std': 0.33203125, 'EER': -1, 'EO': [0.1272108843537415, 0.0], 'DP': -1, 'accuracy_s0': 0.2833333333333333, 'accuracy_s1': 0.3469387755102041, 'classwise_accuracy': {0: array([ 85, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {2: 14, 0: 31, 3: 11}, 'class_pred_count_s1': {2: 25, 0: 88, 3: 15}, 'class_pred_count': {2: 39, 0: 119, 3: 26}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [34] Eval metrics for task 2 >> {'accuracy': 0.46075672295184494, 'loss': 0.007370861619710923, 'std': 0.18026891807379614, 'EER': -1, 'EO': [0.03983516483516486, 0.35427807486631013], 'DP': -1, 'accuracy_s0': 0.5515734265734266, 'accuracy_s1': 0.35451680672268904, 'classwise_accuracy': {2: array([23, 82]), 3: array([50, 78])}, 'DP_ingredients': {'class_pred_count_s0': {3: 49, 0: 6, 2: 15}, 'class_pred_count_s1': {0: 37, 2: 25, 3: 28}, 'class_pred_count': {0: 43, 2: 40, 3: 77}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [35] Eval metrics for task 1 >> {'accuracy': 0.33203125, 'loss': 0.007684878033140431, 'std': 0.33203125, 'EER': -1, 'EO': [0.1272108843537415, 0.0], 'DP': -1, 'accuracy_s0': 0.2833333333333333, 'accuracy_s1': 0.3469387755102041, 'classwise_accuracy': {0: array([ 85, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 31, 2: 14, 3: 11}, 'class_pred_count_s1': {0: 88, 2: 25, 3: 15}, 'class_pred_count': {0: 119, 2: 39, 3: 26}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [35] Eval metrics for task 2 >> {'accuracy': 0.4476235146966854, 'loss': 0.007297193259000778, 'std': 0.15494058786741713, 'EER': -1, 'EO': [0.0782967032967033, 0.3382352941176471], 'DP': -1, 'accuracy_s0': 0.5480769230769231, 'accuracy_s1': 0.3398109243697479, 'classwise_accuracy': {2: array([24, 82]), 3: array([47, 78])}, 'DP_ingredients': {'class_pred_count_s0': {2: 18, 3: 46, 0: 6}, 'class_pred_count_s1': {0: 36, 2: 27, 3: 27}, 'class_pred_count': {0: 42, 2: 45, 3: 73}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [35] Eval metrics for task 1 >> {'accuracy': 0.33203125, 'loss': 0.007692952518877776, 'std': 0.33203125, 'EER': -1, 'EO': [0.1272108843537415, 0.0], 'DP': -1, 'accuracy_s0': 0.2833333333333333, 'accuracy_s1': 0.3469387755102041, 'classwise_accuracy': {0: array([ 85, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 31, 3: 11, 2: 14}, 'class_pred_count_s1': {0: 88, 2: 23, 3: 17}, 'class_pred_count': {0: 119, 3: 28, 2: 37}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [35] Eval metrics for task 2 >> {'accuracy': 0.46716697936210133, 'loss': 0.007250281423330307, 'std': 0.18667917448405252, 'EER': -1, 'EO': [0.2727272727272727, 0.03983516483516486], 'DP': -1, 'accuracy_s0': 0.5402097902097902, 'accuracy_s1': 0.3839285714285714, 'classwise_accuracy': {3: array([51, 78]), 2: array([23, 82])}, 'DP_ingredients': {'class_pred_count_s0': {3: 48, 2: 16, 0: 6}, 'class_pred_count_s1': {2: 23, 0: 37, 3: 30}, 'class_pred_count': {3: 78, 2: 39, 0: 43}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [36] Eval metrics for task 1 >> {'accuracy': 0.33203125, 'loss': 0.007684357788251794, 'std': 0.33203125, 'EER': -1, 'EO': [0.1272108843537415, 0.0], 'DP': -1, 'accuracy_s0': 0.2833333333333333, 'accuracy_s1': 0.3469387755102041, 'classwise_accuracy': {0: array([ 85, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {2: 14, 3: 11, 0: 31}, 'class_pred_count_s1': {0: 88, 3: 17, 2: 23}, 'class_pred_count': {0: 119, 2: 37, 3: 28}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [36] Eval metrics for task 2 >> {'accuracy': 0.46075672295184494, 'loss': 0.00722540020942688, 'std': 0.18026891807379614, 'EER': -1, 'EO': [0.03983516483516486, 0.30213903743315507], 'DP': -1, 'accuracy_s0': 0.5402097902097902, 'accuracy_s1': 0.3692226890756303, 'classwise_accuracy': {2: array([23, 82]), 3: array([50, 78])}, 'DP_ingredients': {'class_pred_count_s0': {3: 48, 0: 6, 2: 16}, 'class_pred_count_s1': {0: 37, 3: 29, 2: 24}, 'class_pred_count': {0: 43, 3: 77, 2: 40}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [36] Eval metrics for task 1 >> {'accuracy': 0.33984375, 'loss': 0.007649301186851833, 'std': 0.33984375, 'EER': -1, 'EO': [0.10408163265306125, 0.0], 'DP': -1, 'accuracy_s0': 0.3, 'accuracy_s1': 0.3520408163265306, 'classwise_accuracy': {0: array([ 87, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 32, 2: 14, 3: 10}, 'class_pred_count_s1': {3: 17, 2: 22, 0: 89}, 'class_pred_count': {3: 27, 2: 36, 0: 121}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [36] Eval metrics for task 2 >> {'accuracy': 0.4546591619762352, 'loss': 0.007224909961223602, 'std': 0.1863664790494059, 'EER': -1, 'EO': [0.05769230769230771, 0.30213903743315507], 'DP': -1, 'accuracy_s0': 0.5402097902097902, 'accuracy_s1': 0.3602941176470588, 'classwise_accuracy': {2: array([22, 82]), 3: array([50, 78])}, 'DP_ingredients': {'class_pred_count_s0': {3: 48, 0: 6, 2: 16}, 'class_pred_count_s1': {0: 38, 2: 23, 3: 29}, 'class_pred_count': {0: 44, 2: 39, 3: 77}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [37] Eval metrics for task 1 >> {'accuracy': 0.33984375, 'loss': 0.007604751250018244, 'std': 0.33984375, 'EER': -1, 'EO': [0.10408163265306125, 0.0], 'DP': -1, 'accuracy_s0': 0.3, 'accuracy_s1': 0.3520408163265306, 'classwise_accuracy': {0: array([ 87, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {3: 10, 0: 32, 2: 14}, 'class_pred_count_s1': {0: 90, 2: 21, 3: 17}, 'class_pred_count': {0: 122, 2: 35, 3: 27}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [37] Eval metrics for task 2 >> {'accuracy': 0.4549718574108818, 'loss': 0.007238463312387466, 'std': 0.19887429643527205, 'EER': -1, 'EO': [0.3248663101604278, 0.07554945054945056], 'DP': -1, 'accuracy_s0': 0.5515734265734266, 'accuracy_s1': 0.35136554621848737, 'classwise_accuracy': {3: array([51, 78]), 2: array([21, 82])}, 'DP_ingredients': {'class_pred_count_s0': {2: 15, 3: 49, 0: 6}, 'class_pred_count_s1': {2: 21, 3: 29, 0: 40}, 'class_pred_count': {2: 36, 3: 78, 0: 46}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [37] Eval metrics for task 1 >> {'accuracy': 0.34375, 'loss': 0.0075537413358688354, 'std': 0.34375, 'EER': -1, 'EO': [0.11428571428571432, 0.0], 'DP': -1, 'accuracy_s0': 0.3, 'accuracy_s1': 0.35714285714285715, 'classwise_accuracy': {0: array([ 88, 128]), 1: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 32, 2: 14, 3: 10}, 'class_pred_count_s1': {0: 91, 2: 20, 3: 17}, 'class_pred_count': {0: 123, 2: 34, 3: 27}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [37] Eval metrics for task 2 >> {'accuracy': 0.4491869918699187, 'loss': 0.007263924181461334, 'std': 0.21747967479674793, 'EER': -1, 'EO': [0.2954545454545454, 0.11126373626373628], 'DP': -1, 'accuracy_s0': 0.5515734265734266, 'accuracy_s1': 0.3482142857142857, 'classwise_accuracy': {3: array([52, 78]), 2: array([19, 82])}, 'DP_ingredients': {'class_pred_count_s0': {3: 49, 0: 6, 2: 15}, 'class_pred_count_s1': {3: 32, 0: 40, 2: 18}, 'class_pred_count': {3: 81, 0: 46, 2: 33}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [38] Eval metrics for task 1 >> {'accuracy': 0.34765625, 'loss': 0.007505523121875265, 'std': 0.34765625, 'EER': -1, 'EO': [0.0, 0.1244897959183674], 'DP': -1, 'accuracy_s0': 0.3, 'accuracy_s1': 0.3622448979591837, 'classwise_accuracy': {1: array([ 0, 56]), 0: array([ 89, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 33, 3: 10, 2: 13}, 'class_pred_count_s1': {2: 19, 0: 92, 3: 17}, 'class_pred_count': {2: 32, 0: 125, 3: 27}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [38] Eval metrics for task 2 >> {'accuracy': 0.43699186991869915, 'loss': 0.0072913944721221926, 'std': 0.22967479674796748, 'EER': -1, 'EO': [0.2954545454545454, 0.14697802197802198], 'DP': -1, 'accuracy_s0': 0.5515734265734266, 'accuracy_s1': 0.33035714285714285, 'classwise_accuracy': {3: array([52, 78]), 2: array([17, 82])}, 'DP_ingredients': {'class_pred_count_s0': {3: 49, 0: 6, 2: 15}, 'class_pred_count_s1': {0: 41, 3: 33, 2: 16}, 'class_pred_count': {3: 82, 0: 47, 2: 31}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [38] Eval metrics for task 1 >> {'accuracy': 0.34765625, 'loss': 0.007467264714448348, 'std': 0.34765625, 'EER': -1, 'EO': [0.0, 0.1244897959183674], 'DP': -1, 'accuracy_s0': 0.3, 'accuracy_s1': 0.3622448979591837, 'classwise_accuracy': {1: array([ 0, 56]), 0: array([ 89, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 33, 3: 8, 2: 15}, 'class_pred_count_s1': {0: 92, 2: 20, 3: 16}, 'class_pred_count': {0: 125, 2: 35, 3: 24}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# ...
# [71] Eval metrics for task 1 >> {'accuracy': 0.5719866071428572, 'loss': 0.005592173208361087, 'std': 0.10770089285714285, 'EER': -1, 'EO': [0.4256410256410256, 0.27823129251700685], 'DP': -1, 'accuracy_s0': 0.5794871794871794, 'accuracy_s1': 0.5057823129251701, 'classwise_accuracy': {1: array([26, 56]), 0: array([ 87, 128])}, 'DP_ingredients': {'class_pred_count_s0': {0: 20, 4: 3, 1: 27, 5: 4, 2: 2}, 'class_pred_count_s1': {0: 92, 1: 22, 4: 9, 5: 5}, 'class_pred_count': {0: 112, 4: 12, 1: 49, 5: 9, 2: 2}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [71] Eval metrics for task 2 >> {'accuracy': 0.018292682926829267, 'loss': 0.017773717641830444, 'std': 0.018292682926829267, 'EER': -1, 'EO': [0.0027472527472527514, 0.0], 'DP': -1, 'accuracy_s0': 0.019230769230769232, 'accuracy_s1': 0.017857142857142856, 'classwise_accuracy': {2: array([ 3, 82]), 3: array([ 0, 78])}, 'DP_ingredients': {'class_pred_count_s0': {4: 22, 1: 19, 5: 18, 2: 2, 0: 9}, 'class_pred_count_s1': {5: 13, 4: 15, 0: 49, 1: 10, 2: 3}, 'class_pred_count': {5: 31, 4: 37, 1: 29, 0: 58, 2: 5}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [71] Eval metrics for task 3 >> {'accuracy': 0.401706513474698, 'loss': 0.005327348236565117, 'std': 0.10957168201402383, 'EER': -1, 'EO': [0.05913978494623656, 0.0508171603677221], 'DP': -1, 'accuracy_s0': 0.4011417180137731, 'accuracy_s1': 0.4053030303030303, 'classwise_accuracy': {4: array([26, 89]), 5: array([ 68, 133])}, 'DP_ingredients': {'class_pred_count_s0': {0: 8, 5: 85, 4: 46, 1: 11, 2: 1}, 'class_pred_count_s1': {0: 8, 5: 32, 4: 22, 2: 4, 1: 5}, 'class_pred_count': {0: 16, 5: 117, 4: 68, 1: 16, 2: 5}, 'count_s0': 151, 'count_s1': 71, 'count': 222}}
# [72] Eval metrics for task 1 >> {'accuracy': 0.5680803571428572, 'loss': 0.005593237669571587, 'std': 0.10379464285714285, 'EER': -1, 'EO': [0.2680272108843538, 0.4256410256410256], 'DP': -1, 'accuracy_s0': 0.5794871794871794, 'accuracy_s1': 0.5006802721088436, 'classwise_accuracy': {0: array([ 86, 128]), 1: array([26, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 20, 1: 27, 4: 2, 5: 4, 2: 3}, 'class_pred_count_s1': {0: 91, 5: 5, 4: 9, 1: 23}, 'class_pred_count': {0: 111, 1: 50, 4: 11, 5: 9, 2: 3}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [72] Eval metrics for task 2 >> {'accuracy': 0.018292682926829267, 'loss': 0.017699234187602997, 'std': 0.018292682926829267, 'EER': -1, 'EO': [0.0, 0.0027472527472527514], 'DP': -1, 'accuracy_s0': 0.019230769230769232, 'accuracy_s1': 0.017857142857142856, 'classwise_accuracy': {3: array([ 0, 78]), 2: array([ 3, 82])}, 'DP_ingredients': {'class_pred_count_s0': {4: 21, 5: 18, 1: 19, 0: 9, 2: 3}, 'class_pred_count_s1': {4: 15, 5: 13, 0: 49, 1: 10, 2: 3}, 'class_pred_count': {4: 36, 5: 31, 0: 58, 1: 29, 2: 6}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [72] Eval metrics for task 3 >> {'accuracy': 0.401706513474698, 'loss': 0.005352828416738425, 'std': 0.10957168201402383, 'EER': -1, 'EO': [0.05913978494623656, 0.0508171603677221], 'DP': -1, 'accuracy_s0': 0.4011417180137731, 'accuracy_s1': 0.4053030303030303, 'classwise_accuracy': {4: array([26, 89]), 5: array([ 68, 133])}, 'DP_ingredients': {'class_pred_count_s0': {5: 85, 4: 46, 1: 11, 0: 8, 2: 1}, 'class_pred_count_s1': {5: 32, 1: 5, 4: 22, 0: 8, 2: 4}, 'class_pred_count': {5: 117, 4: 68, 1: 16, 0: 16, 2: 5}, 'count_s0': 151, 'count_s1': 71, 'count': 222}}
# [72] Eval metrics for task 1 >> {'accuracy': 0.5680803571428572, 'loss': 0.005624250873275425, 'std': 0.10379464285714285, 'EER': -1, 'EO': [0.4256410256410256, 0.2680272108843538], 'DP': -1, 'accuracy_s0': 0.5794871794871794, 'accuracy_s1': 0.5006802721088436, 'classwise_accuracy': {1: array([26, 56]), 0: array([ 86, 128])}, 'DP_ingredients': {'class_pred_count_s0': {5: 4, 1: 27, 0: 20, 2: 3, 4: 2}, 'class_pred_count_s1': {0: 91, 4: 10, 1: 23, 5: 4}, 'class_pred_count': {0: 111, 4: 12, 5: 8, 1: 50, 2: 3}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [72] Eval metrics for task 2 >> {'accuracy': 0.018292682926829267, 'loss': 0.01748504638671875, 'std': 0.018292682926829267, 'EER': -1, 'EO': [0.0, 0.0027472527472527514], 'DP': -1, 'accuracy_s0': 0.019230769230769232, 'accuracy_s1': 0.017857142857142856, 'classwise_accuracy': {3: array([ 0, 78]), 2: array([ 3, 82])}, 'DP_ingredients': {'class_pred_count_s0': {1: 19, 0: 9, 5: 17, 4: 21, 2: 4}, 'class_pred_count_s1': {4: 18, 1: 10, 2: 3, 0: 49, 5: 10}, 'class_pred_count': {4: 39, 1: 29, 2: 7, 0: 58, 5: 27}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [72] Eval metrics for task 3 >> {'accuracy': 0.4073244910027879, 'loss': 0.00537442785125595, 'std': 0.10395370448593391, 'EER': -1, 'EO': [0.043010752688172005, 0.0508171603677221], 'DP': -1, 'accuracy_s0': 0.4092062341428053, 'accuracy_s1': 0.4053030303030303, 'classwise_accuracy': {4: array([27, 89]), 5: array([ 68, 133])}, 'DP_ingredients': {'class_pred_count_s0': {5: 84, 4: 46, 1: 11, 0: 8, 2: 2}, 'class_pred_count_s1': {4: 22, 5: 32, 2: 4, 0: 8, 1: 5}, 'class_pred_count': {5: 116, 4: 68, 2: 6, 0: 16, 1: 16}, 'count_s0': 151, 'count_s1': 71, 'count': 222}}
# [73] Eval metrics for task 1 >> {'accuracy': 0.5680803571428572, 'loss': 0.005658327885296034, 'std': 0.10379464285714285, 'EER': -1, 'EO': [0.2680272108843538, 0.4256410256410256], 'DP': -1, 'accuracy_s0': 0.5794871794871794, 'accuracy_s1': 0.5006802721088436, 'classwise_accuracy': {0: array([ 86, 128]), 1: array([26, 56])}, 'DP_ingredients': {'class_pred_count_s0': {1: 27, 5: 3, 0: 20, 4: 3, 2: 3}, 'class_pred_count_s1': {0: 91, 1: 23, 5: 4, 4: 10}, 'class_pred_count': {0: 111, 1: 50, 5: 7, 4: 13, 2: 3}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [73] Eval metrics for task 2 >> {'accuracy': 0.018292682926829267, 'loss': 0.017293742299079894, 'std': 0.018292682926829267, 'EER': -1, 'EO': [0.0027472527472527514, 0.0], 'DP': -1, 'accuracy_s0': 0.019230769230769232, 'accuracy_s1': 0.017857142857142856, 'classwise_accuracy': {2: array([ 3, 82]), 3: array([ 0, 78])}, 'DP_ingredients': {'class_pred_count_s0': {5: 18, 1: 19, 4: 20, 0: 9, 2: 4}, 'class_pred_count_s1': {0: 48, 5: 10, 4: 18, 1: 11, 2: 3}, 'class_pred_count': {0: 57, 5: 28, 1: 30, 4: 38, 2: 7}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [73] Eval metrics for task 3 >> {'accuracy': 0.4073244910027879, 'loss': 0.005391976854822657, 'std': 0.10395370448593391, 'EER': -1, 'EO': [0.0508171603677221, 0.043010752688172005], 'DP': -1, 'accuracy_s0': 0.4092062341428053, 'accuracy_s1': 0.4053030303030303, 'classwise_accuracy': {5: array([ 68, 133]), 4: array([27, 89])}, 'DP_ingredients': {'class_pred_count_s0': {5: 83, 4: 46, 1: 11, 0: 8, 2: 3}, 'class_pred_count_s1': {5: 32, 1: 5, 4: 21, 0: 8, 2: 5}, 'class_pred_count': {5: 115, 4: 67, 1: 16, 0: 16, 2: 8}, 'count_s0': 151, 'count_s1': 71, 'count': 222}}
# [73] Eval metrics for task 1 >> {'accuracy': 0.5731026785714286, 'loss': 0.005687125998994578, 'std': 0.09095982142857142, 'EER': -1, 'EO': [0.2578231292517007, 0.3923076923076923], 'DP': -1, 'accuracy_s0': 0.5794871794871794, 'accuracy_s1': 0.5122448979591837, 'classwise_accuracy': {0: array([ 85, 128]), 1: array([27, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 20, 1: 27, 5: 3, 4: 3, 2: 3}, 'class_pred_count_s1': {2: 1, 0: 89, 1: 25, 5: 3, 4: 10}, 'class_pred_count': {0: 109, 2: 4, 1: 52, 5: 6, 4: 13}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [73] Eval metrics for task 2 >> {'accuracy': 0.018292682926829267, 'loss': 0.01718721687793732, 'std': 0.018292682926829267, 'EER': -1, 'EO': [0.0, 0.0027472527472527514], 'DP': -1, 'accuracy_s0': 0.019230769230769232, 'accuracy_s1': 0.017857142857142856, 'classwise_accuracy': {3: array([ 0, 78]), 2: array([ 3, 82])}, 'DP_ingredients': {'class_pred_count_s0': {0: 9, 4: 20, 1: 19, 5: 18, 2: 4}, 'class_pred_count_s1': {4: 18, 0: 48, 1: 11, 5: 10, 2: 3}, 'class_pred_count': {0: 57, 4: 38, 1: 30, 5: 28, 2: 7}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [73] Eval metrics for task 3 >> {'accuracy': 0.4073244910027879, 'loss': 0.005399142299686467, 'std': 0.10395370448593391, 'EER': -1, 'EO': [0.043010752688172005, 0.0508171603677221], 'DP': -1, 'accuracy_s0': 0.4092062341428053, 'accuracy_s1': 0.4053030303030303, 'classwise_accuracy': {4: array([27, 89]), 5: array([ 68, 133])}, 'DP_ingredients': {'class_pred_count_s0': {4: 46, 5: 83, 1: 11, 0: 8, 2: 3}, 'class_pred_count_s1': {2: 5, 0: 8, 4: 21, 5: 32, 1: 5}, 'class_pred_count': {4: 67, 2: 8, 5: 115, 0: 16, 1: 16}, 'count_s0': 151, 'count_s1': 71, 'count': 222}}
# [74] Eval metrics for task 1 >> {'accuracy': 0.5731026785714286, 'loss': 0.0056902345107949295, 'std': 0.09095982142857142, 'EER': -1, 'EO': [0.2578231292517007, 0.3923076923076923], 'DP': -1, 'accuracy_s0': 0.5794871794871794, 'accuracy_s1': 0.5122448979591837, 'classwise_accuracy': {0: array([ 85, 128]), 1: array([27, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 20, 1: 27, 5: 3, 2: 3, 4: 3}, 'class_pred_count_s1': {0: 89, 1: 25, 4: 10, 5: 3, 2: 1}, 'class_pred_count': {0: 109, 1: 52, 5: 6, 4: 13, 2: 4}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [74] Eval metrics for task 2 >> {'accuracy': 0.018292682926829267, 'loss': 0.0171724870800972, 'std': 0.018292682926829267, 'EER': -1, 'EO': [0.0, 0.0027472527472527514], 'DP': -1, 'accuracy_s0': 0.019230769230769232, 'accuracy_s1': 0.017857142857142856, 'classwise_accuracy': {3: array([ 0, 78]), 2: array([ 3, 82])}, 'DP_ingredients': {'class_pred_count_s0': {4: 21, 1: 20, 5: 17, 2: 4, 0: 8}, 'class_pred_count_s1': {5: 9, 0: 48, 4: 19, 1: 11, 2: 3}, 'class_pred_count': {5: 26, 4: 40, 1: 31, 0: 56, 2: 7}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [74] Eval metrics for task 3 >> {'accuracy': 0.39976345357776466, 'loss': 0.005418922987070169, 'std': 0.07392075694855113, 'EER': -1, 'EO': [0.06256384065372828, 0.010752688172043001], 'DP': -1, 'accuracy_s0': 0.40848133381660023, 'accuracy_s1': 0.38257575757575757, 'classwise_accuracy': {5: array([ 63, 133]), 4: array([29, 89])}, 'DP_ingredients': {'class_pred_count_s0': {4: 51, 5: 78, 1: 11, 0: 8, 2: 3}, 'class_pred_count_s1': {5: 30, 2: 5, 4: 23, 1: 5, 0: 8}, 'class_pred_count': {4: 74, 5: 108, 1: 16, 2: 8, 0: 16}, 'count_s0': 151, 'count_s1': 71, 'count': 222}}
# [74] Eval metrics for task 1 >> {'accuracy': 0.58203125, 'loss': 0.0056908934012703275, 'std': 0.08203125, 'EER': -1, 'EO': [0.2578231292517007, 0.43076923076923074], 'DP': -1, 'accuracy_s0': 0.5987179487179487, 'accuracy_s1': 0.5122448979591837, 'classwise_accuracy': {0: array([ 85, 128]), 1: array([28, 56])}, 'DP_ingredients': {'class_pred_count_s0': {4: 3, 1: 28, 5: 3, 0: 19, 2: 3}, 'class_pred_count_s1': {0: 89, 4: 10, 1: 25, 2: 1, 5: 3}, 'class_pred_count': {0: 108, 4: 13, 1: 53, 5: 6, 2: 4}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [74] Eval metrics for task 2 >> {'accuracy': 0.018292682926829267, 'loss': 0.01720753312110901, 'std': 0.018292682926829267, 'EER': -1, 'EO': [0.0, 0.0027472527472527514], 'DP': -1, 'accuracy_s0': 0.019230769230769232, 'accuracy_s1': 0.017857142857142856, 'classwise_accuracy': {3: array([ 0, 78]), 2: array([ 3, 82])}, 'DP_ingredients': {'class_pred_count_s0': {5: 18, 0: 8, 4: 20, 1: 20, 2: 4}, 'class_pred_count_s1': {4: 17, 0: 48, 5: 11, 1: 11, 2: 3}, 'class_pred_count': {5: 29, 4: 37, 0: 56, 1: 31, 2: 7}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [74] Eval metrics for task 3 >> {'accuracy': 0.4073244910027879, 'loss': 0.005409929129454467, 'std': 0.10395370448593391, 'EER': -1, 'EO': [0.010155316606929532, 0.0508171603677221], 'DP': -1, 'accuracy_s0': 0.4172707502718376, 'accuracy_s1': 0.3867845117845118, 'classwise_accuracy': {4: array([27, 89]), 5: array([ 68, 133])}, 'DP_ingredients': {'class_pred_count_s0': {4: 47, 0: 8, 5: 82, 2: 3, 1: 11}, 'class_pred_count_s1': {1: 5, 4: 20, 5: 33, 2: 5, 0: 8}, 'class_pred_count': {1: 16, 4: 67, 0: 16, 5: 115, 2: 8}, 'count_s0': 151, 'count_s1': 71, 'count': 222}}
# [75] Eval metrics for task 1 >> {'accuracy': 0.5909598214285714, 'loss': 0.005695113021394481, 'std': 0.07310267857142855, 'EER': -1, 'EO': [0.2578231292517007, 0.4692307692307693], 'DP': -1, 'accuracy_s0': 0.617948717948718, 'accuracy_s1': 0.5122448979591837, 'classwise_accuracy': {0: array([ 85, 128]), 1: array([29, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 18, 1: 29, 2: 3, 4: 3, 5: 3}, 'class_pred_count_s1': {0: 89, 4: 9, 1: 25, 5: 4, 2: 1}, 'class_pred_count': {0: 107, 4: 12, 1: 54, 5: 7, 2: 4}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [75] Eval metrics for task 2 >> {'accuracy': 0.018292682926829267, 'loss': 0.017272695899009705, 'std': 0.018292682926829267, 'EER': -1, 'EO': [0.0027472527472527514, 0.0], 'DP': -1, 'accuracy_s0': 0.019230769230769232, 'accuracy_s1': 0.017857142857142856, 'classwise_accuracy': {2: array([ 3, 82]), 3: array([ 0, 78])}, 'DP_ingredients': {'class_pred_count_s0': {4: 19, 2: 4, 1: 20, 5: 19, 0: 8}, 'class_pred_count_s1': {0: 48, 4: 17, 5: 11, 2: 3, 1: 11}, 'class_pred_count': {0: 56, 4: 36, 5: 30, 2: 7, 1: 31}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [75] Eval metrics for task 3 >> {'accuracy': 0.3998479344428487, 'loss': 0.005397677958548606, 'std': 0.11894905803835432, 'EER': -1, 'EO': [0.022102747909199527, 0.062053115423901906], 'DP': -1, 'accuracy_s0': 0.406759695541863, 'accuracy_s1': 0.3867845117845118, 'classwise_accuracy': {4: array([25, 89]), 5: array([ 69, 133])}, 'DP_ingredients': {'class_pred_count_s0': {5: 85, 0: 8, 4: 44, 1: 11, 2: 3}, 'class_pred_count_s1': {2: 5, 4: 20, 5: 33, 0: 8, 1: 5}, 'class_pred_count': {5: 118, 2: 8, 0: 16, 4: 64, 1: 16}, 'count_s0': 151, 'count_s1': 71, 'count': 222}}
# after select_coreset, num samples per label [32, 32]
# during update_coreset, num samples per label [0, 0]
# during update_coreset, num samples per label [0, 0]
# [75] Eval metrics for task 1 >> {'accuracy': 0.58203125, 'loss': 0.005704743058785149, 'std': 0.08203125, 'EER': -1, 'EO': [0.2578231292517007, 0.43076923076923074], 'DP': -1, 'accuracy_s0': 0.5987179487179487, 'accuracy_s1': 0.5122448979591837, 'classwise_accuracy': {0: array([ 85, 128]), 1: array([28, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 19, 1: 28, 4: 3, 2: 3, 5: 3}, 'class_pred_count_s1': {1: 25, 4: 11, 0: 89, 5: 2, 2: 1}, 'class_pred_count': {1: 53, 0: 108, 4: 14, 5: 5, 2: 4}, 'count_s0': 56, 'count_s1': 128, 'count': 184}}
# [75] Eval metrics for task 2 >> {'accuracy': 0.018292682926829267, 'loss': 0.01721634566783905, 'std': 0.018292682926829267, 'EER': -1, 'EO': [0.0, 0.0027472527472527514], 'DP': -1, 'accuracy_s0': 0.019230769230769232, 'accuracy_s1': 0.017857142857142856, 'classwise_accuracy': {3: array([ 0, 78]), 2: array([ 3, 82])}, 'DP_ingredients': {'class_pred_count_s0': {4: 21, 1: 20, 0: 8, 5: 17, 2: 4}, 'class_pred_count_s1': {5: 9, 2: 3, 0: 48, 4: 19, 1: 11}, 'class_pred_count': {5: 26, 2: 7, 4: 40, 0: 56, 1: 31}, 'count_s0': 70, 'count_s1': 90, 'count': 160}}
# [75] Eval metrics for task 3 >> {'accuracy': 0.4090985891695531, 'loss': 0.005426828925674026, 'std': 0.04954802737180028, 'EER': -1, 'EO': [0.07405515832482124, 0.015531660692950977], 'DP': -1, 'accuracy_s0': 0.41899238854657483, 'accuracy_s1': 0.3897306397306397, 'classwise_accuracy': {5: array([ 61, 133]), 4: array([32, 89])}, 'DP_ingredients': {'class_pred_count_s0': {4: 54, 5: 75, 0: 8, 1: 11, 2: 3}, 'class_pred_count_s1': {4: 25, 5: 28, 1: 6, 2: 5, 0: 7}, 'class_pred_count': {4: 79, 5: 103, 0: 15, 1: 17, 2: 8}, 'count_s0': 151, 'count_s1': 71, 'count': 222}}
# training_task_end
# final avg-acc 0.3364741740321275
# final avg-forget 0.19590368980612882

# %%
metric_manager_callback.meters['accuracy'].get_data()
# Out:
# array([[0.525, 0.   , 0.   ],
#        [0.402, 0.41 , 0.   ],
#        [0.582, 0.018, 0.409]])

# %%
np.mean(metric_manager_callback.meters['accuracy'].compute_overall())
# Out:
# 0.4225095565291284

# %%
[np.round(x, 3) for x in metric_manager_callback.meters['EO'].compute_overall()]
# Out:
# [0.1, 0.164, 0.13]

# %%
np.mean(metric_manager_callback.meters['EO'].compute_overall())
# Out:
# 0.1313845179693842

# %%
[np.round(x, 3) for x in metric_manager_callback.meters['DP'].compute_overall()]
# Out:
# [0.047, 0.066, 0.076]

# %%
np.mean(metric_manager_callback.meters['DP'].compute_overall())
# Out:
# 0.0630438122558262
