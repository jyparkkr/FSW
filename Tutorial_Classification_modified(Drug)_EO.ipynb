# %%
import numpy as np
import random

import torch
import torch.nn.functional as F
import cl_gym as cl

import sys
import os

seed = 0

np.random.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.cuda.manual_seed_all(seed)
torch.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.enabled = False
torch.set_num_threads(8)


def make_params() -> dict:
    import os
    from pathlib import Path
    import uuid

    params = {
            # dataset
            'dataset': "Drug",
            'fairness_agg': 'mean',
            # 'dataset': "FashionMNIST",
            'random_class_idx': False,

            # benchmark
            'seed': seed,
            'num_tasks': 3,
            'epochs_per_task': 25,
            'per_task_examples': np.inf,
            # 'per_task_examples': 10000,
            'per_task_memory_examples': 64,
            'batch_size_train': 64,
            'batch_size_memory': 64,
            'batch_size_validation': 256,
            'tau': 10.0,
            # 'tau': 0.0,

            # algorithm
            'optimizer': 'sgd',
            'learning_rate': 0.001,
            'momentum': 0.9,
            'learning_rate_decay': 1.0,
            'criterion': torch.nn.CrossEntropyLoss(),
            'device': torch.device('cuda:6' if torch.cuda.is_available() else 'cpu'),
             
            # sample selection
            'alpha':0.02,
            'metric' : "EO",
            'lambda': 1.,
            'lambda_old': 0.0,
              }

#     trial_id = str(uuid.uuid4())
    trial_id = f"demo/dataset={params['dataset']}/seed={params['seed']}_epoch={params['epochs_per_task']}_lr={params['learning_rate']}_alpha={params['alpha']}_tau={params['tau']}"
    params['trial_id'] = trial_id
    params['output_dir'] = os.path.join("./outputs/{}".format(trial_id))
    print(f"output_dir={params['output_dir']}")
    Path(params['output_dir']).mkdir(parents=True, exist_ok=True)

    return params

params = make_params()
# Out:
# output_dir=./outputs/demo/dataset=Drug/seed=0_epoch=25_lr=0.001_alpha=0.02_tau=10.0

# %%
from datasets import MNIST
from datasets import FashionMNIST
from datasets import CIFAR10, CIFAR100
from datasets.drug import Drug

if params['dataset'] == 'MNIST':
    benchmark = MNIST(num_tasks=params['num_tasks'],
                    per_task_memory_examples=params['per_task_memory_examples'],
                    per_task_examples = params['per_task_examples'],
                    random_class_idx = params['random_class_idx'])
    input_dim = (28, 28)
elif params['dataset'] == 'FashionMNIST':
    benchmark = FashionMNIST(num_tasks=params['num_tasks'],
                            per_task_memory_examples=params['per_task_memory_examples'],
                            per_task_examples = params['per_task_examples'],
                            random_class_idx = params['random_class_idx'])
    input_dim = (28, 28)
elif params['dataset'] == 'CIFAR10':
    benchmark = CIFAR10(num_tasks=params['num_tasks'],
                        per_task_memory_examples=params['per_task_memory_examples'],
                        per_task_examples = params['per_task_examples'],
                        random_class_idx = params['random_class_idx'])
    input_dim = (3, 32, 32)
elif params['dataset'] == 'CIFAR100':        
    benchmark = CIFAR100(num_tasks=params['num_tasks'],
                        per_task_memory_examples=params['per_task_memory_examples'],
                        per_task_examples = params['per_task_examples'],
                        random_class_idx = params['random_class_idx'])
    input_dim = (3, 32, 32)
elif params['dataset'] == 'Drug':        
    benchmark = Drug(num_tasks=params['num_tasks'],
                        per_task_memory_examples=params['per_task_memory_examples'],
                        per_task_examples = params['per_task_examples'],
                        joint = params['random_class_idx'],
                        random_class_idx = params['random_class_idx'])
    input_dim = (12)
else:
    raise NotImplementedError
class_idx = benchmark.class_idx
num_classes = len(class_idx)

# %%
from algorithms.imbalance import Heuristic2
from algorithms.sensitive import Heuristic3
from metrics import FairMetricCollector
from backbones import MLP2Layers2

backbone = MLP2Layers2(
    input_dim=input_dim, 
    hidden_dim_1=256, 
    hidden_dim_2=256, 
    output_dim=num_classes,
    class_idx=class_idx,
    config=params
    ).to(params['device'])
algorithm = Heuristic3(backbone, benchmark, params, requires_memory=True)
metric_manager_callback = FairMetricCollector(num_tasks=params['num_tasks'],
                                                        eval_interval='epoch',
                                                        epochs_per_task=params['epochs_per_task'])

# %%
# from trainers import ContinualTrainer
from trainers.fair_trainer import FairContinualTrainer2 as ContinualTrainer
# from trainers.imbalance_trainer import ImbalanceContinualTrainer1 as ContinualTrainer

trainer = ContinualTrainer(algorithm, params, callbacks=[metric_manager_callback])

# %%
if params['fairness_agg'] == "mean":
    agg = np.mean
elif params['fairness_agg'] == "max":
    agg = np.max
else:
    raise NotImplementedError

fairness_metrics = ["std", "EER", "EO", "DP"]
for metric in metric_manager_callback.meters:
    if metric in fairness_metrics:
        metric_manager_callback.meters[metric].agg = agg

# %%
trainer.run()
print("final avg-acc", metric_manager_callback.meters['accuracy'].compute_final())
print("final avg-forget", metric_manager_callback.meters['forgetting'].compute_final())
# Out:
# ---------------------------- Task 1 -----------------------
# [1] Eval metrics for task 1 >> {'accuracy': 0.056910569105691054, 'loss': 0.009496929719276036, 'std': 0.056910569105691054, 'EER': -1, 'EO': [0.08383458646616541, 0.0], 'DP': -1, 'accuracy_s0': 0.08928571428571429, 'accuracy_s1': 0.04736842105263158, 'classwise_accuracy': {0: array([ 14, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {5: 37, 0: 13, 2: 11, 3: 1}, 'class_pred_count_s1': {5: 63, 3: 27, 0: 15, 2: 27}, 'class_pred_count': {5: 100, 3: 28, 0: 28, 2: 38}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [2] Eval metrics for task 1 >> {'accuracy': 0.483739837398374, 'loss': 0.008856236934661865, 'std': 0.483739837398374, 'EER': -1, 'EO': [0.04210526315789476, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.4789473684210526, 'classwise_accuracy': {0: array([119, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 61, 5: 1}, 'class_pred_count_s1': {0: 126, 2: 3, 5: 3}, 'class_pred_count': {0: 187, 2: 3, 5: 4}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [3] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.008154714230409603, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [4] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.007482933629419386, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [5] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.00686134812758141, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [6] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.00630659540903937, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [7] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.005834129667773689, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [8] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.00544821663001149, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [9] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.005143452550947052, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 71]), 0: array([123, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [10] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.004898922959553827, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [11] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.004697071830021967, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [12] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.004519783651705869, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [13] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.004360883199062544, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 71]), 0: array([123, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [14] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.004211365254883913, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [15] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.004087299415745686, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 71]), 0: array([123, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [16] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.003980454095860117, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [17] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.003888291181977262, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [18] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0038164506867988824, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [19] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0037566444922968283, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [20] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0037032998714250386, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 71]), 0: array([123, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [21] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0036618734143443942, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 71]), 0: array([123, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [22] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0036313739634051766, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [23] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.00359865377858742, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 71]), 0: array([123, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [24] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0035736911075631367, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [25] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0035425396924166335, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# training_task_end
# ---------------------------- Task 2 -----------------------
# Elapsed time(grad):0.894
# losses=tensor([[0.4451, 1.0513, 4.0891, 3.8365, 0.3538, 1.2085, 4.3937, 4.0660]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.326
# Fairness:[-0.01089941  0.01352124  0.03238826  0.02365466]
# Current class expected loss:[ 0.          0.         -0.07569019 -0.11701846]
# len(updated_seq_indices)=338
# [26] Eval metrics for task 1 >> {'accuracy': 0.594354746364365, 'loss': 0.003875571120645582, 'std': 0.2366311691285927, 'EER': -1, 'EO': [0.2319548872180451, 0.15500794912559612], 'DP': -1, 'accuracy_s0': 0.5451680672268907, 'accuracy_s1': 0.5836415362731152, 'classwise_accuracy': {0: array([ 44, 123]), 1: array([59, 71])}, 'DP_ingredients': {'class_pred_count_s0': {1: 54, 0: 8}, 'class_pred_count_s1': {1: 84, 0: 48}, 'class_pred_count': {1: 138, 0: 56}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [26] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.02827258590314028, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {1: 54, 0: 6}, 'class_pred_count_s1': {1: 55, 0: 24}, 'class_pred_count': {1: 109, 0: 30}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.683
# losses=tensor([[0.8993, 0.5358, 3.8016, 3.5969, 0.7375, 0.6501, 4.0371, 3.7747]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.165
# Fairness:[-0.0184047   0.00292804  0.02551996  0.01964932]
# Current class expected loss:[ 0.          0.          0.         -0.05963533]
# len(updated_seq_indices)=338
# [27] Eval metrics for task 1 >> {'accuracy': 0.5916638039619833, 'loss': 0.003900358357380346, 'std': 0.16889957631970684, 'EER': -1, 'EO': [0.1208267090620031, 0.31616541353383454], 'DP': -1, 'accuracy_s0': 0.5010504201680672, 'accuracy_s1': 0.598719772403983, 'classwise_accuracy': {1: array([54, 71]), 0: array([ 52, 123])}, 'DP_ingredients': {'class_pred_count_s0': {1: 51, 0: 11}, 'class_pred_count_s1': {1: 74, 0: 58}, 'class_pred_count': {1: 125, 0: 69}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [27] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.025410909446880972, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {3: array([ 0, 56]), 2: array([ 0, 83])}, 'DP_ingredients': {'class_pred_count_s0': {1: 51, 0: 9}, 'class_pred_count_s1': {0: 31, 1: 48}, 'class_pred_count': {0: 40, 1: 99}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.702
# losses=tensor([[0.8808, 0.5261, 3.4123, 3.2621, 0.6984, 0.6867, 3.6119, 3.4137]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.134
# Fairness:[-0.01871847  0.00410503  0.01720958  0.01536147]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [28] Eval metrics for task 1 >> {'accuracy': 0.6088400320622924, 'loss': 0.0037055021708773585, 'std': 0.2285583419214474, 'EER': -1, 'EO': [0.020676691729323293, 0.2861685214626391], 'DP': -1, 'accuracy_s0': 0.6754201680672269, 'accuracy_s1': 0.542674253200569, 'classwise_accuracy': {0: array([103, 123]), 1: array([27, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 39, 1: 23}, 'class_pred_count_s1': {0: 108, 1: 24}, 'class_pred_count': {0: 147, 1: 47}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [28] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.02348291788169806, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 36, 1: 24}, 'class_pred_count_s1': {0: 57, 1: 22}, 'class_pred_count': {0: 93, 1: 46}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.702
# losses=tensor([[0.6519, 0.6814, 3.1295, 3.0305, 0.4914, 0.9428, 3.3296, 3.1841]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.14
# Fairness:[-0.01207     0.01490882  0.01225739  0.01258046]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [29] Eval metrics for task 1 >> {'accuracy': 0.6012252376044888, 'loss': 0.0037820179437853627, 'std': 0.12235199816786904, 'EER': -1, 'EO': [0.26629570747217807, 0.1507518796992482], 'DP': -1, 'accuracy_s0': 0.6123949579831933, 'accuracy_s1': 0.5546230440967284, 'classwise_accuracy': {1: array([34, 71]), 0: array([ 89, 123])}, 'DP_ingredients': {'class_pred_count_s0': {1: 32, 0: 30}, 'class_pred_count_s1': {0: 96, 1: 36}, 'class_pred_count': {0: 126, 1: 68}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [29] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.022279802843821136, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 32, 1: 28}, 'class_pred_count_s1': {1: 33, 0: 46}, 'class_pred_count': {1: 61, 0: 78}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.693
# losses=tensor([[0.7064, 0.5787, 2.9868, 2.8906, 0.5227, 0.8745, 3.1488, 3.0271]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.14
# Fairness:[-0.01176126  0.0150388   0.00636734  0.01023319]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [30] Eval metrics for task 1 >> {'accuracy': 0.6133631054620405, 'loss': 0.003942736645334775, 'std': 0.07677773960838197, 'EER': -1, 'EO': [0.2323308270676691, 0.19952305246422886], 'DP': -1, 'accuracy_s0': 0.5756302521008403, 'accuracy_s1': 0.5920341394025604, 'classwise_accuracy': {0: array([ 66, 123]), 1: array([49, 71])}, 'DP_ingredients': {'class_pred_count_s0': {1: 45, 0: 17}, 'class_pred_count_s1': {0: 71, 1: 61}, 'class_pred_count': {1: 106, 0: 88}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [30] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.021761597489281526, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {3: array([ 0, 56]), 2: array([ 0, 83])}, 'DP_ingredients': {'class_pred_count_s0': {1: 43, 0: 17}, 'class_pred_count_s1': {1: 42, 0: 37}, 'class_pred_count': {1: 85, 0: 54}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.703
# losses=tensor([[0.8249, 0.4358, 2.9555, 2.8312, 0.6060, 0.7326, 3.0698, 2.9475]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.14
# Fairness:[-0.01454396  0.01021811  0.00127217  0.00873149]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [31] Eval metrics for task 1 >> {'accuracy': 0.615538761021413, 'loss': 0.0038557098698370237, 'std': 0.04643306996450247, 'EER': -1, 'EO': [0.2535771065182829, 0.18195488721804515], 'DP': -1, 'accuracy_s0': 0.611344537815126, 'accuracy_s1': 0.5755334281650071, 'classwise_accuracy': {1: array([47, 71]), 0: array([ 70, 123])}, 'DP_ingredients': {'class_pred_count_s0': {1: 43, 0: 19}, 'class_pred_count_s1': {1: 57, 0: 75}, 'class_pred_count': {1: 100, 0: 94}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [31] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.021668876675393085, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 26, 1: 34}, 'class_pred_count_s1': {0: 40, 1: 39}, 'class_pred_count': {0: 66, 1: 73}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.75
# losses=tensor([[0.7341, 0.4332, 2.9584, 2.8034, 0.5347, 0.7832, 3.0653, 2.9245]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.142
# Fairness:[-0.00976806  0.01582257  0.          0.00900923]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [32] Eval metrics for task 1 >> {'accuracy': 0.6028283522271842, 'loss': 0.003778173751437787, 'std': 0.03944807053704341, 'EER': -1, 'EO': [0.10413354531001595, 0.1842105263157895], 'DP': -1, 'accuracy_s0': 0.5588235294117647, 'accuracy_s1': 0.5988620199146515, 'classwise_accuracy': {1: array([40, 71]), 0: array([ 79, 123])}, 'DP_ingredients': {'class_pred_count_s0': {1: 35, 0: 27}, 'class_pred_count_s1': {0: 83, 1: 49}, 'class_pred_count': {0: 110, 1: 84}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [32] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.021707387279263503, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {3: array([ 0, 56]), 2: array([ 0, 83])}, 'DP_ingredients': {'class_pred_count_s0': {1: 28, 0: 32}, 'class_pred_count_s1': {1: 35, 0: 44}, 'class_pred_count': {1: 63, 0: 76}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.72
# losses=tensor([[0.6296, 0.4496, 2.9767, 2.7844, 0.4650, 0.8479, 3.0830, 2.9138]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.171
# Fairness:[-0.00395265  0.02247999  0.          0.00981356]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [33] Eval metrics for task 1 >> {'accuracy': 0.6084965075002863, 'loss': 0.0038643522360890183, 'std': 0.03939081644337572, 'EER': -1, 'EO': [0.18195488721804515, 0.16772655007949133], 'DP': -1, 'accuracy_s0': 0.5819327731092437, 'accuracy_s1': 0.5890469416785207, 'classwise_accuracy': {0: array([ 70, 123]), 1: array([46, 71])}, 'DP_ingredients': {'class_pred_count_s0': {1: 41, 0: 21}, 'class_pred_count_s1': {1: 58, 0: 74}, 'class_pred_count': {1: 99, 0: 95}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [33] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.021612542996303642, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {1: 32, 0: 28}, 'class_pred_count_s1': {1: 37, 0: 42}, 'class_pred_count': {1: 69, 0: 70}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.68
# losses=tensor([[0.6516, 0.3858, 2.9993, 2.7661, 0.5000, 0.7621, 3.0731, 2.8842]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.145
# Fairness:[-0.00314074  0.017748    0.          0.00981211]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [34] Eval metrics for task 1 >> {'accuracy': 0.58925913202794, 'loss': 0.003923562998624192, 'std': 0.04454368487346849, 'EER': -1, 'EO': [0.13831478537360897, 0.1503759398496241], 'DP': -1, 'accuracy_s0': 0.5672268907563025, 'accuracy_s1': 0.5732574679943101, 'classwise_accuracy': {1: array([45, 71]), 0: array([ 67, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 22, 1: 40}, 'class_pred_count_s1': {0: 71, 1: 61}, 'class_pred_count': {0: 93, 1: 101}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [34] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.021359033721814052, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {1: 31, 0: 29}, 'class_pred_count_s1': {0: 41, 1: 38}, 'class_pred_count': {1: 69, 0: 70}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.891
# losses=tensor([[0.6292, 0.3643, 2.9864, 2.7220, 0.5095, 0.7225, 3.0433, 2.8343]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.142
# Fairness:[-1.68257313e-04  1.57077641e-02  8.67361738e-19  9.48635770e-03]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [35] Eval metrics for task 1 >> {'accuracy': 0.5762624527653728, 'loss': 0.0039109916416640135, 'std': 0.01528684300927513, 'EER': -1, 'EO': [0.050079491255961894, 0.12518796992481196], 'DP': -1, 'accuracy_s0': 0.5409663865546219, 'accuracy_s1': 0.578520625889047, 'classwise_accuracy': {1: array([42, 71]), 0: array([ 69, 123])}, 'DP_ingredients': {'class_pred_count_s0': {1: 36, 0: 26}, 'class_pred_count_s1': {0: 72, 1: 60}, 'class_pred_count': {0: 98, 1: 96}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [35] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.021009436614221805, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {1: 26, 0: 34}, 'class_pred_count_s1': {0: 44, 1: 35}, 'class_pred_count': {0: 78, 1: 61}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):1.029
# losses=tensor([[0.5513, 0.3879, 2.9418, 2.6648, 0.4762, 0.7434, 2.9962, 2.7781]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.166
# Fairness:[0.00392248 0.01810884 0.         0.00916862]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [36] Eval metrics for task 1 >> {'accuracy': 0.5721974121149662, 'loss': 0.003988040783970626, 'std': 0.019351883659681657, 'EER': -1, 'EO': [0.11466165413533835, 0.050079491255961894], 'DP': -1, 'accuracy_s0': 0.5409663865546219, 'accuracy_s1': 0.5732574679943101, 'classwise_accuracy': {0: array([ 68, 123]), 1: array([42, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 26, 1: 36}, 'class_pred_count_s1': {0: 71, 1: 61}, 'class_pred_count': {0: 97, 1: 97}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [36] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.020662503276797507, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 35, 1: 25}, 'class_pred_count_s1': {0: 45, 1: 34}, 'class_pred_count': {0: 80, 1: 59}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.785
# losses=tensor([[0.5374, 0.3707, 2.9068, 2.6105, 0.4910, 0.6937, 2.9499, 2.7188]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.168
# Fairness:[0.00639058 0.01457655 0.         0.00888332]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [37] Eval metrics for task 1 >> {'accuracy': 0.5559372495133402, 'loss': 0.004062549969584672, 'std': 0.03561204626130765, 'EER': -1, 'EO': [0.050079491255961894, 0.0725563909774436], 'DP': -1, 'accuracy_s0': 0.5409663865546219, 'accuracy_s1': 0.5522048364153627, 'classwise_accuracy': {1: array([42, 71]), 0: array([ 64, 123])}, 'DP_ingredients': {'class_pred_count_s0': {1: 36, 0: 26}, 'class_pred_count_s1': {0: 67, 1: 65}, 'class_pred_count': {0: 93, 1: 101}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [37] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.02038005959215782, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 34, 1: 26}, 'class_pred_count_s1': {0: 45, 1: 34}, 'class_pred_count': {0: 79, 1: 60}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.891
# losses=tensor([[0.5211, 0.3556, 2.8743, 2.5679, 0.5000, 0.6507, 2.9098, 2.6735]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.136
# Fairness:[0.00879068 0.01168885 0.         0.00863864]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [38] Eval metrics for task 1 >> {'accuracy': 0.5581129050727127, 'loss': 0.004074520364250105, 'std': 0.0052673766174281544, 'EER': -1, 'EO': [0.06842105263157894, 0.04769475357710651], 'DP': -1, 'accuracy_s0': 0.5441176470588236, 'accuracy_s1': 0.5544807965860598, 'classwise_accuracy': {0: array([ 68, 123]), 1: array([40, 71])}, 'DP_ingredients': {'class_pred_count_s0': {1: 34, 0: 28}, 'class_pred_count_s1': {0: 71, 1: 61}, 'class_pred_count': {0: 99, 1: 95}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [38] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.020197070759835, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {3: array([ 0, 56]), 2: array([ 0, 83])}, 'DP_ingredients': {'class_pred_count_s0': {0: 36, 1: 24}, 'class_pred_count_s1': {0: 48, 1: 31}, 'class_pred_count': {0: 84, 1: 55}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.752
# losses=tensor([[0.4694, 0.3659, 2.8508, 2.5258, 0.4735, 0.6493, 2.8881, 2.6342]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.144
# Fairness:[0.01141824 0.01198032 0.         0.0088067 ]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [39] Eval metrics for task 1 >> {'accuracy': 0.5681323714645596, 'loss': 0.0041469833285538195, 'std': 0.023416924310088183, 'EER': -1, 'EO': [0.05789473684210522, 0.10651828298887123], 'DP': -1, 'accuracy_s0': 0.5735294117647058, 'accuracy_s1': 0.5492176386913229, 'classwise_accuracy': {0: array([ 67, 123]), 1: array([42, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 26, 1: 36}, 'class_pred_count_s1': {1: 62, 0: 70}, 'class_pred_count': {1: 98, 0: 96}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [39] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.020021857117577424, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 35, 1: 25}, 'class_pred_count_s1': {0: 48, 1: 31}, 'class_pred_count': {0: 83, 1: 56}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.758
# losses=tensor([[0.4530, 0.3505, 2.8350, 2.4853, 0.4749, 0.6099, 2.8705, 2.5935]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.138
# Fairness:[0.01316804 0.00941864 0.         0.00859682]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [40] Eval metrics for task 1 >> {'accuracy': 0.5751746249856864, 'loss': 0.004210435852562029, 'std': 0.030459177831214934, 'EER': -1, 'EO': [0.05789473684210522, 0.07949125596184425], 'DP': -1, 'accuracy_s0': 0.5735294117647058, 'accuracy_s1': 0.5627311522048364, 'classwise_accuracy': {0: array([ 67, 123]), 1: array([43, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 26, 1: 36}, 'class_pred_count_s1': {1: 63, 0: 69}, 'class_pred_count': {1: 99, 0: 95}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [40] Eval metrics for task 2 >> {'accuracy': 0.008928571428571428, 'loss': 0.019872519609739455, 'std': 0.008928571428571428, 'EER': -1, 'EO': [0.034482758620689655, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.017241379310344827, 'classwise_accuracy': {3: array([ 1, 56]), 2: array([ 0, 83])}, 'DP_ingredients': {'class_pred_count_s0': {0: 37, 1: 23}, 'class_pred_count_s1': {0: 47, 1: 31, 3: 1}, 'class_pred_count': {0: 84, 1: 54, 3: 1}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.751
# losses=tensor([[0.4311, 0.3398, 2.8226, 2.4452, 0.4680, 0.5803, 2.8581, 2.5540]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.157
# Fairness:[0.01481117 0.00763602 0.         0.00843316]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [41] Eval metrics for task 1 >> {'accuracy': 0.5751746249856864, 'loss': 0.004260634638599514, 'std': 0.030459177831214934, 'EER': -1, 'EO': [0.011654135338345917, 0.07949125596184425], 'DP': -1, 'accuracy_s0': 0.5913865546218487, 'accuracy_s1': 0.5574679943100995, 'classwise_accuracy': {0: array([ 67, 123]), 1: array([43, 71])}, 'DP_ingredients': {'class_pred_count_s0': {1: 35, 0: 27}, 'class_pred_count_s1': {1: 64, 0: 68}, 'class_pred_count': {1: 99, 0: 95}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [41] Eval metrics for task 2 >> {'accuracy': 0.008928571428571428, 'loss': 0.019720254184530793, 'std': 0.008928571428571428, 'EER': -1, 'EO': [0.0, 0.034482758620689655], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.017241379310344827, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 1, 56])}, 'DP_ingredients': {'class_pred_count_s0': {1: 23, 0: 37}, 'class_pred_count_s1': {0: 48, 1: 30, 3: 1}, 'class_pred_count': {1: 53, 0: 85, 3: 1}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.991
# losses=tensor([[0.4007, 0.3362, 2.8036, 2.4122, 0.4507, 0.5633, 2.8392, 2.5222]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.18
# Fairness:[0.01635284 0.00682493 0.         0.00832017]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [42] Eval metrics for task 1 >> {'accuracy': 0.579239665636093, 'loss': 0.004345027441830979, 'std': 0.026394137180808408, 'EER': -1, 'EO': [0.07949125596184425, 0.022180451127819523], 'DP': -1, 'accuracy_s0': 0.5913865546218487, 'accuracy_s1': 0.5627311522048364, 'classwise_accuracy': {1: array([43, 71]), 0: array([ 68, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 27, 1: 35}, 'class_pred_count_s1': {0: 69, 1: 63}, 'class_pred_count': {0: 96, 1: 98}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [42] Eval metrics for task 2 >> {'accuracy': 0.008928571428571428, 'loss': 0.01949171025118382, 'std': 0.008928571428571428, 'EER': -1, 'EO': [0.0, 0.034482758620689655], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.017241379310344827, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 1, 56])}, 'DP_ingredients': {'class_pred_count_s0': {1: 23, 0: 37}, 'class_pred_count_s1': {1: 30, 0: 47, 3: 2}, 'class_pred_count': {1: 53, 0: 84, 3: 2}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.736
# losses=tensor([[0.3842, 0.3228, 2.7726, 2.3777, 0.4454, 0.5335, 2.8072, 2.4875]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.147
# Fairness:[0.01768344 0.00502793 0.         0.00797425]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [43] Eval metrics for task 1 >> {'accuracy': 0.57110958433528, 'loss': 0.00442660162129353, 'std': 0.034524218481621405, 'EER': -1, 'EO': [0.0011278195488721998, 0.07949125596184425], 'DP': -1, 'accuracy_s0': 0.5913865546218487, 'accuracy_s1': 0.5522048364153627, 'classwise_accuracy': {0: array([ 66, 123]), 1: array([43, 71])}, 'DP_ingredients': {'class_pred_count_s0': {1: 35, 0: 27}, 'class_pred_count_s1': {0: 67, 1: 65}, 'class_pred_count': {0: 94, 1: 100}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [43] Eval metrics for task 2 >> {'accuracy': 0.017857142857142856, 'loss': 0.019248099635830886, 'std': 0.017857142857142856, 'EER': -1, 'EO': [0.06896551724137931, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.034482758620689655, 'classwise_accuracy': {3: array([ 2, 56]), 2: array([ 0, 83])}, 'DP_ingredients': {'class_pred_count_s0': {0: 39, 1: 21}, 'class_pred_count_s1': {0: 44, 3: 3, 1: 32}, 'class_pred_count': {0: 83, 3: 3, 1: 53}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.948
# losses=tensor([[0.3630, 0.3135, 2.7401, 2.3434, 0.4353, 0.5106, 2.7708, 2.4515]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.146
# Fairness:[0.01912569 0.00374274 0.         0.0076035 ]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [44] Eval metrics for task 1 >> {'accuracy': 0.5721974121149662, 'loss': 0.0045044366846379545, 'std': 0.019351883659681657, 'EER': -1, 'EO': [0.0703007518796992, 0.050079491255961894], 'DP': -1, 'accuracy_s0': 0.6123949579831933, 'accuracy_s1': 0.5522048364153627, 'classwise_accuracy': {0: array([ 68, 123]), 1: array([42, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 30, 1: 32}, 'class_pred_count_s1': {0: 67, 1: 65}, 'class_pred_count': {0: 97, 1: 97}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [44] Eval metrics for task 2 >> {'accuracy': 0.017857142857142856, 'loss': 0.01906128581479299, 'std': 0.017857142857142856, 'EER': -1, 'EO': [0.06896551724137931, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.034482758620689655, 'classwise_accuracy': {3: array([ 2, 56]), 2: array([ 0, 83])}, 'DP_ingredients': {'class_pred_count_s0': {0: 42, 1: 18}, 'class_pred_count_s1': {0: 43, 1: 32, 3: 4}, 'class_pred_count': {0: 85, 1: 50, 3: 4}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.722
# losses=tensor([[0.3396, 0.3048, 2.7182, 2.3129, 0.4222, 0.4907, 2.7450, 2.4179]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.171
# Fairness:[ 2.04932687e-02  2.80583922e-03 -4.33680869e-19  7.04698199e-03]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [45] Eval metrics for task 1 >> {'accuracy': 0.5640673308141533, 'loss': 0.004593611070790242, 'std': 0.027481964960494654, 'EER': -1, 'EO': [0.050079491255961894, 0.09135338345864652], 'DP': -1, 'accuracy_s0': 0.6123949579831933, 'accuracy_s1': 0.5416785206258891, 'classwise_accuracy': {1: array([42, 71]), 0: array([ 66, 123])}, 'DP_ingredients': {'class_pred_count_s0': {1: 32, 0: 30}, 'class_pred_count_s1': {1: 67, 0: 65}, 'class_pred_count': {1: 99, 0: 95}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [45] Eval metrics for task 2 >> {'accuracy': 0.026785714285714284, 'loss': 0.018862923272222065, 'std': 0.026785714285714284, 'EER': -1, 'EO': [0.031928480204342274, 0.0], 'DP': -1, 'accuracy_s0': 0.018518518518518517, 'accuracy_s1': 0.034482758620689655, 'classwise_accuracy': {3: array([ 3, 56]), 2: array([ 0, 83])}, 'DP_ingredients': {'class_pred_count_s0': {0: 43, 1: 16, 3: 1}, 'class_pred_count_s1': {3: 4, 0: 43, 1: 32}, 'class_pred_count': {3: 5, 0: 86, 1: 48}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.716
# losses=tensor([[0.3194, 0.2935, 2.6941, 2.2804, 0.4122, 0.4683, 2.7186, 2.3829]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.168
# Fairness:[0.02164415 0.00149284 0.         0.00649337]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [46] Eval metrics for task 1 >> {'accuracy': 0.5681323714645596, 'loss': 0.004683862949155041, 'std': 0.023416924310088183, 'EER': -1, 'EO': [0.12706766917293233, 0.006359300476947549], 'DP': -1, 'accuracy_s0': 0.615546218487395, 'accuracy_s1': 0.5551920341394025, 'classwise_accuracy': {0: array([ 67, 123]), 1: array([42, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 32, 1: 30}, 'class_pred_count_s1': {0: 64, 1: 68}, 'class_pred_count': {0: 96, 1: 98}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [46] Eval metrics for task 2 >> {'accuracy': 0.026785714285714284, 'loss': 0.01874841202934869, 'std': 0.026785714285714284, 'EER': -1, 'EO': [0.0, 0.031928480204342274], 'DP': -1, 'accuracy_s0': 0.018518518518518517, 'accuracy_s1': 0.034482758620689655, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 3, 56])}, 'DP_ingredients': {'class_pred_count_s0': {1: 16, 0: 43, 3: 1}, 'class_pred_count_s1': {0: 44, 1: 31, 3: 4}, 'class_pred_count': {1: 47, 0: 87, 3: 5}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.934
# losses=tensor([[0.3016, 0.2788, 2.6775, 2.2633, 0.4019, 0.4441, 2.7014, 2.3630]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.149
# Fairness:[0.02235904 0.00017055 0.         0.00607395]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [47] Eval metrics for task 1 >> {'accuracy': 0.5640673308141533, 'loss': 0.004769257970691956, 'std': 0.027481964960494654, 'EER': -1, 'EO': [0.13759398496240605, 0.006359300476947549], 'DP': -1, 'accuracy_s0': 0.615546218487395, 'accuracy_s1': 0.5499288762446657, 'classwise_accuracy': {0: array([ 66, 123]), 1: array([42, 71])}, 'DP_ingredients': {'class_pred_count_s0': {1: 30, 0: 32}, 'class_pred_count_s1': {0: 63, 1: 68, 3: 1}, 'class_pred_count': {0: 95, 1: 98, 3: 1}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [47] Eval metrics for task 2 >> {'accuracy': 0.026785714285714284, 'loss': 0.01864030206803795, 'std': 0.026785714285714284, 'EER': -1, 'EO': [0.0, 0.031928480204342274], 'DP': -1, 'accuracy_s0': 0.018518518518518517, 'accuracy_s1': 0.034482758620689655, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 3, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 43, 1: 16, 3: 1}, 'class_pred_count_s1': {3: 5, 0: 43, 1: 31}, 'class_pred_count': {0: 86, 3: 6, 1: 47}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.961
# losses=tensor([[0.2813, 0.2670, 2.6646, 2.2434, 0.3870, 0.4248, 2.6868, 2.3403]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.175
# Fairness:[0.02282197 0.         0.         0.00587038]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [48] Eval metrics for task 1 >> {'accuracy': 0.5822168785068131, 'loss': 0.004871640930470732, 'std': 0.037501431352341685, 'EER': -1, 'EO': [0.060413354531001606, 0.12706766917293233], 'DP': -1, 'accuracy_s0': 0.615546218487395, 'accuracy_s1': 0.5822190611664296, 'classwise_accuracy': {1: array([44, 71]), 0: array([ 67, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 32, 1: 30}, 'class_pred_count_s1': {1: 69, 0: 62, 3: 1}, 'class_pred_count': {0: 94, 1: 99, 3: 1}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [48] Eval metrics for task 2 >> {'accuracy': 0.03571428571428571, 'loss': 0.018493998822548405, 'std': 0.03571428571428571, 'EER': -1, 'EO': [0.0, 0.005108556832694761], 'DP': -1, 'accuracy_s0': 0.037037037037037035, 'accuracy_s1': 0.034482758620689655, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 4, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 42, 1: 16, 3: 2}, 'class_pred_count_s1': {1: 30, 0: 43, 3: 6}, 'class_pred_count': {1: 46, 0: 85, 3: 8}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):1.033
# losses=tensor([[0.2668, 0.2512, 2.6436, 2.2224, 0.3764, 0.4022, 2.6655, 2.3161]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.151
# Fairness:[ 0.02347205 -0.00071735  0.          0.00587955]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [49] Eval metrics for task 1 >> {'accuracy': 0.5862819191572197, 'loss': 0.00496836206347672, 'std': 0.03343639070193516, 'EER': -1, 'EO': [0.11654135338345872, 0.060413354531001606], 'DP': -1, 'accuracy_s0': 0.615546218487395, 'accuracy_s1': 0.5874822190611664, 'classwise_accuracy': {0: array([ 68, 123]), 1: array([44, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 32, 1: 30}, 'class_pred_count_s1': {1: 68, 0: 63, 3: 1}, 'class_pred_count': {1: 98, 0: 95, 3: 1}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [49] Eval metrics for task 2 >> {'accuracy': 0.05357142857142857, 'loss': 0.01840517675276283, 'std': 0.05357142857142857, 'EER': -1, 'EO': [0.0, 0.007662835249042141], 'DP': -1, 'accuracy_s0': 0.05555555555555555, 'accuracy_s1': 0.05172413793103448, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 6, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 41, 1: 16, 3: 3}, 'class_pred_count_s1': {0: 43, 1: 29, 3: 7}, 'class_pred_count': {0: 84, 1: 45, 3: 10}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):1.019
# losses=tensor([[0.2511, 0.2363, 2.6341, 2.2042, 0.3624, 0.3827, 2.6551, 2.2956]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.144
# Fairness:[ 0.02410349 -0.00193985  0.          0.00549815]
# Current class expected loss:[0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [50] Eval metrics for task 1 >> {'accuracy': 0.605519294629566, 'loss': 0.005057769952361116, 'std': 0.028283522271842443, 'EER': -1, 'EO': [0.1774436090225564, 0.08744038155802858], 'DP': -1, 'accuracy_s0': 0.6512605042016807, 'accuracy_s1': 0.6062588904694168, 'classwise_accuracy': {0: array([ 71, 123]), 1: array([45, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 34, 1: 28}, 'class_pred_count_s1': {0: 63, 1: 68, 3: 1}, 'class_pred_count': {0: 97, 1: 96, 3: 1}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [50] Eval metrics for task 2 >> {'accuracy': 0.05357142857142857, 'loss': 0.01838614100174938, 'std': 0.05357142857142857, 'EER': -1, 'EO': [0.007662835249042141, 0.0], 'DP': -1, 'accuracy_s0': 0.05555555555555555, 'accuracy_s1': 0.05172413793103448, 'classwise_accuracy': {3: array([ 6, 56]), 2: array([ 0, 83])}, 'DP_ingredients': {'class_pred_count_s0': {1: 15, 0: 42, 3: 3}, 'class_pred_count_s1': {1: 28, 0: 43, 3: 8}, 'class_pred_count': {1: 43, 0: 85, 3: 11}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# training_task_end
# ---------------------------- Task 3 -----------------------
# Elapsed time(grad):0.941
# losses=tensor([[0.2335, 0.2233, 2.6853, 2.2654, 4.5455, 4.2987, 0.3445, 0.3665, 2.4900,
#          2.7625, 4.5071, 4.3568]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.188
# Fairness:[ 0.00821912  0.00257972 -0.00209061  0.03949608  0.01236912  0.02928759]
# Current class expected loss:[ 0.          0.          0.          0.         -0.09079847  0.        ]
# len(updated_seq_indices)=512
# [51] Eval metrics for task 1 >> {'accuracy': 0.4800755754036413, 'loss': 0.007543586578565775, 'std': 0.04105118515973891, 'EER': -1, 'EO': [0.04054054054054057, 0.013533834586466176], 'DP': -1, 'accuracy_s0': 0.4642857142857143, 'accuracy_s1': 0.4913229018492177, 'classwise_accuracy': {1: array([37, 71]), 0: array([ 54, 123])}, 'DP_ingredients': {'class_pred_count_s0': {3: 9, 1: 24, 0: 22, 2: 7}, 'class_pred_count_s1': {1: 50, 3: 24, 0: 52, 2: 6}, 'class_pred_count': {1: 74, 3: 33, 0: 74, 2: 13}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [51] Eval metrics for task 2 >> {'accuracy': 0.36650172117039587, 'loss': 0.009558519013494039, 'std': 0.29421256454388983, 'EER': -1, 'EO': [0.0600255427841635, 0.030909090909090914], 'DP': -1, 'accuracy_s0': 0.3602693602693603, 'accuracy_s1': 0.3748275862068966, 'classwise_accuracy': {3: array([37, 56]), 2: array([ 6, 83])}, 'DP_ingredients': {'class_pred_count_s0': {0: 24, 3: 26, 1: 7, 2: 3}, 'class_pred_count_s1': {3: 42, 1: 17, 0: 17, 2: 3}, 'class_pred_count': {3: 68, 0: 41, 1: 24, 2: 6}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [51] Eval metrics for task 3 >> {'accuracy': 0.0, 'loss': 0.015538806055748412, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {5: array([  0, 133]), 4: array([  0, 100])}, 'DP_ingredients': {'class_pred_count_s0': {3: 97, 0: 46, 1: 7, 2: 2}, 'class_pred_count_s1': {3: 65, 1: 13, 0: 2, 2: 1}, 'class_pred_count': {3: 162, 0: 48, 1: 20, 2: 3}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# Elapsed time(grad):0.974
# losses=tensor([[0.6158, 0.5931, 1.4592, 1.1555, 3.7602, 3.5248, 0.8688, 0.6805, 1.3844,
#          1.2607, 3.7817, 3.6438]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.19
# Fairness:[ 0.01867179  0.0071325  -0.00906191 -0.0013462   0.00010749  0.00257692]
# Current class expected loss:[0. 0. 0. 0. 0. 0.]
# len(updated_seq_indices)=448
# [52] Eval metrics for task 1 >> {'accuracy': 0.22460780945837627, 'loss': 0.00943519159690621, 'std': 0.027424710866826976, 'EER': -1, 'EO': [0.1360902255639098, 0.0397456279809221], 'DP': -1, 'accuracy_s0': 0.2668067226890756, 'accuracy_s1': 0.2186344238975818, 'classwise_accuracy': {0: array([ 31, 123]), 1: array([14, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 17, 2: 17, 3: 18, 1: 10}, 'class_pred_count_s1': {1: 27, 3: 45, 2: 33, 0: 27}, 'class_pred_count': {1: 37, 3: 63, 2: 50, 0: 44}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [52] Eval metrics for task 2 >> {'accuracy': 0.4682659208261618, 'loss': 0.008041921279413238, 'std': 0.2995912220309811, 'EER': -1, 'EO': [0.07212121212121211, 0.12388250319284799], 'DP': -1, 'accuracy_s0': 0.45791245791245794, 'accuracy_s1': 0.48379310344827586, 'classwise_accuracy': {2: array([14, 83]), 3: array([43, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 9, 3: 36, 2: 13, 1: 2}, 'class_pred_count_s1': {2: 10, 3: 61, 1: 6, 0: 2}, 'class_pred_count': {0: 11, 2: 23, 3: 97, 1: 8}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [52] Eval metrics for task 3 >> {'accuracy': 0.0, 'loss': 0.013698504206448666, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {5: array([  0, 133]), 4: array([  0, 100])}, 'DP_ingredients': {'class_pred_count_s0': {2: 6, 3: 132, 0: 12, 1: 2}, 'class_pred_count_s1': {3: 73, 0: 1, 2: 6, 1: 1}, 'class_pred_count': {2: 12, 3: 205, 0: 13, 1: 3}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# Elapsed time(grad):0.915
# losses=tensor([[0.8948, 0.9871, 1.2260, 0.9163, 3.3126, 3.0980, 1.1764, 1.0837, 1.1907,
#          0.9408, 3.3462, 3.2165]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.175
# Fairness:[ 0.01928977  0.00679176 -0.00710653 -0.00933878  0.          0.00195354]
# Current class expected loss:[0. 0. 0. 0. 0. 0.]
# len(updated_seq_indices)=384
# [53] Eval metrics for task 1 >> {'accuracy': 0.4356463987175083, 'loss': 0.007852002517464235, 'std': 0.029142333676857896, 'EER': -1, 'EO': [0.10174880763116056, 0.028571428571428525], 'DP': -1, 'accuracy_s0': 0.4201680672268907, 'accuracy_s1': 0.45675675675675675, 'classwise_accuracy': {1: array([33, 71]), 0: array([ 50, 123])}, 'DP_ingredients': {'class_pred_count_s0': {1: 21, 0: 23, 2: 10, 3: 8}, 'class_pred_count_s1': {1: 46, 0: 48, 3: 34, 2: 4}, 'class_pred_count': {1: 67, 0: 71, 3: 42, 2: 14}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# ...
# Elapsed time(grad):1.008
# losses=tensor([[0.4099, 0.3480, 1.1101, 0.8829, 2.4456, 2.4511, 0.5756, 0.4842, 1.0558,
#          0.9135, 2.4922, 2.4612]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.19
# Fairness:[ 0.01088098  0.01157784 -0.00695584 -0.00496531  0.00359112  0.        ]
# Current class expected loss:[0. 0. 0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [68] Eval metrics for task 1 >> {'accuracy': 0.40341234398259473, 'loss': 0.009437590530238201, 'std': 0.0050383602427573615, 'EER': -1, 'EO': [0.03909774436090224, 0.050079491255961894], 'DP': -1, 'accuracy_s0': 0.4054621848739496, 'accuracy_s1': 0.4109530583214794, 'classwise_accuracy': {0: array([ 49, 123]), 1: array([29, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 21, 1: 21, 3: 8, 2: 12}, 'class_pred_count_s1': {0: 47, 1: 40, 3: 30, 2: 15}, 'class_pred_count': {0: 68, 1: 61, 3: 38, 2: 27}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [68] Eval metrics for task 2 >> {'accuracy': 0.397052495697074, 'loss': 0.010023344334938544, 'std': 0.1922332185886403, 'EER': -1, 'EO': [0.1127272727272727, 0.0063856960408684715], 'DP': -1, 'accuracy_s0': 0.43265993265993263, 'accuracy_s1': 0.37310344827586206, 'classwise_accuracy': {2: array([17, 83]), 3: array([33, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 12, 2: 13, 3: 26, 1: 9}, 'class_pred_count_s1': {3: 39, 1: 11, 0: 14, 2: 15}, 'class_pred_count': {0: 26, 2: 28, 3: 65, 1: 20}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [68] Eval metrics for task 3 >> {'accuracy': 0.0, 'loss': 0.010508681571534775, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {4: array([  0, 100]), 5: array([  0, 133])}, 'DP_ingredients': {'class_pred_count_s0': {3: 126, 0: 7, 1: 4, 2: 15}, 'class_pred_count_s1': {3: 63, 2: 12, 1: 5, 0: 1}, 'class_pred_count': {3: 189, 0: 8, 1: 9, 2: 27}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# Elapsed time(grad):0.988
# losses=tensor([[0.4073, 0.3383, 1.0749, 0.8762, 2.4315, 2.4409, 0.5796, 0.4643, 1.0170,
#          0.9000, 2.4814, 2.4492]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.224
# Fairness:[ 1.13774059e-02  1.06873573e-02 -7.31773725e-03 -5.08478879e-03
#   4.01283310e-03 -2.16840434e-19]
# Current class expected loss:[0. 0. 0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [69] Eval metrics for task 1 >> {'accuracy': 0.406389556853315, 'loss': 0.009575897885352066, 'std': 0.01614565441429061, 'EER': -1, 'EO': [0.049624060150375904, 0.07710651828298892], 'DP': -1, 'accuracy_s0': 0.4054621848739496, 'accuracy_s1': 0.41920341394025606, 'classwise_accuracy': {0: array([ 48, 123]), 1: array([30, 71])}, 'DP_ingredients': {'class_pred_count_s0': {3: 9, 0: 20, 1: 21, 2: 12}, 'class_pred_count_s1': {3: 30, 0: 45, 1: 41, 2: 16}, 'class_pred_count': {3: 39, 0: 65, 1: 62, 2: 28}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [69] Eval metrics for task 2 >> {'accuracy': 0.41802925989672973, 'loss': 0.010022836623431968, 'std': 0.18911359724612734, 'EER': -1, 'EO': [0.12303030303030305, 0.04342273307790556], 'DP': -1, 'accuracy_s0': 0.46632996632996637, 'accuracy_s1': 0.38310344827586207, 'classwise_accuracy': {2: array([19, 83]), 3: array([34, 56])}, 'DP_ingredients': {'class_pred_count_s0': {3: 26, 2: 14, 0: 11, 1: 9}, 'class_pred_count_s1': {3: 38, 1: 11, 0: 14, 2: 16}, 'class_pred_count': {3: 64, 1: 20, 2: 30, 0: 25}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [69] Eval metrics for task 3 >> {'accuracy': 0.0, 'loss': 0.010446069578244451, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {5: array([  0, 133]), 4: array([  0, 100])}, 'DP_ingredients': {'class_pred_count_s0': {0: 7, 2: 15, 3: 126, 1: 4}, 'class_pred_count_s1': {3: 63, 1: 5, 2: 12, 0: 1}, 'class_pred_count': {0: 8, 2: 27, 3: 189, 1: 9}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# Elapsed time(grad):0.979
# losses=tensor([[0.4022, 0.3223, 1.0518, 0.8665, 2.4131, 2.4253, 0.5753, 0.4456, 0.9869,
#          0.8902, 2.4668, 2.4336]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.188
# Fairness:[ 0.01152802  0.01064296 -0.0079016  -0.00512363  0.00446497  0.        ]
# Current class expected loss:[0. 0. 0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [70] Eval metrics for task 1 >> {'accuracy': 0.40341234398259473, 'loss': 0.009621371313468697, 'std': 0.0050383602427573615, 'EER': -1, 'EO': [0.050079491255961894, 0.03909774436090224], 'DP': -1, 'accuracy_s0': 0.4054621848739496, 'accuracy_s1': 0.4109530583214794, 'classwise_accuracy': {1: array([29, 71]), 0: array([ 49, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 20, 2: 12, 1: 21, 3: 9}, 'class_pred_count_s1': {3: 30, 2: 15, 0: 47, 1: 40}, 'class_pred_count': {0: 67, 3: 39, 2: 27, 1: 61}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [70] Eval metrics for task 2 >> {'accuracy': 0.40910068846815834, 'loss': 0.01009167441361242, 'std': 0.18018502581755597, 'EER': -1, 'EO': [0.0063856960408684715, 0.12303030303030305], 'DP': -1, 'accuracy_s0': 0.44781144781144777, 'accuracy_s1': 0.38310344827586207, 'classwise_accuracy': {3: array([33, 56]), 2: array([19, 83])}, 'DP_ingredients': {'class_pred_count_s0': {1: 9, 2: 14, 3: 25, 0: 12}, 'class_pred_count_s1': {2: 16, 3: 38, 1: 11, 0: 14}, 'class_pred_count': {1: 20, 2: 30, 3: 63, 0: 26}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [70] Eval metrics for task 3 >> {'accuracy': 0.0, 'loss': 0.010405461675619362, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {5: array([  0, 133]), 4: array([  0, 100])}, 'DP_ingredients': {'class_pred_count_s0': {3: 126, 2: 15, 1: 4, 0: 7}, 'class_pred_count_s1': {3: 63, 2: 13, 1: 4, 0: 1}, 'class_pred_count': {3: 189, 2: 28, 1: 8, 0: 8}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# Elapsed time(grad):1.029
# losses=tensor([[0.3670, 0.3298, 1.0494, 0.8403, 2.3989, 2.4185, 0.5401, 0.4602, 0.9732,
#          0.8641, 2.4515, 2.4222]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.181
# Fairness:[ 1.14707887e-02  1.09962998e-02 -8.90506628e-03 -5.81736578e-03
#   4.48796764e-03 -2.16840434e-19]
# Current class expected loss:[0. 0. 0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [71] Eval metrics for task 1 >> {'accuracy': 0.40232451620290854, 'loss': 0.009867618378904677, 'std': 0.02021069506469711, 'EER': -1, 'EO': [0.06015037593984962, 0.07710651828298892], 'DP': -1, 'accuracy_s0': 0.4054621848739496, 'accuracy_s1': 0.4139402560455192, 'classwise_accuracy': {0: array([ 47, 123]), 1: array([30, 71])}, 'DP_ingredients': {'class_pred_count_s0': {2: 12, 3: 9, 0: 20, 1: 21}, 'class_pred_count_s1': {0: 44, 1: 41, 3: 29, 2: 18}, 'class_pred_count': {0: 64, 1: 62, 3: 38, 2: 30}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [71] Eval metrics for task 2 >> {'accuracy': 0.43007745266781405, 'loss': 0.010082234581597417, 'std': 0.17706540447504301, 'EER': -1, 'EO': [0.08303030303030304, 0.04342273307790556], 'DP': -1, 'accuracy_s0': 0.46632996632996637, 'accuracy_s1': 0.40310344827586203, 'classwise_accuracy': {2: array([21, 83]), 3: array([34, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 9, 3: 27, 2: 14, 1: 10}, 'class_pred_count_s1': {1: 11, 2: 18, 0: 13, 3: 37}, 'class_pred_count': {0: 22, 3: 64, 2: 32, 1: 21}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [71] Eval metrics for task 3 >> {'accuracy': 0.0, 'loss': 0.010355343634478525, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {5: array([  0, 133]), 4: array([  0, 100])}, 'DP_ingredients': {'class_pred_count_s0': {2: 16, 3: 126, 1: 4, 0: 6}, 'class_pred_count_s1': {3: 63, 2: 13, 1: 4, 0: 1}, 'class_pred_count': {3: 189, 2: 29, 1: 8, 0: 7}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# Elapsed time(grad):0.788
# losses=tensor([[0.3872, 0.2958, 1.0249, 0.8289, 2.3845, 2.4035, 0.5676, 0.4117, 0.9486,
#          0.8446, 2.4430, 2.4116]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.217
# Fairness:[ 1.18902241e-02  1.00495239e-02 -9.00459363e-03 -6.12920164e-03
#   5.01419285e-03 -2.16840434e-19]
# Current class expected loss:[0. 0. 0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [72] Eval metrics for task 1 >> {'accuracy': 0.388240009160655, 'loss': 0.00991931711275553, 'std': 0.006126188022443579, 'EER': -1, 'EO': [0.06015037593984962, 0.0794912559618442], 'DP': -1, 'accuracy_s0': 0.3907563025210084, 'accuracy_s1': 0.4004267425320057, 'classwise_accuracy': {0: array([ 47, 123]), 1: array([28, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 20, 1: 20, 3: 9, 2: 13}, 'class_pred_count_s1': {1: 40, 0: 45, 3: 31, 2: 16}, 'class_pred_count': {1: 60, 0: 65, 3: 40, 2: 29}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [72] Eval metrics for task 2 >> {'accuracy': 0.41802925989672973, 'loss': 0.010152876805916106, 'std': 0.18911359724612734, 'EER': -1, 'EO': [0.04342273307790556, 0.0727272727272727], 'DP': -1, 'accuracy_s0': 0.4511784511784512, 'accuracy_s1': 0.3931034482758621, 'classwise_accuracy': {3: array([34, 56]), 2: array([19, 83])}, 'DP_ingredients': {'class_pred_count_s0': {3: 28, 2: 13, 1: 10, 0: 9}, 'class_pred_count_s1': {3: 37, 0: 14, 2: 17, 1: 11}, 'class_pred_count': {3: 65, 0: 23, 2: 30, 1: 21}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [72] Eval metrics for task 3 >> {'accuracy': 0.0, 'loss': 0.010312243080957765, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {4: array([  0, 100]), 5: array([  0, 133])}, 'DP_ingredients': {'class_pred_count_s0': {3: 127, 0: 6, 2: 16, 1: 3}, 'class_pred_count_s1': {2: 13, 3: 64, 0: 1, 1: 3}, 'class_pred_count': {3: 191, 2: 29, 0: 7, 1: 6}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# Elapsed time(grad):0.961
# losses=tensor([[0.3625, 0.2967, 1.0202, 0.8037, 2.3781, 2.3888, 0.5346, 0.4188, 0.9341,
#          0.8216, 2.4361, 2.3939]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.229
# Fairness:[ 1.13127238e-02  1.04093097e-02 -9.84659717e-03 -6.72501482e-03
#   5.08793050e-03 -5.42101086e-20]
# Current class expected loss:[0. 0. 0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [73] Eval metrics for task 1 >> {'accuracy': 0.3923050498110615, 'loss': 0.00992244727832755, 'std': 0.002061147372037081, 'EER': -1, 'EO': [0.049624060150375904, 0.0794912559618442], 'DP': -1, 'accuracy_s0': 0.3907563025210084, 'accuracy_s1': 0.4056899004267426, 'classwise_accuracy': {0: array([ 48, 123]), 1: array([28, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 20, 1: 20, 2: 13, 3: 9}, 'class_pred_count_s1': {1: 39, 3: 30, 0: 46, 2: 17}, 'class_pred_count': {1: 59, 0: 66, 3: 39, 2: 30}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [73] Eval metrics for task 2 >> {'accuracy': 0.40619621342512907, 'loss': 0.010257034850635116, 'std': 0.16523235800344233, 'EER': -1, 'EO': [0.030651340996168508, 0.052727272727272706], 'DP': -1, 'accuracy_s0': 0.41414141414141414, 'accuracy_s1': 0.40310344827586203, 'classwise_accuracy': {3: array([32, 56]), 2: array([20, 83])}, 'DP_ingredients': {'class_pred_count_s0': {1: 10, 3: 26, 2: 14, 0: 10}, 'class_pred_count_s1': {2: 18, 3: 36, 0: 14, 1: 11}, 'class_pred_count': {2: 32, 1: 21, 3: 62, 0: 24}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [73] Eval metrics for task 3 >> {'accuracy': 0.0, 'loss': 0.010250852854978372, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {4: array([  0, 100]), 5: array([  0, 133])}, 'DP_ingredients': {'class_pred_count_s0': {2: 17, 3: 125, 0: 7, 1: 3}, 'class_pred_count_s1': {3: 63, 1: 3, 2: 14, 0: 1}, 'class_pred_count': {2: 31, 3: 188, 0: 8, 1: 6}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# Elapsed time(grad):1.081
# losses=tensor([[0.3294, 0.2927, 1.0008, 0.8057, 2.3671, 2.3703, 0.4983, 0.4180, 0.9088,
#          0.8289, 2.4271, 2.3742]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.2
# Fairness:[ 0.01105695  0.01093329 -0.01031114 -0.00689754  0.0053728   0.        ]
# Current class expected loss:[0. 0. 0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [74] Eval metrics for task 1 >> {'accuracy': 0.408278941944349, 'loss': 0.01009580462249284, 'std': 0.042425283407763664, 'EER': -1, 'EO': [0.018282988871224204, 0.034962406015037584], 'DP': -1, 'accuracy_s0': 0.41701680672268904, 'accuracy_s1': 0.40867709815078235, 'classwise_accuracy': {1: array([32, 71]), 0: array([ 45, 123])}, 'DP_ingredients': {'class_pred_count_s0': {1: 23, 0: 19, 3: 9, 2: 11}, 'class_pred_count_s1': {3: 30, 1: 43, 2: 16, 0: 43}, 'class_pred_count': {1: 66, 3: 39, 0: 62, 2: 27}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [74] Eval metrics for task 2 >> {'accuracy': 0.40619621342512907, 'loss': 0.010372038367840883, 'std': 0.16523235800344233, 'EER': -1, 'EO': [0.052727272727272706, 0.030651340996168508], 'DP': -1, 'accuracy_s0': 0.41414141414141414, 'accuracy_s1': 0.40310344827586203, 'classwise_accuracy': {2: array([20, 83]), 3: array([32, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 9, 2: 15, 3: 26, 1: 10}, 'class_pred_count_s1': {2: 18, 1: 13, 3: 35, 0: 13}, 'class_pred_count': {2: 33, 1: 23, 0: 22, 3: 61}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [74] Eval metrics for task 3 >> {'accuracy': 0.0, 'loss': 0.010202577697360975, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {4: array([  0, 100]), 5: array([  0, 133])}, 'DP_ingredients': {'class_pred_count_s0': {3: 123, 1: 4, 2: 19, 0: 6}, 'class_pred_count_s1': {3: 62, 1: 4, 2: 14, 0: 1}, 'class_pred_count': {3: 185, 1: 8, 2: 33, 0: 7}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# Elapsed time(grad):0.829
# losses=tensor([[0.3461, 0.2498, 0.9874, 0.8037, 2.3513, 2.3562, 0.5194, 0.3499, 0.8940,
#          0.8258, 2.4202, 2.3691]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.211
# Fairness:[ 0.01155092  0.00938131 -0.01038327 -0.00699931  0.00604513  0.        ]
# Current class expected loss:[0. 0. 0. 0. 0. 0.]
# len(updated_seq_indices)=320
# [75] Eval metrics for task 1 >> {'accuracy': 0.388240009160655, 'loss': 0.010219639109582016, 'std': 0.006126188022443579, 'EER': -1, 'EO': [0.013909774436090205, 0.0794912559618442], 'DP': -1, 'accuracy_s0': 0.37289915966386555, 'accuracy_s1': 0.4056899004267426, 'classwise_accuracy': {0: array([ 47, 123]), 1: array([28, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 19, 3: 9, 1: 20, 2: 14}, 'class_pred_count_s1': {2: 17, 1: 39, 0: 46, 3: 30}, 'class_pred_count': {2: 31, 1: 59, 0: 65, 3: 39}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [75] Eval metrics for task 2 >> {'accuracy': 0.40619621342512907, 'loss': 0.010299927039112118, 'std': 0.16523235800344233, 'EER': -1, 'EO': [0.040868454661558085, 0.052727272727272706], 'DP': -1, 'accuracy_s0': 0.43265993265993263, 'accuracy_s1': 0.3858620689655172, 'classwise_accuracy': {3: array([32, 56]), 2: array([20, 83])}, 'DP_ingredients': {'class_pred_count_s0': {3: 27, 0: 9, 1: 9, 2: 15}, 'class_pred_count_s1': {2: 19, 3: 35, 0: 14, 1: 11}, 'class_pred_count': {3: 62, 0: 23, 2: 34, 1: 20}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [75] Eval metrics for task 3 >> {'accuracy': 0.0, 'loss': 0.010165880678037717, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {5: array([  0, 133]), 4: array([  0, 100])}, 'DP_ingredients': {'class_pred_count_s0': {3: 123, 2: 19, 0: 7, 1: 3}, 'class_pred_count_s1': {3: 64, 2: 14, 0: 1, 1: 2}, 'class_pred_count': {3: 187, 2: 33, 0: 8, 1: 5}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# training_task_end
# final avg-acc 0.26481207419526137
# final avg-forget 0.1086396427344555

# %%
import copy
task_weight = copy.deepcopy(algorithm.weight_all)

num_bin = 20
np.arange(0+1/num_bin, 1+1/num_bin, 1/num_bin)

def bin(w: np.array, num_bin=20):
    out = dict()
    for r in np.arange(0+1/num_bin, 1+1/num_bin, 1/num_bin):
        r = np.round(r, 2)
        out[r] = np.sum(np.logical_and(w<=r, r-1/num_bin<w))
    out[1/num_bin] += np.sum(w==0)
    kk = list(out.keys())
    for k in kk:
        if out[k] == 0:
            del(out[k])
    return out


binned_weight = dict()
for i, wt in enumerate(task_weight):
    if i==0:
        continue
    print(f"task:{i+1}")
    binned_weight[i+1] = list()
    for we in wt:
        binned_weight[i+1].append({k: bin(we[k]) for k in we})
# Out:
# task:2
# task:3

# %%
def bin(w: np.array, num_bin=20):
    out = dict()
    for r in np.arange(0+1/num_bin, 1+1/num_bin, 1/num_bin):
        r = np.round(r, 2)
        out[r] = np.sum(np.logical_and(w<=r, r-1/num_bin<w))
    out[1/num_bin] += np.sum(w==0)
    kk = list(out.keys())
    for k in kk:
        if out[k] == 0:
            del(out[k])
    return out

# %%
binned_weight = dict()
for i, wt in enumerate(task_weight):
    if i==0:
        continue
    print(f"task:{i+1}")
    binned_weight[i+1] = list()
    for we in wt:
        binned_weight[i+1].append({k: bin(we[k]) for k in we})
# Out:
# task:2
# task:3

# %%
binned_weight
# Out:
# {2: [{0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {0.05: 3, 0.9: 1, 1.0: 150}, 1: {1.0: 184}},
#   {0: {0.05: 19, 0.6: 1, 0.95: 1, 1.0: 133}, 1: {0.05: 2, 1.0: 182}},
#   {0: {0.05: 31, 0.8: 1, 1.0: 122}, 1: {0.05: 6, 1.0: 178}},
#   {0: {0.05: 38, 0.1: 1, 0.7: 1, 1.0: 114}, 1: {0.05: 7, 1.0: 177}},
#   {0: {0.05: 42, 0.45: 1, 0.85: 1, 1.0: 110}, 1: {0.05: 7, 1.0: 177}},
#   {0: {0.05: 43, 0.8: 1, 1.0: 110}, 1: {0.05: 6, 0.5: 1, 0.65: 1, 1.0: 176}},
#   {0: {0.05: 41, 0.25: 1, 0.3: 1, 0.45: 1, 1.0: 110}, 1: {0.05: 7, 1.0: 177}},
#   {0: {0.05: 39, 0.55: 1, 0.6: 1, 0.95: 1, 1.0: 112}, 1: {0.05: 10, 1.0: 174}},
#   {0: {0.05: 37, 0.55: 1, 0.85: 1, 1.0: 115},
#    1: {0.05: 14, 0.55: 1, 1.0: 169}},
#   {0: {0.05: 30, 0.45: 1, 1.0: 123}, 1: {0.05: 23, 0.35: 1, 1.0: 160}},
#   {0: {0.05: 27, 0.3: 1, 0.55: 1, 1.0: 125}, 1: {0.05: 28, 0.1: 1, 1.0: 155}},
#   {0: {0.05: 29, 0.3: 1, 0.35: 1, 1.0: 123}, 1: {0.05: 29, 0.4: 1, 1.0: 154}},
#   {0: {0.05: 33, 0.25: 1, 0.45: 1, 1.0: 119},
#    1: {0.05: 27, 0.45: 1, 1.0: 156}},
#   {0: {0.05: 36, 0.95: 1, 1.0: 117}, 1: {0.05: 27, 0.6: 1, 0.95: 1, 1.0: 155}},
#   {0: {0.05: 37, 0.35: 1, 1.0: 116}, 1: {0.05: 27, 0.1: 1, 1.0: 156}},
#   {0: {0.05: 37, 0.55: 1, 1.0: 116}, 1: {0.05: 30, 1.0: 154}},
#   {0: {0.05: 38, 0.25: 1, 0.4: 1, 1.0: 114}, 1: {0.05: 30, 0.95: 1, 1.0: 153}},
#   {0: {0.05: 39, 0.35: 1, 1.0: 114}, 1: {0.05: 31, 0.5: 1, 1.0: 152}},
#   {0: {0.05: 39, 0.45: 1, 1.0: 114}, 1: {0.05: 32, 0.35: 1, 1.0: 151}},
#   {0: {0.05: 39, 0.75: 1, 1.0: 114}, 1: {0.05: 33, 0.55: 2, 1.0: 149}},
#   {0: {0.05: 39, 0.75: 1, 1.0: 114}, 1: {0.05: 33, 0.2: 1, 0.35: 1, 1.0: 149}},
#   {0: {0.05: 39, 0.1: 1, 0.45: 1, 1.0: 113},
#    1: {0.05: 33, 0.6: 1, 0.95: 1, 1.0: 149}},
#   {0: {0.05: 40, 0.15: 1, 0.4: 1, 1.0: 112}, 1: {0.05: 31, 0.75: 1, 1.0: 152}},
#   {0: {0.05: 40, 0.75: 1, 0.85: 1, 1.0: 112},
#    1: {0.05: 32, 0.45: 1, 1.0: 151}}],
#  3: [{0: {0.05: 60, 0.2: 1, 1.0: 311}, 1: {0.05: 35, 1.0: 148}},
#   {0: {0.05: 148, 0.55: 1, 0.95: 1, 1.0: 222}, 1: {0.05: 11, 1.0: 172}},
#   {0: {0.05: 189, 0.5: 1, 0.8: 1, 1.0: 181}, 1: {0.05: 20, 0.65: 1, 1.0: 162}},
#   {0: {0.05: 196, 0.1: 1, 0.7: 1, 0.75: 1, 1.0: 173}, 1: {0.05: 20, 1.0: 163}},
#   {0: {0.05: 196, 0.35: 1, 1.0: 175},
#    1: {0.05: 21, 0.45: 1, 0.75: 1, 1.0: 160}},
#   {0: {0.05: 201, 0.3: 1, 0.6: 1, 1.0: 169}, 1: {0.05: 26, 0.95: 1, 1.0: 156}},
#   {0: {0.05: 210, 0.75: 1, 1.0: 161}, 1: {0.05: 28, 0.75: 1, 1.0: 154}},
#   {0: {0.05: 214, 0.65: 1, 0.75: 1, 0.8: 1, 1.0: 155},
#    1: {0.05: 28, 1.0: 155}},
#   {0: {0.05: 213, 0.1: 1, 0.2: 1, 0.75: 1, 1.0: 156}, 1: {0.05: 28, 1.0: 155}},
#   {0: {0.05: 214, 0.1: 1, 0.9: 1, 1.0: 156}, 1: {0.05: 28, 0.8: 1, 1.0: 154}},
#   {0: {0.05: 211, 0.25: 1, 0.3: 2, 1.0: 158}, 1: {0.05: 31, 1.0: 152}},
#   {0: {0.05: 210, 0.25: 1, 0.3: 1, 0.6: 1, 1.0: 159}, 1: {0.05: 36, 1.0: 147}},
#   {0: {0.05: 211, 0.1: 1, 0.3: 1, 1.0: 159}, 1: {0.05: 39, 0.65: 1, 1.0: 143}},
#   {0: {0.05: 212, 0.3: 1, 0.45: 1, 0.5: 1, 1.0: 157}, 1: {0.05: 41, 1.0: 142}},
#   {0: {0.05: 211, 0.5: 1, 0.8: 1, 0.95: 1, 1.0: 158}, 1: {0.05: 45, 1.0: 138}},
#   {0: {0.05: 213, 0.1: 1, 1.0: 158}, 1: {0.05: 43, 0.65: 1, 1.0: 139}},
#   {0: {0.05: 213, 0.65: 1, 0.9: 1, 1.0: 157},
#    1: {0.05: 43, 0.55: 1, 1.0: 139}},
#   {0: {0.05: 209, 0.4: 1, 0.8: 1, 1.0: 161}, 1: {0.05: 48, 0.65: 1, 1.0: 134}},
#   {0: {0.05: 208, 0.35: 2, 0.45: 1, 1.0: 161}, 1: {0.05: 49, 1.0: 134}},
#   {0: {0.05: 208, 0.25: 1, 0.7: 1, 1.0: 162}, 1: {0.05: 50, 1.0: 133}},
#   {0: {0.05: 207, 0.3: 2, 1.0: 163}, 1: {0.05: 51, 0.55: 1, 1.0: 131}},
#   {0: {0.05: 208, 0.45: 2, 0.85: 1, 1.0: 161}, 1: {0.05: 51, 1.0: 132}},
#   {0: {0.05: 207, 0.2: 1, 0.4: 1, 0.9: 1, 1.0: 162}, 1: {0.05: 53, 1.0: 130}},
#   {0: {0.05: 206, 0.1: 1, 1.0: 165}, 1: {0.05: 53, 0.8: 1, 0.95: 1, 1.0: 128}},
#   {0: {0.05: 208, 0.6: 1, 0.65: 1, 1.0: 162},
#    1: {0.05: 49, 0.7: 1, 1.0: 133}}]}

# %%
metric_manager_callback.meters['accuracy'].get_data()
# Out:
# array([[0.5  , 0.   , 0.   ],
#        [0.606, 0.054, 0.   ],
#        [0.388, 0.406, 0.   ]])

# %%
np.mean(metric_manager_callback.meters['accuracy'].compute_overall())
# Out:
# 0.36478581193191956

# %%
[np.round(x, 3) for x in metric_manager_callback.meters['EO'].compute_overall()]
# Out:
# [0.0, 0.068, 0.031]

# %%
np.mean(metric_manager_callback.meters['EO'].compute_overall())
# Out:
# 0.03310094425173366

# %%
[np.round(x, 3) for x in metric_manager_callback.meters['DP'].compute_overall()]
# Out:
# [0.0, 0.04, 0.036]

# %%
np.mean(metric_manager_callback.meters['DP'].compute_overall())
# Out:
# 0.02526963520768237
