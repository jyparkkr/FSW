# %%
import numpy as np
import random

import torch
import torch.nn.functional as F
import cl_gym as cl

import sys
import os

seed = 0

np.random.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.cuda.manual_seed_all(seed)
torch.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.enabled = False
torch.set_num_threads(8)


def make_params() -> dict:
    import os
    from pathlib import Path
    import uuid

    params = {
            # dataset
            'dataset': "Drug",
            'fairness_agg': 'mean',
            # 'dataset': "FashionMNIST",
            'random_class_idx': False,

            # benchmark
            'seed': seed,
            'num_tasks': 3,
            'epochs_per_task': 25,
            'per_task_examples': np.inf,
            # 'per_task_examples': 10000,
            'per_task_memory_examples': 64,
            'batch_size_train': 64,
            'batch_size_memory': 64,
            'batch_size_validation': 256,
            'tau': 10.0,
            # 'tau': 0.0,

            # algorithm
            'optimizer': 'sgd',
            'learning_rate': 0.001,
            'momentum': 0.9,
            'learning_rate_decay': 1.0,
            'criterion': torch.nn.CrossEntropyLoss(),
            'device': torch.device('cuda:6' if torch.cuda.is_available() else 'cpu'),
             
            # sample selection
            'alpha':0.01,
            'metric' : "DP",
            'lambda': 10.,
            'lambda_old': 0.0,
              }

#     trial_id = str(uuid.uuid4())
    trial_id = f"demo/dataset={params['dataset']}/seed={params['seed']}_epoch={params['epochs_per_task']}_lr={params['learning_rate']}_alpha={params['alpha']}_tau={params['tau']}"
    params['trial_id'] = trial_id
    params['output_dir'] = os.path.join("./outputs/{}".format(trial_id))
    print(f"output_dir={params['output_dir']}")
    Path(params['output_dir']).mkdir(parents=True, exist_ok=True)

    return params

params = make_params()
# Out:
# output_dir=./outputs/demo/dataset=Drug/seed=0_epoch=25_lr=0.001_alpha=0.01_tau=10.0

# %%
from datasets import MNIST
from datasets import FashionMNIST
from datasets import CIFAR10, CIFAR100
from datasets.drug import Drug

if params['dataset'] == 'MNIST':
    benchmark = MNIST(num_tasks=params['num_tasks'],
                    per_task_memory_examples=params['per_task_memory_examples'],
                    per_task_examples = params['per_task_examples'],
                    random_class_idx = params['random_class_idx'])
    input_dim = (28, 28)
elif params['dataset'] == 'FashionMNIST':
    benchmark = FashionMNIST(num_tasks=params['num_tasks'],
                            per_task_memory_examples=params['per_task_memory_examples'],
                            per_task_examples = params['per_task_examples'],
                            random_class_idx = params['random_class_idx'])
    input_dim = (28, 28)
elif params['dataset'] == 'CIFAR10':
    benchmark = CIFAR10(num_tasks=params['num_tasks'],
                        per_task_memory_examples=params['per_task_memory_examples'],
                        per_task_examples = params['per_task_examples'],
                        random_class_idx = params['random_class_idx'])
    input_dim = (3, 32, 32)
elif params['dataset'] == 'CIFAR100':        
    benchmark = CIFAR100(num_tasks=params['num_tasks'],
                        per_task_memory_examples=params['per_task_memory_examples'],
                        per_task_examples = params['per_task_examples'],
                        random_class_idx = params['random_class_idx'])
    input_dim = (3, 32, 32)
elif params['dataset'] == 'Drug':        
    benchmark = Drug(num_tasks=params['num_tasks'],
                        per_task_memory_examples=params['per_task_memory_examples'],
                        per_task_examples = params['per_task_examples'],
                        joint = params['random_class_idx'],
                        random_class_idx = params['random_class_idx'])
    input_dim = (12)
else:
    raise NotImplementedError
class_idx = benchmark.class_idx
num_classes = len(class_idx)

# %%
from algorithms.imbalance import Heuristic2
from algorithms.sensitive import Heuristic3
from metrics import FairMetricCollector
from backbones import MLP2Layers2

backbone = MLP2Layers2(
    input_dim=input_dim, 
    hidden_dim_1=256, 
    hidden_dim_2=256, 
    output_dim=num_classes,
    class_idx=class_idx,
    config=params
    ).to(params['device'])
algorithm = Heuristic3(backbone, benchmark, params, requires_memory=True)
metric_manager_callback = FairMetricCollector(num_tasks=params['num_tasks'],
                                                        eval_interval='epoch',
                                                        epochs_per_task=params['epochs_per_task'])

# %%
# from trainers import ContinualTrainer
from trainers.fair_trainer import FairContinualTrainer2 as ContinualTrainer
# from trainers.imbalance_trainer import ImbalanceContinualTrainer1 as ContinualTrainer

trainer = ContinualTrainer(algorithm, params, callbacks=[metric_manager_callback])

# %%
if params['fairness_agg'] == "mean":
    agg = np.mean
elif params['fairness_agg'] == "max":
    agg = np.max
else:
    raise NotImplementedError

fairness_metrics = ["std", "EER", "EO", "DP"]
for metric in metric_manager_callback.meters:
    if metric in fairness_metrics:
        metric_manager_callback.meters[metric].agg = agg

# %%
trainer.run()
print("final avg-acc", metric_manager_callback.meters['accuracy'].compute_final())
print("final avg-forget", metric_manager_callback.meters['forgetting'].compute_final())
# Out:
# ---------------------------- Task 1 -----------------------
# [1] Eval metrics for task 1 >> {'accuracy': 0.056910569105691054, 'loss': 0.009496929719276036, 'std': 0.056910569105691054, 'EER': -1, 'EO': [0.08383458646616541, 0.0], 'DP': -1, 'accuracy_s0': 0.08928571428571429, 'accuracy_s1': 0.04736842105263158, 'classwise_accuracy': {0: array([ 14, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {5: 37, 0: 13, 2: 11, 3: 1}, 'class_pred_count_s1': {5: 63, 3: 27, 0: 15, 2: 27}, 'class_pred_count': {5: 100, 3: 28, 0: 28, 2: 38}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [2] Eval metrics for task 1 >> {'accuracy': 0.483739837398374, 'loss': 0.008856236934661865, 'std': 0.483739837398374, 'EER': -1, 'EO': [0.04210526315789476, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.4789473684210526, 'classwise_accuracy': {0: array([119, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 61, 5: 1}, 'class_pred_count_s1': {0: 126, 2: 3, 5: 3}, 'class_pred_count': {0: 187, 2: 3, 5: 4}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [3] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.008154714230409603, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [4] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.007482933629419386, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [5] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.00686134812758141, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [6] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.00630659540903937, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [7] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.005834129667773689, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [8] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.00544821663001149, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [9] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.005143452550947052, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 71]), 0: array([123, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [10] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.004898922959553827, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [11] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.004697071830021967, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [12] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.004519783651705869, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [13] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.004360883199062544, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 71]), 0: array([123, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [14] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.004211365254883913, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [15] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.004087299415745686, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 71]), 0: array([123, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [16] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.003980454095860117, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [17] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.003888291181977262, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [18] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0038164506867988824, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [19] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0037566444922968283, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [20] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0037032998714250386, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 71]), 0: array([123, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [21] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0036618734143443942, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 71]), 0: array([123, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [22] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0036313739634051766, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [23] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.00359865377858742, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {1: array([ 0, 71]), 0: array([123, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [24] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0035736911075631367, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [25] Eval metrics for task 1 >> {'accuracy': 0.5, 'loss': 0.0035425396924166335, 'std': 0.5, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.5, 'accuracy_s1': 0.5, 'classwise_accuracy': {0: array([123, 123]), 1: array([ 0, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 62}, 'class_pred_count_s1': {0: 132}, 'class_pred_count': {0: 194}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# training_task_end
# ---------------------------- Task 2 -----------------------
# Elapsed time(grad):1.331
# losses=tensor([[0.4451, 1.0513, 4.0891, 3.8365, 0.3538, 1.2085, 4.3937, 4.0660]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.284
# Fairness:[ 0.02049626  0.00570622  0.02390805 -0.00119954]
# Current class expected loss:[  0.           0.         -10.98201308 -10.46319017]
# len(updated_seq_indices)=338
# [26] Eval metrics for task 1 >> {'accuracy': 0.594354746364365, 'loss': 0.003875571120645582, 'std': 0.2366311691285927, 'EER': -1, 'EO': [0.2319548872180451, 0.15500794912559612], 'DP': -1, 'accuracy_s0': 0.5451680672268907, 'accuracy_s1': 0.5836415362731152, 'classwise_accuracy': {0: array([ 44, 123]), 1: array([59, 71])}, 'DP_ingredients': {'class_pred_count_s0': {1: 54, 0: 8}, 'class_pred_count_s1': {1: 84, 0: 48}, 'class_pred_count': {1: 138, 0: 56}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [26] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.02827258590314028, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {1: 54, 0: 6}, 'class_pred_count_s1': {1: 55, 0: 24}, 'class_pred_count': {1: 109, 0: 30}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.893
# losses=tensor([[0.8993, 0.5358, 3.8016, 3.5969, 0.7375, 0.6501, 4.0371, 3.7747]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.164
# Fairness:[ 0.01337244  0.00583577  0.02057277 -0.00141333]
# Current class expected loss:[ 0.          0.         -9.66613393 -9.48397529]
# len(updated_seq_indices)=338
# [27] Eval metrics for task 1 >> {'accuracy': 0.5916638039619833, 'loss': 0.003900813994948397, 'std': 0.16889957631970684, 'EER': -1, 'EO': [0.1208267090620031, 0.31616541353383454], 'DP': -1, 'accuracy_s0': 0.5010504201680672, 'accuracy_s1': 0.598719772403983, 'classwise_accuracy': {1: array([54, 71]), 0: array([ 52, 123])}, 'DP_ingredients': {'class_pred_count_s0': {1: 51, 0: 11}, 'class_pred_count_s1': {1: 74, 0: 58}, 'class_pred_count': {1: 125, 0: 69}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [27] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.025399324705274843, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {3: array([ 0, 56]), 2: array([ 0, 83])}, 'DP_ingredients': {'class_pred_count_s0': {1: 51, 0: 9}, 'class_pred_count_s1': {0: 31, 1: 48}, 'class_pred_count': {0: 40, 1: 99}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):1.065
# losses=tensor([[0.8808, 0.5262, 3.4099, 3.2613, 0.6984, 0.6868, 3.6098, 3.4130]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.144
# Fairness:[ 0.01378578  0.00641684  0.01690344 -0.00125067]
# Current class expected loss:[ 0.          0.         -7.92324022 -8.06736987]
# len(updated_seq_indices)=338
# [28] Eval metrics for task 1 >> {'accuracy': 0.6017977785411657, 'loss': 0.0037085355557117264, 'std': 0.23560059544257414, 'EER': -1, 'EO': [0.020676691729323293, 0.25675675675675674], 'DP': -1, 'accuracy_s0': 0.6607142857142857, 'accuracy_s1': 0.542674253200569, 'classwise_accuracy': {0: array([103, 123]), 1: array([26, 71])}, 'DP_ingredients': {'class_pred_count_s0': {1: 22, 0: 40}, 'class_pred_count_s1': {0: 108, 1: 24}, 'class_pred_count': {0: 148, 1: 46}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [28] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.023182189721855328, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 37, 1: 23}, 'class_pred_count_s1': {0: 58, 1: 21}, 'class_pred_count': {0: 95, 1: 44}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.957
# losses=tensor([[0.6409, 0.6843, 3.0833, 2.9946, 0.4798, 0.9595, 3.2849, 3.1494]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.207
# Fairness:[ 0.01784235  0.00743865  0.01448051 -0.00094286]
# Current class expected loss:[ 0.          0.         -6.6092583  -7.06464255]
# len(updated_seq_indices)=338
# [29] Eval metrics for task 1 >> {'accuracy': 0.6147372037100652, 'loss': 0.0038582436817208516, 'std': 0.0049811061490896424, 'EER': -1, 'EO': [0.2782193958664546, 0.32706766917293234], 'DP': -1, 'accuracy_s0': 0.5609243697478992, 'accuracy_s1': 0.585348506401138, 'classwise_accuracy': {1: array([44, 71]), 0: array([ 75, 123])}, 'DP_ingredients': {'class_pred_count_s0': {1: 44, 0: 18}, 'class_pred_count_s1': {0: 84, 1: 48}, 'class_pred_count': {0: 102, 1: 92}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [29] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.021870848086240482, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {1: 36, 0: 24}, 'class_pred_count_s1': {0: 42, 1: 37}, 'class_pred_count': {0: 66, 1: 73}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):1.142
# losses=tensor([[0.7669, 0.5128, 2.9223, 2.8548, 0.5653, 0.8045, 3.0797, 2.9891]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.147
# Fairness:[ 0.01545551  0.00758855  0.0125582  -0.00095349]
# Current class expected loss:[ 0.          0.         -5.89094366 -6.53633791]
# len(updated_seq_indices)=338
# [30] Eval metrics for task 1 >> {'accuracy': 0.6063208519409138, 'loss': 0.00392783824930486, 'std': 0.06973548608725522, 'EER': -1, 'EO': [0.2323308270676691, 0.22655007949125594], 'DP': -1, 'accuracy_s0': 0.5756302521008403, 'accuracy_s1': 0.578520625889047, 'classwise_accuracy': {0: array([ 66, 123]), 1: array([48, 71])}, 'DP_ingredients': {'class_pred_count_s0': {1: 45, 0: 17}, 'class_pred_count_s1': {1: 60, 0: 72}, 'class_pred_count': {1: 105, 0: 89}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [30] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.021388235709650052, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {3: array([ 0, 56]), 2: array([ 0, 83])}, 'DP_ingredients': {'class_pred_count_s0': {1: 42, 0: 18}, 'class_pred_count_s1': {1: 41, 0: 38}, 'class_pred_count': {1: 83, 0: 56}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):1.016
# losses=tensor([[0.7923, 0.4293, 2.8635, 2.8041, 0.5780, 0.7470, 3.0003, 2.9362]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.187
# Fairness:[ 0.01423467  0.0076383   0.01177426 -0.00087796]
# Current class expected loss:[ 0.          0.         -5.61816861 -6.35772477]
# len(updated_seq_indices)=338
# [31] Eval metrics for task 1 >> {'accuracy': 0.5968739264857437, 'loss': 0.0038013943691843563, 'std': 0.061662658880109966, 'EER': -1, 'EO': [0.10174880763116056, 0.1590225563909775], 'DP': -1, 'accuracy_s0': 0.5619747899159664, 'accuracy_s1': 0.5906116642958749, 'classwise_accuracy': {1: array([38, 71]), 0: array([ 81, 123])}, 'DP_ingredients': {'class_pred_count_s0': {1: 33, 0: 29}, 'class_pred_count_s1': {0: 85, 1: 47}, 'class_pred_count': {0: 114, 1: 80}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [31] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.021269149917492763, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {3: array([ 0, 56]), 2: array([ 0, 83])}, 'DP_ingredients': {'class_pred_count_s0': {0: 32, 1: 28}, 'class_pred_count_s1': {1: 36, 0: 43}, 'class_pred_count': {0: 75, 1: 64}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):1.093
# losses=tensor([[0.6425, 0.4648, 2.8342, 2.7653, 0.4709, 0.8518, 2.9918, 2.9179]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.153
# Fairness:[ 0.01576618  0.00813118  0.01198023 -0.00060676]
# Current class expected loss:[ 0.          0.         -5.5842896  -6.27587527]
# len(updated_seq_indices)=338
# [32] Eval metrics for task 1 >> {'accuracy': 0.6084965075002863, 'loss': 0.003893666967903216, 'std': 0.03939081644337572, 'EER': -1, 'EO': [0.18195488721804515, 0.16772655007949133], 'DP': -1, 'accuracy_s0': 0.5819327731092437, 'accuracy_s1': 0.5890469416785207, 'classwise_accuracy': {0: array([ 70, 123]), 1: array([46, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 21, 1: 41}, 'class_pred_count_s1': {0: 74, 1: 58}, 'class_pred_count': {0: 95, 1: 99}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [32] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.02105677556648529, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {1: 31, 0: 29}, 'class_pred_count_s1': {1: 37, 0: 42}, 'class_pred_count': {1: 68, 0: 71}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):1.063
# losses=tensor([[0.6571, 0.3977, 2.8305, 2.7193, 0.5030, 0.7641, 2.9712, 2.8679]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.145
# Fairness:[ 0.01501407  0.00763966  0.0116696  -0.00054922]
# Current class expected loss:[ 0.          0.         -5.5514086  -6.08423838]
# len(updated_seq_indices)=338
# [33] Eval metrics for task 1 >> {'accuracy': 0.5822168785068131, 'loss': 0.003948992675112695, 'std': 0.037501431352341685, 'EER': -1, 'EO': [0.1503759398496241, 0.10890302066772661], 'DP': -1, 'accuracy_s0': 0.5525210084033614, 'accuracy_s1': 0.5732574679943101, 'classwise_accuracy': {0: array([ 67, 123]), 1: array([44, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 23, 1: 39}, 'class_pred_count_s1': {0: 71, 1: 61}, 'class_pred_count': {0: 94, 1: 100}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [33] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.0207604898823251, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 31, 1: 29}, 'class_pred_count_s1': {1: 38, 0: 41}, 'class_pred_count': {1: 67, 0: 72}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.92
# losses=tensor([[0.6189, 0.3797, 2.8024, 2.6574, 0.5039, 0.7292, 2.9395, 2.8081]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.168
# Fairness:[ 0.01559934  0.00724866  0.01142797 -0.00042814]
# Current class expected loss:[ 0.          0.         -5.45245338 -5.85439213]
# len(updated_seq_indices)=338
# [34] Eval metrics for task 1 >> {'accuracy': 0.5651551585938395, 'loss': 0.003960913296827336, 'std': 0.012309630138554906, 'EER': -1, 'EO': [0.11466165413533835, 0.020667726550079535], 'DP': -1, 'accuracy_s0': 0.5262605042016807, 'accuracy_s1': 0.5732574679943101, 'classwise_accuracy': {0: array([ 68, 123]), 1: array([41, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 27, 1: 35}, 'class_pred_count_s1': {0: 71, 1: 61}, 'class_pred_count': {0: 98, 1: 96}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [34] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.020371083732989195, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 35, 1: 25}, 'class_pred_count_s1': {0: 44, 1: 35}, 'class_pred_count': {0: 79, 1: 60}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.99
# losses=tensor([[0.5450, 0.3956, 2.7488, 2.5908, 0.4755, 0.7356, 2.8865, 2.7463]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.157
# Fairness:[ 0.01702718  0.00700041  0.01107876 -0.00028948]
# Current class expected loss:[ 0.          0.         -5.26309179 -5.63348771]
# len(updated_seq_indices)=338
# [35] Eval metrics for task 1 >> {'accuracy': 0.5559372495133402, 'loss': 0.004078708051406231, 'std': 0.03561204626130765, 'EER': -1, 'EO': [0.050079491255961894, 0.0725563909774436], 'DP': -1, 'accuracy_s0': 0.5409663865546219, 'accuracy_s1': 0.5522048364153627, 'classwise_accuracy': {1: array([42, 71]), 0: array([ 64, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 26, 1: 36}, 'class_pred_count_s1': {1: 65, 0: 67}, 'class_pred_count': {0: 93, 1: 101}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [35] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.01990998391624835, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 34, 1: 26}, 'class_pred_count_s1': {0: 44, 1: 35}, 'class_pred_count': {0: 78, 1: 61}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.85
# losses=tensor([[0.5396, 0.3670, 2.6934, 2.5327, 0.4998, 0.6684, 2.8157, 2.6852]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.196
# Fairness:[ 0.0174596   0.00640351  0.01042876 -0.00024669]
# Current class expected loss:[ 0.          0.         -5.0317599  -5.44478829]
# len(updated_seq_indices)=338
# [36] Eval metrics for task 1 >> {'accuracy': 0.5721974121149662, 'loss': 0.004127791861897891, 'std': 0.019351883659681657, 'EER': -1, 'EO': [0.050079491255961894, 0.06842105263157894], 'DP': -1, 'accuracy_s0': 0.5588235294117647, 'accuracy_s1': 0.5679943100995732, 'classwise_accuracy': {1: array([42, 71]), 0: array([ 68, 123])}, 'DP_ingredients': {'class_pred_count_s0': {1: 35, 0: 27}, 'class_pred_count_s1': {1: 62, 0: 70}, 'class_pred_count': {1: 97, 0: 97}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [36] Eval metrics for task 2 >> {'accuracy': 0.0, 'loss': 0.019549057638044837, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 0, 56])}, 'DP_ingredients': {'class_pred_count_s0': {1: 25, 0: 35}, 'class_pred_count_s1': {0: 48, 1: 31}, 'class_pred_count': {0: 83, 1: 56}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.919
# losses=tensor([[0.4907, 0.3695, 2.6486, 2.4741, 0.4823, 0.6539, 2.7643, 2.6294]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.182
# Fairness:[ 0.01840665  0.0060815   0.01004206 -0.00013349]
# Current class expected loss:[ 0.          0.         -4.87969324 -5.2625543 ]
# len(updated_seq_indices)=338
# [37] Eval metrics for task 1 >> {'accuracy': 0.5721974121149662, 'loss': 0.004204379836308588, 'std': 0.019351883659681657, 'EER': -1, 'EO': [0.10651828298887123, 0.06842105263157894], 'DP': -1, 'accuracy_s0': 0.5735294117647058, 'accuracy_s1': 0.5544807965860598, 'classwise_accuracy': {1: array([42, 71]), 0: array([ 68, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 26, 1: 36}, 'class_pred_count_s1': {0: 71, 1: 61}, 'class_pred_count': {0: 97, 1: 97}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [37] Eval metrics for task 2 >> {'accuracy': 0.008928571428571428, 'loss': 0.019246936702042174, 'std': 0.008928571428571428, 'EER': -1, 'EO': [0.0, 0.034482758620689655], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.017241379310344827, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 1, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 36, 1: 24}, 'class_pred_count_s1': {0: 48, 1: 30, 3: 1}, 'class_pred_count': {0: 84, 1: 54, 3: 1}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):1.05
# losses=tensor([[0.4597, 0.3599, 2.6148, 2.4204, 0.4751, 0.6215, 2.7224, 2.5785]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.166
# Fairness:[ 1.89230790e-02  5.69576737e-03  9.72876390e-03 -2.48429400e-05]
# Current class expected loss:[ 0.          0.         -4.77718326 -5.10040006]
# len(updated_seq_indices)=338
# [38] Eval metrics for task 1 >> {'accuracy': 0.57110958433528, 'loss': 0.004285883657711069, 'std': 0.034524218481621405, 'EER': -1, 'EO': [0.047368421052631615, 0.07949125596184425], 'DP': -1, 'accuracy_s0': 0.5735294117647058, 'accuracy_s1': 0.5574679943100995, 'classwise_accuracy': {0: array([ 66, 123]), 1: array([43, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 26, 1: 36}, 'class_pred_count_s1': {1: 64, 0: 68}, 'class_pred_count': {1: 100, 0: 94}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [38] Eval metrics for task 2 >> {'accuracy': 0.017857142857142856, 'loss': 0.019054339086409095, 'std': 0.017857142857142856, 'EER': -1, 'EO': [0.06896551724137931, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.034482758620689655, 'classwise_accuracy': {3: array([ 2, 56]), 2: array([ 0, 83])}, 'DP_ingredients': {'class_pred_count_s0': {1: 23, 0: 37}, 'class_pred_count_s1': {0: 46, 1: 30, 3: 3}, 'class_pred_count': {0: 83, 1: 53, 3: 3}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.905
# losses=tensor([[0.4346, 0.3454, 2.6080, 2.3585, 0.4688, 0.5833, 2.7108, 2.5193]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.168
# Fairness:[0.01918366 0.00526369 0.0097114  0.00011175]
# Current class expected loss:[ 0.          0.         -4.81293704 -4.88857197]
# len(updated_seq_indices)=338
# [39] Eval metrics for task 1 >> {'accuracy': 0.5751746249856864, 'loss': 0.00436462139345936, 'std': 0.030459177831214934, 'EER': -1, 'EO': [0.07949125596184425, 0.011654135338345917], 'DP': -1, 'accuracy_s0': 0.5913865546218487, 'accuracy_s1': 0.5574679943100995, 'classwise_accuracy': {1: array([43, 71]), 0: array([ 67, 123])}, 'DP_ingredients': {'class_pred_count_s0': {1: 35, 0: 27}, 'class_pred_count_s1': {1: 64, 0: 68}, 'class_pred_count': {1: 99, 0: 95}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [39] Eval metrics for task 2 >> {'accuracy': 0.017857142857142856, 'loss': 0.018882012195724378, 'std': 0.017857142857142856, 'EER': -1, 'EO': [0.0, 0.06896551724137931], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.034482758620689655, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 2, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 37, 1: 23}, 'class_pred_count_s1': {0: 45, 1: 30, 3: 4}, 'class_pred_count': {0: 82, 1: 53, 3: 4}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.905
# losses=tensor([[0.4055, 0.3347, 2.6052, 2.2975, 0.4556, 0.5523, 2.7035, 2.4607]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.191
# Fairness:[0.01942938 0.00489364 0.00973945 0.00024236]
# Current class expected loss:[ 0.          0.         -4.87071805 -4.67970953]
# len(updated_seq_indices)=338
# [40] Eval metrics for task 1 >> {'accuracy': 0.5751746249856864, 'loss': 0.004464783004878722, 'std': 0.030459177831214934, 'EER': -1, 'EO': [0.011654135338345917, 0.07949125596184425], 'DP': -1, 'accuracy_s0': 0.5913865546218487, 'accuracy_s1': 0.5574679943100995, 'classwise_accuracy': {0: array([ 67, 123]), 1: array([43, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 27, 1: 35}, 'class_pred_count_s1': {0: 68, 1: 64}, 'class_pred_count': {0: 95, 1: 99}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [40] Eval metrics for task 2 >> {'accuracy': 0.03571428571428571, 'loss': 0.01861709313426944, 'std': 0.03571428571428571, 'EER': -1, 'EO': [0.0, 0.005108556832694761], 'DP': -1, 'accuracy_s0': 0.037037037037037035, 'accuracy_s1': 0.034482758620689655, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 4, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 37, 1: 21, 3: 2}, 'class_pred_count_s1': {1: 31, 0: 43, 3: 5}, 'class_pred_count': {0: 80, 1: 52, 3: 7}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):1.137
# losses=tensor([[0.3808, 0.3213, 2.5764, 2.2538, 0.4455, 0.5210, 2.6651, 2.4172]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.181
# Fairness:[0.01978603 0.00458198 0.00946245 0.00030518]
# Current class expected loss:[ 0.          0.         -4.79962881 -4.56455796]
# len(updated_seq_indices)=338
# [41] Eval metrics for task 1 >> {'accuracy': 0.5559372495133402, 'loss': 0.004562233219441679, 'std': 0.03561204626130765, 'EER': -1, 'EO': [0.050079491255961894, 0.019924812030075123], 'DP': -1, 'accuracy_s0': 0.5766806722689075, 'accuracy_s1': 0.5416785206258891, 'classwise_accuracy': {1: array([42, 71]), 0: array([ 64, 123])}, 'DP_ingredients': {'class_pred_count_s0': {1: 34, 0: 28}, 'class_pred_count_s1': {1: 66, 0: 65, 3: 1}, 'class_pred_count': {1: 100, 0: 93, 3: 1}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [41] Eval metrics for task 2 >> {'accuracy': 0.03571428571428571, 'loss': 0.018369165255869034, 'std': 0.03571428571428571, 'EER': -1, 'EO': [0.0, 0.005108556832694761], 'DP': -1, 'accuracy_s0': 0.037037037037037035, 'accuracy_s1': 0.034482758620689655, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 4, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 41, 1: 17, 3: 2}, 'class_pred_count_s1': {1: 32, 3: 5, 0: 42}, 'class_pred_count': {1: 49, 3: 7, 0: 83}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.863
# losses=tensor([[0.3520, 0.3108, 2.5498, 2.2113, 0.4297, 0.4970, 2.6291, 2.3735]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.156
# Fairness:[0.02018271 0.00433001 0.00921813 0.00035284]
# Current class expected loss:[ 0.          0.         -4.74381655 -4.45307596]
# len(updated_seq_indices)=338
# [42] Eval metrics for task 1 >> {'accuracy': 0.5559372495133402, 'loss': 0.0046768603251152435, 'std': 0.03561204626130765, 'EER': -1, 'EO': [0.06616541353383454, 0.050079491255961894], 'DP': -1, 'accuracy_s0': 0.5945378151260504, 'accuracy_s1': 0.5364153627311522, 'classwise_accuracy': {0: array([ 64, 123]), 1: array([42, 71])}, 'DP_ingredients': {'class_pred_count_s0': {1: 33, 0: 29}, 'class_pred_count_s1': {1: 67, 0: 64, 3: 1}, 'class_pred_count': {1: 100, 0: 93, 3: 1}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [42] Eval metrics for task 2 >> {'accuracy': 0.07142857142857142, 'loss': 0.01819453308050581, 'std': 0.07142857142857142, 'EER': -1, 'EO': [0.0, 0.06130268199233718], 'DP': -1, 'accuracy_s0': 0.05555555555555555, 'accuracy_s1': 0.08620689655172414, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([ 8, 56])}, 'DP_ingredients': {'class_pred_count_s0': {1: 17, 0: 40, 3: 3}, 'class_pred_count_s1': {1: 32, 0: 38, 3: 9}, 'class_pred_count': {1: 49, 0: 78, 3: 12}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.886
# losses=tensor([[0.3305, 0.2919, 2.5382, 2.1699, 0.4200, 0.4646, 2.6095, 2.3307]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.187
# Fairness:[0.02031882 0.00404286 0.00913326 0.00040192]
# Current class expected loss:[ 0.          0.         -4.76457646 -4.34262197]
# len(updated_seq_indices)=338
# [43] Eval metrics for task 1 >> {'accuracy': 0.5670445436848734, 'loss': 0.0047846461079784275, 'std': 0.03858925913202793, 'EER': -1, 'EO': [0.14812030075187976, 0.02305246422893481], 'DP': -1, 'accuracy_s0': 0.6302521008403361, 'accuracy_s1': 0.5446657183499288, 'classwise_accuracy': {0: array([ 65, 123]), 1: array([43, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 30, 1: 31, 3: 1}, 'class_pred_count_s1': {1: 68, 0: 62, 3: 2}, 'class_pred_count': {1: 99, 0: 92, 3: 3}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [43] Eval metrics for task 2 >> {'accuracy': 0.08035714285714286, 'loss': 0.017972469329833984, 'std': 0.08035714285714286, 'EER': -1, 'EO': [0.024265644955300147, 0.0], 'DP': -1, 'accuracy_s0': 0.07407407407407407, 'accuracy_s1': 0.08620689655172414, 'classwise_accuracy': {3: array([ 9, 56]), 2: array([ 0, 83])}, 'DP_ingredients': {'class_pred_count_s0': {1: 17, 0: 39, 3: 4}, 'class_pred_count_s1': {0: 38, 3: 9, 1: 32}, 'class_pred_count': {0: 77, 1: 49, 3: 13}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.876
# losses=tensor([[0.3039, 0.2794, 2.5125, 2.1316, 0.4022, 0.4426, 2.5766, 2.2944]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.195
# Fairness:[0.02058097 0.00383456 0.00895956 0.0004841 ]
# Current class expected loss:[ 0.          0.         -4.7288879  -4.26528746]
# len(updated_seq_indices)=338
# [44] Eval metrics for task 1 >> {'accuracy': 0.5700217565555937, 'loss': 0.004917225579625552, 'std': 0.04969655330356115, 'EER': -1, 'EO': [0.15864661654135342, 0.060413354531001606], 'DP': -1, 'accuracy_s0': 0.615546218487395, 'accuracy_s1': 0.566429587482219, 'classwise_accuracy': {0: array([ 64, 123]), 1: array([44, 71])}, 'DP_ingredients': {'class_pred_count_s0': {1: 30, 0: 31, 3: 1}, 'class_pred_count_s1': {1: 70, 0: 59, 3: 3}, 'class_pred_count': {1: 100, 0: 90, 3: 4}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [44] Eval metrics for task 2 >> {'accuracy': 0.08928571428571429, 'loss': 0.01771116428238025, 'std': 0.08928571428571429, 'EER': -1, 'EO': [0.012771392081736888, 0.0], 'DP': -1, 'accuracy_s0': 0.09259259259259259, 'accuracy_s1': 0.08620689655172414, 'classwise_accuracy': {3: array([10, 56]), 2: array([ 0, 83])}, 'DP_ingredients': {'class_pred_count_s0': {0: 38, 1: 16, 3: 6}, 'class_pred_count_s1': {1: 31, 0: 38, 3: 10}, 'class_pred_count': {1: 47, 0: 76, 3: 16}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.804
# losses=tensor([[0.2846, 0.2620, 2.4851, 2.0886, 0.3905, 0.4157, 2.5396, 2.2498]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.192
# Fairness:[0.02087376 0.00363411 0.00873798 0.00052698]
# Current class expected loss:[ 0.          0.         -4.68884151 -4.16682466]
# len(updated_seq_indices)=338
# [45] Eval metrics for task 1 >> {'accuracy': 0.5740867972060002, 'loss': 0.005047242973268647, 'std': 0.04563151265315468, 'EER': -1, 'EO': [0.14812030075187976, 0.060413354531001606], 'DP': -1, 'accuracy_s0': 0.615546218487395, 'accuracy_s1': 0.5716927453769559, 'classwise_accuracy': {0: array([ 65, 123]), 1: array([44, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 31, 1: 29, 3: 2}, 'class_pred_count_s1': {0: 60, 3: 3, 1: 69}, 'class_pred_count': {0: 91, 1: 98, 3: 5}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [45] Eval metrics for task 2 >> {'accuracy': 0.10714285714285714, 'loss': 0.017555675918249775, 'std': 0.10714285714285714, 'EER': -1, 'EO': [0.0, 0.015325670498084282], 'DP': -1, 'accuracy_s0': 0.1111111111111111, 'accuracy_s1': 0.10344827586206896, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([12, 56])}, 'DP_ingredients': {'class_pred_count_s0': {1: 16, 0: 37, 3: 7}, 'class_pred_count_s1': {0: 39, 1: 28, 3: 12}, 'class_pred_count': {0: 76, 1: 44, 3: 19}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.867
# losses=tensor([[0.2661, 0.2435, 2.4756, 2.0472, 0.3771, 0.3882, 2.5240, 2.2092]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.195
# Fairness:[0.02091967 0.00342324 0.00872984 0.00060415]
# Current class expected loss:[ 0.          0.         -4.73600834 -4.06764088]
# len(updated_seq_indices)=338
# [46] Eval metrics for task 1 >> {'accuracy': 0.5851940913775335, 'loss': 0.0051651965711534634, 'std': 0.04860872552387496, 'EER': -1, 'EO': [0.08744038155802858, 0.13759398496240605], 'DP': -1, 'accuracy_s0': 0.615546218487395, 'accuracy_s1': 0.5904694167852063, 'classwise_accuracy': {1: array([45, 71]), 0: array([ 66, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 31, 1: 29, 3: 2}, 'class_pred_count_s1': {1: 69, 0: 60, 3: 3}, 'class_pred_count': {0: 91, 1: 98, 3: 5}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [46] Eval metrics for task 2 >> {'accuracy': 0.11607142857142858, 'loss': 0.017414374317196633, 'std': 0.11607142857142858, 'EER': -1, 'EO': [0.0, 0.019157088122605387], 'DP': -1, 'accuracy_s0': 0.1111111111111111, 'accuracy_s1': 0.1206896551724138, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([13, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 37, 3: 7, 1: 16}, 'class_pred_count_s1': {1: 29, 0: 37, 3: 13}, 'class_pred_count': {1: 45, 0: 74, 3: 20}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):1.137
# losses=tensor([[0.2443, 0.2302, 2.4694, 2.0035, 0.3587, 0.3665, 2.5118, 2.1678]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.212
# Fairness:[0.02105244 0.00325097 0.00875107 0.00070357]
# Current class expected loss:[ 0.          0.         -4.80072111 -3.95897756]
# len(updated_seq_indices)=338
# [47] Eval metrics for task 1 >> {'accuracy': 0.5933241726783465, 'loss': 0.0052864465516867095, 'std': 0.040478644223061966, 'EER': -1, 'EO': [0.08744038155802858, 0.16278195488721803], 'DP': -1, 'accuracy_s0': 0.6334033613445378, 'accuracy_s1': 0.5957325746799431, 'classwise_accuracy': {1: array([45, 71]), 0: array([ 68, 123])}, 'DP_ingredients': {'class_pred_count_s0': {1: 28, 0: 32, 3: 2}, 'class_pred_count_s1': {1: 66, 0: 61, 3: 5}, 'class_pred_count': {1: 94, 0: 93, 3: 7}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [47] Eval metrics for task 2 >> {'accuracy': 0.13392857142857142, 'loss': 0.01722205457069891, 'std': 0.13392857142857142, 'EER': -1, 'EO': [0.05491698595146868, 0.0], 'DP': -1, 'accuracy_s0': 0.14814814814814814, 'accuracy_s1': 0.1206896551724138, 'classwise_accuracy': {3: array([15, 56]), 2: array([ 0, 83])}, 'DP_ingredients': {'class_pred_count_s0': {3: 10, 0: 35, 1: 15}, 'class_pred_count_s1': {0: 37, 3: 14, 1: 28}, 'class_pred_count': {0: 72, 3: 24, 1: 43}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.958
# losses=tensor([[0.2238, 0.2192, 2.4474, 1.9654, 0.3406, 0.3471, 2.4843, 2.1314]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.155
# Fairness:[0.02127877 0.00311485 0.00866666 0.00077806]
# Current class expected loss:[ 0.          0.         -4.79880027 -3.88805065]
# len(updated_seq_indices)=338
# [48] Eval metrics for task 1 >> {'accuracy': 0.58925913202794, 'loss': 0.005441770725643512, 'std': 0.04454368487346849, 'EER': -1, 'EO': [0.08744038155802858, 0.17330827067669174], 'DP': -1, 'accuracy_s0': 0.6334033613445378, 'accuracy_s1': 0.5904694167852063, 'classwise_accuracy': {1: array([45, 71]), 0: array([ 67, 123])}, 'DP_ingredients': {'class_pred_count_s0': {0: 32, 1: 28, 3: 2}, 'class_pred_count_s1': {1: 67, 0: 60, 3: 5}, 'class_pred_count': {1: 95, 0: 92, 3: 7}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [48] Eval metrics for task 2 >> {'accuracy': 0.13392857142857142, 'loss': 0.016996405965132678, 'std': 0.13392857142857142, 'EER': -1, 'EO': [0.0, 0.05491698595146868], 'DP': -1, 'accuracy_s0': 0.14814814814814814, 'accuracy_s1': 0.1206896551724138, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([15, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 36, 3: 10, 1: 14}, 'class_pred_count_s1': {1: 27, 0: 38, 3: 14}, 'class_pred_count': {0: 74, 3: 24, 1: 41}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.881
# losses=tensor([[0.2149, 0.2003, 2.4175, 1.9260, 0.3339, 0.3177, 2.4529, 2.0946]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.161
# Fairness:[0.02134082 0.00295146 0.00860651 0.0008534 ]
# Current class expected loss:[ 0.          0.         -4.7770094  -3.82561746]
# len(updated_seq_indices)=338
# [49] Eval metrics for task 1 >> {'accuracy': 0.5740867972060002, 'loss': 0.005569577217102051, 'std': 0.04563151265315468, 'EER': -1, 'EO': [0.19436090225563912, 0.060413354531001606], 'DP': -1, 'accuracy_s0': 0.6334033613445378, 'accuracy_s1': 0.566429587482219, 'classwise_accuracy': {0: array([ 65, 123]), 1: array([44, 71])}, 'DP_ingredients': {'class_pred_count_s0': {3: 2, 1: 28, 0: 32}, 'class_pred_count_s1': {0: 58, 1: 68, 3: 6}, 'class_pred_count': {3: 8, 0: 90, 1: 96}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [49] Eval metrics for task 2 >> {'accuracy': 0.14285714285714285, 'loss': 0.016879328720861203, 'std': 0.14285714285714285, 'EER': -1, 'EO': [0.0, 0.020434227330779042], 'DP': -1, 'accuracy_s0': 0.14814814814814814, 'accuracy_s1': 0.13793103448275862, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([16, 56])}, 'DP_ingredients': {'class_pred_count_s0': {1: 14, 0: 36, 3: 10}, 'class_pred_count_s1': {3: 15, 1: 26, 0: 38}, 'class_pred_count': {3: 25, 1: 40, 0: 74}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# Elapsed time(grad):0.94
# losses=tensor([[0.1992, 0.1876, 2.4139, 1.8835, 0.3169, 0.2976, 2.4453, 2.0524]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.196
# Fairness:[0.02149774 0.00281058 0.00870118 0.00092366]
# Current class expected loss:[ 0.          0.         -4.86610078 -3.72028917]
# len(updated_seq_indices)=338
# [50] Eval metrics for task 1 >> {'accuracy': 0.5781518378564068, 'loss': 0.005705365815113501, 'std': 0.041566472002748156, 'EER': -1, 'EO': [0.18383458646616546, 0.060413354531001606], 'DP': -1, 'accuracy_s0': 0.6334033613445378, 'accuracy_s1': 0.5716927453769559, 'classwise_accuracy': {0: array([ 66, 123]), 1: array([44, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 32, 1: 28, 3: 2}, 'class_pred_count_s1': {1: 67, 0: 59, 3: 6}, 'class_pred_count': {0: 91, 1: 95, 3: 8}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [50] Eval metrics for task 2 >> {'accuracy': 0.16071428571428573, 'loss': 0.01671634303580085, 'std': 0.16071428571428573, 'EER': -1, 'EO': [0.0, 0.048531289910600295], 'DP': -1, 'accuracy_s0': 0.14814814814814814, 'accuracy_s1': 0.1724137931034483, 'classwise_accuracy': {2: array([ 0, 83]), 3: array([18, 56])}, 'DP_ingredients': {'class_pred_count_s0': {0: 35, 3: 10, 1: 15}, 'class_pred_count_s1': {0: 37, 3: 18, 1: 24}, 'class_pred_count': {0: 72, 3: 28, 1: 39}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# training_task_end
# ---------------------------- Task 3 -----------------------
# Elapsed time(grad):0.916
# losses=tensor([[0.1863, 0.1748, 2.4881, 1.9435, 4.7281, 4.4705, 0.3014, 0.2791, 2.2463,
#          2.5891, 4.7326, 4.6187]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.216
# Fairness:[ 0.01102913  0.00067473  0.01020016  0.00243088 -0.02015057 -0.01835724]
# Current class expected loss:[  0.           0.           0.           0.         -12.41137021
#   -8.30179236]
# len(updated_seq_indices)=555
# [51] Eval metrics for task 1 >> {'accuracy': 0.30831329440054966, 'loss': 0.00917978569404366, 'std': 0.01563036757128136, 'EER': -1, 'EO': [0.055643879173290944, 0.17593984962406012], 'DP': -1, 'accuracy_s0': 0.3907563025210084, 'accuracy_s1': 0.27496443812233284, 'classwise_accuracy': {1: array([23, 71]), 0: array([ 36, 123])}, 'DP_ingredients': {'class_pred_count_s0': {3: 10, 0: 22, 1: 16, 2: 14}, 'class_pred_count_s1': {1: 40, 3: 30, 2: 32, 0: 30}, 'class_pred_count': {1: 56, 3: 40, 0: 52, 2: 46}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [51] Eval metrics for task 2 >> {'accuracy': 0.4387908777969019, 'loss': 0.00804088012777644, 'std': 0.2219234079173838, 'EER': -1, 'EO': [0.1587878787878788, 0.0600255427841635], 'DP': -1, 'accuracy_s0': 0.37542087542087543, 'accuracy_s1': 0.4848275862068966, 'classwise_accuracy': {2: array([18, 83]), 3: array([37, 56])}, 'DP_ingredients': {'class_pred_count_s0': {1: 6, 0: 16, 3: 31, 2: 7}, 'class_pred_count_s1': {2: 19, 3: 42, 0: 8, 1: 10}, 'class_pred_count': {2: 26, 3: 73, 1: 16, 0: 24}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [51] Eval metrics for task 3 >> {'accuracy': 0.0, 'loss': 0.016706090116705506, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {5: array([  0, 133]), 4: array([  0, 100])}, 'DP_ingredients': {'class_pred_count_s0': {3: 130, 2: 5, 0: 14, 1: 3}, 'class_pred_count_s1': {3: 68, 2: 7, 1: 5, 0: 1}, 'class_pred_count': {3: 198, 2: 12, 0: 15, 1: 8}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# Elapsed time(grad):0.957
# losses=tensor([[0.6525, 0.6904, 1.2499, 0.9104, 4.0976, 3.7547, 0.9910, 0.7792, 1.1573,
#          1.0355, 4.1284, 3.9128]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.195
# Fairness:[ 0.01202707  0.00143456  0.00550046 -0.0025553  -0.01335361 -0.00609849]
# Current class expected loss:[ 0.          0.          0.          0.         -8.24707501 -3.58103111]
# len(updated_seq_indices)=555
# [52] Eval metrics for task 1 >> {'accuracy': 0.3952822626817818, 'loss': 0.008627567094625886, 'std': 0.013168441543570358, 'EER': -1, 'EO': [0.10639097744360904, 0.050079491255961894], 'DP': -1, 'accuracy_s0': 0.42331932773109243, 'accuracy_s1': 0.39516358463726886, 'classwise_accuracy': {0: array([ 47, 123]), 1: array([29, 71])}, 'DP_ingredients': {'class_pred_count_s0': {3: 9, 2: 10, 0: 24, 1: 19}, 'class_pred_count_s1': {3: 31, 1: 43, 0: 44, 2: 14}, 'class_pred_count': {3: 40, 1: 62, 2: 24, 0: 68}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [52] Eval metrics for task 2 >> {'accuracy': 0.3845740103270224, 'loss': 0.008872504714581606, 'std': 0.2761402753872633, 'EER': -1, 'EO': [0.029090909090909084, 0.0600255427841635], 'DP': -1, 'accuracy_s0': 0.3602693602693603, 'accuracy_s1': 0.4048275862068966, 'classwise_accuracy': {2: array([ 9, 83]), 3: array([37, 56])}, 'DP_ingredients': {'class_pred_count_s0': {3: 32, 1: 7, 0: 16, 2: 5}, 'class_pred_count_s1': {3: 47, 2: 10, 1: 12, 0: 10}, 'class_pred_count': {3: 79, 2: 15, 1: 19, 0: 26}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [52] Eval metrics for task 3 >> {'accuracy': 0.0, 'loss': 0.013050212368944684, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {4: array([  0, 100]), 5: array([  0, 133])}, 'DP_ingredients': {'class_pred_count_s0': {3: 128, 0: 17, 1: 4, 2: 3}, 'class_pred_count_s1': {3: 69, 1: 5, 2: 6, 0: 1}, 'class_pred_count': {3: 197, 0: 18, 1: 9, 2: 9}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# Elapsed time(grad):0.917
# ...
# [68] Eval metrics for task 2 >> {'accuracy': 0.409315834767642, 'loss': 0.010628734561179182, 'std': 0.14425559380378658, 'EER': -1, 'EO': [0.06303030303030305, 0.003831417624521105], 'DP': -1, 'accuracy_s0': 0.4292929292929293, 'accuracy_s1': 0.39586206896551723, 'classwise_accuracy': {2: array([22, 83]), 3: array([31, 56])}, 'DP_ingredients': {'class_pred_count_s0': {1: 8, 2: 17, 3: 26, 0: 9}, 'class_pred_count_s1': {1: 13, 0: 12, 3: 33, 2: 21}, 'class_pred_count': {1: 21, 0: 21, 2: 38, 3: 59}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [68] Eval metrics for task 3 >> {'accuracy': 0.0, 'loss': 0.009216781337885387, 'std': 0.0, 'EER': -1, 'EO': [0.0, 0.0], 'DP': -1, 'accuracy_s0': 0.0, 'accuracy_s1': 0.0, 'classwise_accuracy': {4: array([  0, 100]), 5: array([  0, 133])}, 'DP_ingredients': {'class_pred_count_s0': {3: 121, 2: 21, 0: 7, 1: 2, 5: 1}, 'class_pred_count_s1': {2: 16, 3: 63, 1: 2}, 'class_pred_count': {3: 184, 2: 37, 0: 7, 1: 4, 5: 1}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# Elapsed time(grad):0.842
# losses=tensor([[0.2498, 0.2101, 0.9169, 0.7716, 2.2025, 1.9392, 0.3933, 0.2858, 0.7567,
#          0.6992, 2.4999, 2.1442]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.201
# Fairness:[ 0.00125212  0.00066551  0.00204977 -0.00749219 -0.00166454  0.00351575]
# Current class expected loss:[ 0.          0.          0.          0.         -3.15544051  0.        ]
# len(updated_seq_indices)=512
# [69] Eval metrics for task 1 >> {'accuracy': 0.380109927859842, 'loss': 0.01143983098649487, 'std': 0.014256269323256604, 'EER': -1, 'EO': [0.034962406015037584, 0.023052464228934866], 'DP': -1, 'accuracy_s0': 0.3876050420168067, 'accuracy_s1': 0.3816500711237554, 'classwise_accuracy': {0: array([ 45, 123]), 1: array([28, 71])}, 'DP_ingredients': {'class_pred_count_s0': {1: 21, 0: 20, 2: 13, 3: 8}, 'class_pred_count_s1': {0: 44, 1: 41, 3: 28, 2: 19}, 'class_pred_count': {0: 64, 1: 62, 3: 36, 2: 32}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [69] Eval metrics for task 2 >> {'accuracy': 0.3914586919104992, 'loss': 0.010721544567629587, 'std': 0.12639845094664373, 'EER': -1, 'EO': [0.06303030303030305, 0.0012771392081736277], 'DP': -1, 'accuracy_s0': 0.4107744107744108, 'accuracy_s1': 0.3786206896551724, 'classwise_accuracy': {2: array([22, 83]), 3: array([29, 56])}, 'DP_ingredients': {'class_pred_count_s0': {2: 17, 1: 8, 3: 25, 0: 9, 5: 1}, 'class_pred_count_s1': {0: 13, 3: 32, 2: 22, 1: 12}, 'class_pred_count': {2: 39, 0: 22, 3: 57, 1: 20, 5: 1}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [69] Eval metrics for task 3 >> {'accuracy': 0.0037593984962406013, 'loss': 0.009152116693652238, 'std': 0.0037593984962406013, 'EER': -1, 'EO': [0.011494252873563218, 0.0], 'DP': -1, 'accuracy_s0': 0.005747126436781609, 'accuracy_s1': 0.0, 'classwise_accuracy': {5: array([  1, 133]), 4: array([  0, 100])}, 'DP_ingredients': {'class_pred_count_s0': {0: 7, 3: 118, 5: 4, 2: 21, 1: 2}, 'class_pred_count_s1': {2: 16, 1: 2, 3: 63}, 'class_pred_count': {0: 7, 3: 181, 5: 4, 2: 37, 1: 4}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# Elapsed time(grad):0.918
# losses=tensor([[0.2305, 0.2057, 0.8788, 0.7593, 2.1821, 1.9239, 0.3687, 0.2828, 0.7224,
#          0.6820, 2.4878, 2.1253]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.217
# Fairness:[ 0.00074647  0.0006842   0.00188062 -0.00756338 -0.00163858  0.00340474]
# Current class expected loss:[ 0.          0.          0.          0.         -3.18893335  0.        ]
# len(updated_seq_indices)=512
# [70] Eval metrics for task 1 >> {'accuracy': 0.38199931295087597, 'loss': 0.011685651602204312, 'std': 0.04053589831672963, 'EER': -1, 'EO': [0.06654135338345862, 0.020667726550079535], 'DP': -1, 'accuracy_s0': 0.4023109243697479, 'accuracy_s1': 0.37937411095305834, 'classwise_accuracy': {0: array([ 42, 123]), 1: array([30, 71])}, 'DP_ingredients': {'class_pred_count_s0': {1: 22, 0: 20, 3: 8, 2: 12}, 'class_pred_count_s1': {0: 40, 3: 29, 1: 44, 2: 19}, 'class_pred_count': {1: 66, 0: 60, 3: 37, 2: 31}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [70] Eval metrics for task 2 >> {'accuracy': 0.39748278829604133, 'loss': 0.010857840236142386, 'std': 0.12037435456110157, 'EER': -1, 'EO': [0.0012771392081736277, 0.09333333333333332], 'DP': -1, 'accuracy_s0': 0.42592592592592593, 'accuracy_s1': 0.3786206896551724, 'classwise_accuracy': {3: array([29, 56]), 2: array([23, 83])}, 'DP_ingredients': {'class_pred_count_s0': {3: 24, 2: 18, 1: 8, 0: 9, 5: 1}, 'class_pred_count_s1': {3: 32, 0: 12, 2: 22, 1: 13}, 'class_pred_count': {3: 56, 0: 21, 2: 40, 1: 21, 5: 1}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [70] Eval metrics for task 3 >> {'accuracy': 0.011278195488721804, 'loss': 0.009133267300323355, 'std': 0.011278195488721804, 'EER': -1, 'EO': [0.034482758620689655, 0.0], 'DP': -1, 'accuracy_s0': 0.017241379310344827, 'accuracy_s1': 0.0, 'classwise_accuracy': {5: array([  3, 133]), 4: array([  0, 100])}, 'DP_ingredients': {'class_pred_count_s0': {3: 117, 5: 6, 2: 21, 1: 2, 0: 6}, 'class_pred_count_s1': {3: 63, 2: 15, 1: 2, 5: 1}, 'class_pred_count': {3: 180, 5: 7, 2: 36, 1: 4, 0: 6}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# Elapsed time(grad):0.882
# losses=tensor([[0.2308, 0.1826, 0.8594, 0.7298, 2.1655, 1.9214, 0.3610, 0.2503, 0.7033,
#          0.6541, 2.4840, 2.1258]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.205
# Fairness:[ 0.00056083  0.00048537  0.0016532  -0.00769534 -0.00144523  0.00345895]
# Current class expected loss:[ 0.          0.          0.          0.         -3.17677416  0.        ]
# len(updated_seq_indices)=512
# [71] Eval metrics for task 1 >> {'accuracy': 0.37197984655902894, 'loss': 0.011804161612520512, 'std': 0.022386350624069597, 'EER': -1, 'EO': [0.05601503759398496, 0.023052464228934866], 'DP': -1, 'accuracy_s0': 0.3876050420168067, 'accuracy_s1': 0.37112375533428166, 'classwise_accuracy': {0: array([ 43, 123]), 1: array([28, 71])}, 'DP_ingredients': {'class_pred_count_s0': {2: 13, 1: 21, 0: 20, 3: 8}, 'class_pred_count_s1': {2: 19, 1: 42, 3: 29, 0: 42}, 'class_pred_count': {2: 32, 1: 63, 3: 37, 0: 62}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [71] Eval metrics for task 2 >> {'accuracy': 0.3914586919104992, 'loss': 0.011023557443412945, 'std': 0.12639845094664373, 'EER': -1, 'EO': [0.06303030303030305, 0.0012771392081736277], 'DP': -1, 'accuracy_s0': 0.4107744107744108, 'accuracy_s1': 0.3786206896551724, 'classwise_accuracy': {2: array([22, 83]), 3: array([29, 56])}, 'DP_ingredients': {'class_pred_count_s0': {3: 25, 1: 8, 2: 17, 0: 9, 5: 1}, 'class_pred_count_s1': {3: 31, 0: 12, 2: 22, 4: 1, 1: 13}, 'class_pred_count': {3: 56, 0: 21, 2: 39, 1: 21, 4: 1, 5: 1}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [71] Eval metrics for task 3 >> {'accuracy': 0.018796992481203006, 'loss': 0.009092323769827257, 'std': 0.018796992481203006, 'EER': -1, 'EO': [0.024237881059470265, 0.0], 'DP': -1, 'accuracy_s0': 0.022988505747126436, 'accuracy_s1': 0.010869565217391304, 'classwise_accuracy': {5: array([  5, 133]), 4: array([  0, 100])}, 'DP_ingredients': {'class_pred_count_s0': {3: 115, 2: 19, 5: 9, 0: 7, 1: 2}, 'class_pred_count_s1': {2: 15, 3: 62, 5: 2, 1: 2}, 'class_pred_count': {2: 34, 3: 177, 5: 11, 0: 7, 1: 4}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# Elapsed time(grad):0.88
# losses=tensor([[0.2081, 0.1743, 0.8399, 0.7087, 2.1437, 1.9155, 0.3303, 0.2408, 0.6840,
#          0.6335, 2.4721, 2.1187]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.201
# Fairness:[ 1.49119114e-05  4.50196556e-04  1.45331049e-03 -7.82929928e-03
#  -1.35036115e-03  3.39337568e-03]
# Current class expected loss:[ 0.          0.          0.          0.         -3.18501672  0.        ]
# len(updated_seq_indices)=512
# [72] Eval metrics for task 1 >> {'accuracy': 0.3660254208175885, 'loss': 0.011944910914627547, 'std': 0.00017176228100310165, 'EER': -1, 'EO': [0.034962406015037584, 0.02543720190779014], 'DP': -1, 'accuracy_s0': 0.37289915966386555, 'accuracy_s1': 0.36813655761024183, 'classwise_accuracy': {0: array([ 45, 123]), 1: array([26, 71])}, 'DP_ingredients': {'class_pred_count_s0': {3: 8, 0: 20, 1: 20, 2: 14}, 'class_pred_count_s1': {3: 26, 0: 44, 1: 40, 2: 22}, 'class_pred_count': {3: 34, 0: 64, 1: 60, 2: 36}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [72] Eval metrics for task 2 >> {'accuracy': 0.39748278829604133, 'loss': 0.011116437774767979, 'std': 0.12037435456110157, 'EER': -1, 'EO': [0.04303030303030303, 0.0012771392081736277], 'DP': -1, 'accuracy_s0': 0.4107744107744108, 'accuracy_s1': 0.38862068965517244, 'classwise_accuracy': {2: array([23, 83]), 3: array([29, 56])}, 'DP_ingredients': {'class_pred_count_s0': {3: 25, 0: 9, 1: 8, 2: 17, 5: 1}, 'class_pred_count_s1': {2: 23, 3: 30, 1: 12, 0: 13, 5: 1}, 'class_pred_count': {2: 40, 3: 55, 1: 20, 0: 22, 5: 2}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [72] Eval metrics for task 3 >> {'accuracy': 0.02631578947368421, 'loss': 0.009020668242622343, 'std': 0.02631578947368421, 'EER': -1, 'EO': [0.013993003498250875, 0.0], 'DP': -1, 'accuracy_s0': 0.028735632183908046, 'accuracy_s1': 0.021739130434782608, 'classwise_accuracy': {5: array([  7, 133]), 4: array([  0, 100])}, 'DP_ingredients': {'class_pred_count_s0': {5: 10, 3: 112, 2: 22, 1: 2, 0: 6}, 'class_pred_count_s1': {3: 61, 2: 14, 5: 3, 0: 1, 1: 2}, 'class_pred_count': {5: 13, 3: 173, 2: 36, 1: 4, 0: 7}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# Elapsed time(grad):0.866
# losses=tensor([[0.1894, 0.1747, 0.7894, 0.7089, 2.1333, 1.8908, 0.3030, 0.2394, 0.6427,
#          0.6331, 2.4667, 2.0911]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.2
# Fairness:[-0.00047978  0.00046748  0.00140554 -0.00783197 -0.00152646  0.00329214]
# Current class expected loss:[ 0.          0.          0.          0.         -3.29902276  0.        ]
# len(updated_seq_indices)=512
# [73] Eval metrics for task 1 >> {'accuracy': 0.3749570594297492, 'loss': 0.01235416746631111, 'std': 0.03349364479560288, 'EER': -1, 'EO': [0.050079491255961894, 0.06654135338345862], 'DP': -1, 'accuracy_s0': 0.3876050420168067, 'accuracy_s1': 0.37937411095305834, 'classwise_accuracy': {1: array([29, 71]), 0: array([ 42, 123])}, 'DP_ingredients': {'class_pred_count_s0': {3: 9, 1: 21, 2: 13, 0: 19}, 'class_pred_count_s1': {3: 28, 1: 44, 0: 40, 2: 20}, 'class_pred_count': {3: 37, 1: 65, 0: 59, 2: 33}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [73] Eval metrics for task 2 >> {'accuracy': 0.40641135972461273, 'loss': 0.011173026167231499, 'std': 0.12930292598967297, 'EER': -1, 'EO': [0.04303030303030303, 0.03831417624521072], 'DP': -1, 'accuracy_s0': 0.4292929292929293, 'accuracy_s1': 0.38862068965517244, 'classwise_accuracy': {2: array([23, 83]), 3: array([30, 56])}, 'DP_ingredients': {'class_pred_count_s0': {2: 17, 3: 26, 1: 8, 0: 8, 5: 1}, 'class_pred_count_s1': {3: 31, 1: 13, 2: 23, 0: 11, 4: 1}, 'class_pred_count': {3: 57, 1: 21, 2: 40, 0: 19, 4: 1, 5: 1}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [73] Eval metrics for task 3 >> {'accuracy': 0.02631578947368421, 'loss': 0.00902908042776738, 'std': 0.02631578947368421, 'EER': -1, 'EO': [0.013993003498250875, 0.0], 'DP': -1, 'accuracy_s0': 0.028735632183908046, 'accuracy_s1': 0.021739130434782608, 'classwise_accuracy': {5: array([  7, 133]), 4: array([  0, 100])}, 'DP_ingredients': {'class_pred_count_s0': {3: 113, 0: 6, 5: 10, 2: 21, 1: 2}, 'class_pred_count_s1': {3: 62, 2: 14, 1: 2, 5: 3}, 'class_pred_count': {3: 175, 2: 35, 0: 6, 5: 13, 1: 4}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# Elapsed time(grad):0.933
# losses=tensor([[0.1967, 0.1599, 0.7786, 0.6557, 2.1255, 1.8919, 0.3140, 0.2159, 0.6410,
#          0.5697, 2.4669, 2.0972]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.206
# Fairness:[-0.0004848   0.00019911  0.00107028 -0.00806272 -0.0012289   0.00337397]
# Current class expected loss:[ 0.          0.          0.          0.         -3.18984177  0.        ]
# len(updated_seq_indices)=512
# [74] Eval metrics for task 1 >> {'accuracy': 0.3608725523874957, 'loss': 0.012503557598467954, 'std': 0.019409137753349348, 'EER': -1, 'EO': [0.06654135338345862, 0.05246422893481717], 'DP': -1, 'accuracy_s0': 0.37289915966386555, 'accuracy_s1': 0.3658605974395448, 'classwise_accuracy': {0: array([ 42, 123]), 1: array([27, 71])}, 'DP_ingredients': {'class_pred_count_s0': {0: 20, 1: 20, 2: 14, 3: 8}, 'class_pred_count_s1': {0: 40, 3: 26, 2: 23, 1: 43}, 'class_pred_count': {0: 60, 3: 34, 1: 63, 2: 37}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [74] Eval metrics for task 2 >> {'accuracy': 0.41555507745266784, 'loss': 0.011253317483037496, 'std': 0.10230206540447506, 'EER': -1, 'EO': [0.033333333333333326, 0.0012771392081736277], 'DP': -1, 'accuracy_s0': 0.42592592592592593, 'accuracy_s1': 0.4086206896551724, 'classwise_accuracy': {2: array([26, 83]), 3: array([29, 56])}, 'DP_ingredients': {'class_pred_count_s0': {3: 24, 2: 19, 1: 7, 0: 8, 5: 2}, 'class_pred_count_s1': {0: 11, 3: 29, 2: 25, 1: 13, 4: 1}, 'class_pred_count': {0: 19, 3: 53, 2: 44, 1: 20, 4: 1, 5: 2}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [74] Eval metrics for task 3 >> {'accuracy': 0.041353383458646614, 'loss': 0.008956881551783483, 'std': 0.041353383458646614, 'EER': -1, 'EO': [0.006496751624187905, 0.0], 'DP': -1, 'accuracy_s0': 0.040229885057471264, 'accuracy_s1': 0.043478260869565216, 'classwise_accuracy': {5: array([ 11, 133]), 4: array([  0, 100])}, 'DP_ingredients': {'class_pred_count_s0': {5: 13, 0: 6, 3: 109, 2: 22, 1: 2}, 'class_pred_count_s1': {3: 58, 5: 5, 2: 16, 1: 2}, 'class_pred_count': {5: 18, 0: 6, 3: 167, 2: 38, 1: 4}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# Elapsed time(grad):0.864
# losses=tensor([[0.1865, 0.1546, 0.7090, 0.6764, 2.1133, 1.8664, 0.2927, 0.2056, 0.5877,
#          0.5860, 2.4648, 2.0722]])
# ### Cplex absolute_and_nonabsolute_minsum LP solver ###
# Elapsed time(optim):0.227
# Fairness:[-0.00090492  0.00020564  0.00120814 -0.00799381 -0.00154332  0.00334506]
# Current class expected loss:[ 0.          0.          0.          0.         -3.41599471  0.        ]
# len(updated_seq_indices)=512
# [75] Eval metrics for task 1 >> {'accuracy': 0.37197984655902894, 'loss': 0.01263625228527895, 'std': 0.022386350624069597, 'EER': -1, 'EO': [0.023052464228934866, 0.05601503759398496], 'DP': -1, 'accuracy_s0': 0.3876050420168067, 'accuracy_s1': 0.37112375533428166, 'classwise_accuracy': {1: array([28, 71]), 0: array([ 43, 123])}, 'DP_ingredients': {'class_pred_count_s0': {2: 13, 0: 19, 1: 21, 3: 9}, 'class_pred_count_s1': {0: 42, 1: 42, 2: 21, 3: 27}, 'class_pred_count': {0: 61, 1: 63, 2: 34, 3: 36}, 'count_s0': 62, 'count_s1': 132, 'count': 194}}
# [75] Eval metrics for task 2 >> {'accuracy': 0.39748278829604133, 'loss': 0.011503308797054154, 'std': 0.12037435456110157, 'EER': -1, 'EO': [0.0012771392081736277, 0.04303030303030303], 'DP': -1, 'accuracy_s0': 0.4107744107744108, 'accuracy_s1': 0.38862068965517244, 'classwise_accuracy': {3: array([29, 56]), 2: array([23, 83])}, 'DP_ingredients': {'class_pred_count_s0': {3: 24, 2: 18, 1: 7, 0: 9, 5: 2}, 'class_pred_count_s1': {3: 31, 1: 13, 2: 23, 4: 1, 0: 11}, 'class_pred_count': {3: 55, 1: 20, 2: 41, 4: 1, 0: 20, 5: 2}, 'count_s0': 60, 'count_s1': 79, 'count': 139}}
# [75] Eval metrics for task 3 >> {'accuracy': 0.041353383458646614, 'loss': 0.008931156903377419, 'std': 0.041353383458646614, 'EER': -1, 'EO': [0.006496751624187905, 0.0], 'DP': -1, 'accuracy_s0': 0.040229885057471264, 'accuracy_s1': 0.043478260869565216, 'classwise_accuracy': {5: array([ 11, 133]), 4: array([  0, 100])}, 'DP_ingredients': {'class_pred_count_s0': {0: 6, 3: 110, 2: 21, 5: 13, 1: 2}, 'class_pred_count_s1': {2: 14, 3: 58, 5: 6, 1: 2, 0: 1}, 'class_pred_count': {0: 7, 3: 168, 2: 35, 5: 19, 1: 4}, 'count_s0': 152, 'count_s1': 81, 'count': 233}}
# training_task_end
# final avg-acc 0.2702720061045723
# final avg-forget 0.10308599564868892

# %%
import copy
task_weight = copy.deepcopy(algorithm.weight_all)

num_bin = 20
np.arange(0+1/num_bin, 1+1/num_bin, 1/num_bin)

def bin(w: np.array, num_bin=20):
    out = dict()
    for r in np.arange(0+1/num_bin, 1+1/num_bin, 1/num_bin):
        r = np.round(r, 2)
        out[r] = np.sum(np.logical_and(w<=r, r-1/num_bin<w))
    out[1/num_bin] += np.sum(w==0)
    kk = list(out.keys())
    for k in kk:
        if out[k] == 0:
            del(out[k])
    return out


binned_weight = dict()
for i, wt in enumerate(task_weight):
    if i==0:
        continue
    print(f"task:{i+1}")
    binned_weight[i+1] = list()
    for we in wt:
        binned_weight[i+1].append({k: bin(we[k]) for k in we})
# Out:
# task:2
# task:3

# %%
def bin(w: np.array, num_bin=20):
    out = dict()
    for r in np.arange(0+1/num_bin, 1+1/num_bin, 1/num_bin):
        r = np.round(r, 2)
        out[r] = np.sum(np.logical_and(w<=r, r-1/num_bin<w))
    out[1/num_bin] += np.sum(w==0)
    kk = list(out.keys())
    for k in kk:
        if out[k] == 0:
            del(out[k])
    return out

# %%
binned_weight = dict()
for i, wt in enumerate(task_weight):
    if i==0:
        continue
    print(f"task:{i+1}")
    binned_weight[i+1] = list()
    for we in wt:
        binned_weight[i+1].append({k: bin(we[k]) for k in we})
# Out:
# task:2
# task:3

# %%
binned_weight
# Out:
# {2: [{0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}},
#   {0: {1.0: 154}, 1: {1.0: 184}}],
#  3: [{0: {1.0: 372}, 1: {1.0: 183}},
#   {0: {1.0: 372}, 1: {1.0: 183}},
#   {0: {1.0: 372}, 1: {1.0: 183}},
#   {0: {0.05: 22, 0.55: 1, 1.0: 349}, 1: {0.05: 4, 1.0: 179}},
#   {0: {0.05: 42, 0.5: 1, 1.0: 329}, 1: {0.05: 14, 1.0: 169}},
#   {0: {0.05: 46, 0.6: 1, 1.0: 325}, 1: {0.05: 15, 1.0: 168}},
#   {0: {0.05: 41, 0.35: 1, 1.0: 330}, 1: {0.05: 9, 1.0: 174}},
#   {0: {0.05: 42, 1.0: 330}, 1: {0.05: 11, 0.8: 1, 1.0: 171}},
#   {0: {0.05: 45, 0.7: 1, 1.0: 326}, 1: {0.05: 10, 1.0: 173}},
#   {0: {0.05: 43, 0.2: 1, 1.0: 328}, 1: {0.05: 10, 1.0: 173}},
#   {0: {0.05: 47, 1.0: 325}, 1: {0.05: 9, 0.65: 1, 1.0: 173}},
#   {0: {0.05: 47, 0.65: 1, 1.0: 324}, 1: {0.05: 10, 1.0: 173}},
#   {0: {0.05: 48, 0.9: 1, 1.0: 323}, 1: {0.05: 9, 1.0: 174}},
#   {0: {0.05: 49, 0.35: 1, 1.0: 322}, 1: {0.05: 8, 1.0: 175}},
#   {0: {0.05: 48, 0.85: 1, 1.0: 323}, 1: {0.05: 8, 1.0: 175}},
#   {0: {0.05: 48, 0.6: 1, 1.0: 323}, 1: {0.05: 8, 1.0: 175}},
#   {0: {0.05: 47, 1.0: 325}, 1: {0.05: 9, 1.0: 174}},
#   {0: {0.05: 47, 1.0: 325}, 1: {0.05: 8, 0.55: 1, 1.0: 174}},
#   {0: {0.05: 48, 1.0: 324}, 1: {0.05: 8, 0.95: 1, 1.0: 174}},
#   {0: {0.05: 46, 1.0: 326}, 1: {0.05: 9, 0.4: 1, 1.0: 173}},
#   {0: {0.05: 43, 0.15: 1, 1.0: 328}, 1: {0.05: 11, 1.0: 172}},
#   {0: {0.05: 42, 0.35: 1, 1.0: 329}, 1: {0.05: 11, 1.0: 172}},
#   {0: {0.05: 42, 0.35: 1, 1.0: 329}, 1: {0.05: 11, 1.0: 172}},
#   {0: {0.05: 41, 0.4: 1, 1.0: 330}, 1: {0.05: 13, 1.0: 170}},
#   {0: {0.05: 41, 0.65: 1, 1.0: 330}, 1: {0.05: 11, 1.0: 172}}]}

# %%
metric_manager_callback.meters['accuracy'].get_data()
# Out:
# array([[0.5  , 0.   , 0.   ],
#        [0.578, 0.161, 0.   ],
#        [0.372, 0.397, 0.041]])

# %%
np.mean(metric_manager_callback.meters['accuracy'].compute_overall())
# Out:
# 0.37990168929663953

# %%
[np.round(x, 3) for x in metric_manager_callback.meters['EO'].compute_overall()]
# Out:
# [0.0, 0.073, 0.022]

# %%
np.mean(metric_manager_callback.meters['EO'].compute_overall())
# Out:
# 0.03161336344706863

# %%
[np.round(x, 3) for x in metric_manager_callback.meters['DP'].compute_overall()]
# Out:
# [0.0, 0.031, 0.026]

# %%
np.mean(metric_manager_callback.meters['DP'].compute_overall())
# Out:
# 0.019291231427276397
